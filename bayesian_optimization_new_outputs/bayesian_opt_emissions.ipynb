# %%
# %cd ..
# Out:
# /Users/Matteo/PycharmProjects/TrafficEmu

# %% [markdown]
# # Bayesian optimization: finding the minimum emission

# %% [markdown]
# In this notebook we will performing bayesian optimization on the emulator trained on our sumo simulation. We are interested in identifying the parameters which enable us to obtain the minimum travel time. Our emulator is a gaussian process with an **rbf** kernel.

# %% [markdown]
# ## Imports

# %%
import pickle
import numpy as np
import emukit as ek
import GPy
import pandas as pd

from emukit.model_wrappers import GPyModelWrapper
from emukit.core.initial_designs import RandomDesign
from emukit.core import ParameterSpace, ContinuousParameter, DiscreteParameter
from emukit.bayesian_optimization.acquisitions import ExpectedImprovement
from emukit.bayesian_optimization.loops import BayesianOptimizationLoop

from experimental_design import config
from sumo_grid_simulation.grid_simulation import Simulator
# Out:
# warning in stationary: failed to import cython module: falling back to numpy
# warning in coregionalize: failed to import cython module: falling back to numpy
# warning in choleskies: failed to import cython module: falling back to numpy

# %% [markdown]
# ## Simulator

# %% [markdown]
# We start by initialising our simulation.

# %%
simulator = Simulator(end_time=300)

# %% [markdown]
# We then define the two user functions in which we are interested:

# %%
def user_function_emissions(X):
    """  X = inputs - emukit doesnt pass named args, just an NxM ndarray, N is the number of points to evaluate, M is the number of parameters per each point """
    result = []
    i = 0
    
    print(X)
    print(f'\nUser function emissions called with {X.shape[0]} inputs to simulate')

    
    for gridSize, edgeMaxSpeed, maxSpeed, edgeLength, numLanes, accel in X:
        print(f'\nEvaluating input: {i+1} of {X.shape[0]}\n')
        
        alpha = 0.005
        max_number_of_vehicles = ((gridSize - 1) * gridSize * 2 + 4 * gridSize) * edgeLength / 5
        period = 300/(max_number_of_vehicles * alpha)
        
        s = simulator.simulate(
            gridSize      = int(gridSize),
            edgeMaxSpeed  = edgeMaxSpeed,
            maxSpeed      = maxSpeed,
            edgeLength    = edgeLength,
            numberOfLanes = int(numLanes),
            accel         = accel,
            trips_generator_period = period
        )

        CO2 = s['CO2']/s['num_emissions_samples']
        result.append(CO2/(s['duration'] * s['speed']))
        print(f'\nOutput {result[-1]}\n')
        i += 1
        
    # expand dims is essential or the acquition function breaks
    return np.expand_dims(np.array(result), 1)

# %% [markdown]
# We then load the parameters' space from our configuration file:

# %%
parameter_space = config.get_parameter_space()

# %% [markdown]
# ## Emulator

# %% [markdown]
# ### Rnadomly initialised emulator

# %% [markdown]
# The first emulator we are going to analyse is the one that is just initilised with random points

# %% [markdown]
# We first sample at random 200 datapoints from the parameter space:

# %%
init_X, init_Y = pickle.load(open('bayesian_optimization_new_outputs/init_points/270_init_points_emissions.pkl', 'rb'))

'''
design = RandomDesign(parameter_space)
num_init_points = 270
init_X = design.get_samples(num_init_points)
init_Y = user_function_emissions(init_X)
init_points = init_X, init_Y
with open(f'bayesian_optimization_new_outputs/init_points/{num_init_points}_init_points_emissions.pkl', "wb") as f:
     pickle.dump(init_points, f)
'''
# Out:
# [[ 5.         12.18082649 18.8468186  46.99582856  1.          4.50929979]
#  [11.         10.76974349  5.24535327 69.22592999  1.          2.76330149]
#  [ 5.         21.61067248 17.41779625 40.10987083  2.          4.80918131]
#  ...
#  [18.         17.8298525  21.66135356 59.21727758  2.          3.68492066]
#  [19.         16.92469248 16.06943223 51.62553142  2.          2.15138894]
#  [14.         11.82983431  6.21990632 62.10346949  1.          3.93177032]]
#
# User function emissions called with 270 inputs to simulate
#
# Evaluating input: 1 of 270
#
#  Retrying in 1 seconds
#
# Output 16.198958033709683
#
#
# Evaluating input: 2 of 270
#
#  Retrying in 1 seconds
#
# Output 2.0424693061100547
#
#
# Evaluating input: 3 of 270
#
#  Retrying in 1 seconds
#
# Output 23.93412234128901
#
#
# Evaluating input: 4 of 270
#
#  Retrying in 1 seconds
#
# Output 2.206168343473036
#
#
# Evaluating input: 5 of 270
#
#  Retrying in 1 seconds
#
# Output 13.84551312197348
#
#
# Evaluating input: 6 of 270
#
#  Retrying in 1 seconds
#
# Output 9.784658857278439
#
#
# Evaluating input: 7 of 270
#
#  Retrying in 1 seconds
#
# Output 12.717172127536235
#
#
# Evaluating input: 8 of 270
#
#  Retrying in 1 seconds
#
# Output 15.444251459019299
#
#
# Evaluating input: 9 of 270
#
#  Retrying in 1 seconds
#
# Output 6.221332142950257
#
#
# Evaluating input: 10 of 270
#
#  Retrying in 1 seconds
#
# Output 13.631318886823989
#
#
# Evaluating input: 11 of 270
#
#  Retrying in 1 seconds
#
# Output 17.431418064760663
#
#
# Evaluating input: 12 of 270
#
#  Retrying in 1 seconds
#
# Output 3.068164607248117
#
#
# Evaluating input: 13 of 270
#
#  Retrying in 1 seconds
#
# Output 2.5329981647192183
#
#
# Evaluating input: 14 of 270
#
#  Retrying in 1 seconds
#
# Output 6.842241862379559
#
#
# Evaluating input: 15 of 270
#
#  Retrying in 1 seconds
#
# Output 12.5011926801031
#
#
# Evaluating input: 16 of 270
#
#  Retrying in 1 seconds
#
# Output 3.256246685754371
#
#
# Evaluating input: 17 of 270
#
#  Retrying in 1 seconds
#
# Output 4.216900275295891
#
#
# Evaluating input: 18 of 270
#
#  Retrying in 1 seconds
#
# Output 9.10097455929487
#
#
# Evaluating input: 19 of 270
#
#  Retrying in 1 seconds
#
# Output 19.082997034382696
#
#
# Evaluating input: 20 of 270
#
#  Retrying in 1 seconds
#
# Output 3.041797934105784
#
#
# Evaluating input: 21 of 270
#
#  Retrying in 1 seconds
#
# Output 3.924993574774026
#
#
# Evaluating input: 22 of 270
#
#  Retrying in 1 seconds
#
# Output 22.40812592553795
#
#
# Evaluating input: 23 of 270
#
#  Retrying in 1 seconds
#
# Output 3.4057069138582348
#
#
# Evaluating input: 24 of 270
#
#  Retrying in 1 seconds
#
# Output 4.32527043893214
#
#
# Evaluating input: 25 of 270
#
#  Retrying in 1 seconds
#
# Output 1.5247054516438583
#
#
# Evaluating input: 26 of 270
#
#
# Output 14.87239827398126
#
#
# Evaluating input: 27 of 270
#
#  Retrying in 1 seconds
#
# Output 8.74254661407998
#
#
# Evaluating input: 28 of 270
#
#  Retrying in 1 seconds
#
# Output 6.983028923060291
#
#
# Evaluating input: 29 of 270
#
#  Retrying in 1 seconds
#
# Output 8.716599253587605
#
#
# Evaluating input: 30 of 270
#
#  Retrying in 1 seconds
#
# Output 9.111235352075031
#
#
# Evaluating input: 31 of 270
#
#  Retrying in 1 seconds
#
# Output 9.472602237088083
#
#
# Evaluating input: 32 of 270
#
#  Retrying in 1 seconds
#
# Output 9.900459442649186
#
#
# Evaluating input: 33 of 270
#
#  Retrying in 1 seconds
#
# Output 5.193147092894948
#
#
# Evaluating input: 34 of 270
#
#  Retrying in 1 seconds
#
# Output 3.780612328727391
#
#
# Evaluating input: 35 of 270
#
#  Retrying in 1 seconds
#
# Output 10.474282900139489
#
#
# Evaluating input: 36 of 270
#
#  Retrying in 1 seconds
#
# Output 4.635903754423318
#
#
# Evaluating input: 37 of 270
#
#  Retrying in 1 seconds
#
# Output 5.702955629074784
#
#
# Evaluating input: 38 of 270
#
#  Retrying in 1 seconds
#
# Output 6.316265579507999
#
#
# Evaluating input: 39 of 270
#
#  Retrying in 1 seconds
#
# Output 7.800591540566459
#
#
# Evaluating input: 40 of 270
#
#  Retrying in 1 seconds
#
# Output 9.4086645751424
#
#
# Evaluating input: 41 of 270
#
#  Retrying in 1 seconds
#
# Output 4.279869721337177
#
#
# Evaluating input: 42 of 270
#
#  Retrying in 1 seconds
#
# Output 5.7840972404649875
#
#
# Evaluating input: 43 of 270
#
#  Retrying in 1 seconds
#
# Output 7.042896688823816
#
#
# Evaluating input: 44 of 270
#
#  Retrying in 1 seconds
#
# Output 5.714466524694239
#
#
# Evaluating input: 45 of 270
#
#  Retrying in 1 seconds
#
# Output 13.445539526538296
#
#
# Evaluating input: 46 of 270
#
#  Retrying in 1 seconds
#
# Output 7.152886285468862
#
#
# Evaluating input: 47 of 270
#
#  Retrying in 1 seconds
#
# Output 7.164483545079181
#
#
# Evaluating input: 48 of 270
#
#  Retrying in 1 seconds
#
# Output 6.298889157055421
#
#
# Evaluating input: 49 of 270
#
#  Retrying in 1 seconds
#
# Output 6.824864152339918
#
#
# Evaluating input: 50 of 270
#
#  Retrying in 1 seconds
#
# Output 8.914512144989596
#
#
# Evaluating input: 51 of 270
#
#  Retrying in 1 seconds
#
# Output 5.132966630355455
#
#
# Evaluating input: 52 of 270
#
#  Retrying in 1 seconds
#
# Output 13.634437916161419
#
#
# Evaluating input: 53 of 270
#
#  Retrying in 1 seconds
#
# Output 15.606069291285634
#
#
# Evaluating input: 54 of 270
#
#  Retrying in 1 seconds
#
# Output 6.25371042324615
#
#
# Evaluating input: 55 of 270
#
#  Retrying in 1 seconds
#
# Output 18.55215751211545
#
#
# Evaluating input: 56 of 270
#
#  Retrying in 1 seconds
#
# Output 5.291278057636302
#
#
# Evaluating input: 57 of 270
#
#  Retrying in 1 seconds
#
# Output 17.487455000000004
#
#
# Evaluating input: 58 of 270
#
#  Retrying in 1 seconds
#
# Output 6.716520336227475
#
#
# Evaluating input: 59 of 270
#
#  Retrying in 1 seconds
#
# Output 9.178778201985917
#
#
# Evaluating input: 60 of 270
#
#  Retrying in 1 seconds
#
# Output 4.4857485387121905
#
#
# Evaluating input: 61 of 270
#
#  Retrying in 1 seconds
#
# Output 14.016331467593083
#
#
# Evaluating input: 62 of 270
#
#  Retrying in 1 seconds
#
# Output 9.948889390047022
#
#
# Evaluating input: 63 of 270
#
#  Retrying in 1 seconds
#
# Output 2.9255966479653623
#
#
# Evaluating input: 64 of 270
#
#  Retrying in 1 seconds
#
# Output 4.365066607198144
#
#
# Evaluating input: 65 of 270
#
#  Retrying in 1 seconds
#
# Output 4.042474870871715
#
#
# Evaluating input: 66 of 270
#
#  Retrying in 1 seconds
#
# Output 8.060745597978377
#
#
# Evaluating input: 67 of 270
#
#  Retrying in 1 seconds
#
# Output 5.122106250340378
#
#
# Evaluating input: 68 of 270
#
#  Retrying in 1 seconds
#
# Output 9.72192423867124
#
#
# Evaluating input: 69 of 270
#
#  Retrying in 1 seconds
#
# Output 4.78675230722212
#
#
# Evaluating input: 70 of 270
#
#  Retrying in 1 seconds
#
# Output 10.100524501237407
#
#
# Evaluating input: 71 of 270
#
#  Retrying in 1 seconds
#
# Output 6.25419531357389
#
#
# Evaluating input: 72 of 270
#
#  Retrying in 1 seconds
#
# Output 2.431082169537899
#
#
# Evaluating input: 73 of 270
#
#  Retrying in 1 seconds
#
# Output 17.500452588338085
#
#
# Evaluating input: 74 of 270
#
#  Retrying in 1 seconds
#
# Output 8.628675167571195
#
#
# Evaluating input: 75 of 270
#
#  Retrying in 1 seconds
#
# Output 5.848556698858602
#
#
# Evaluating input: 76 of 270
#
#  Retrying in 1 seconds
#
# Output 9.315087866154869
#
#
# Evaluating input: 77 of 270
#
#  Retrying in 1 seconds
#
# Output 5.155426362145667
#
#
# Evaluating input: 78 of 270
#
#  Retrying in 1 seconds
#
# Output 16.63845653653481
#
#
# Evaluating input: 79 of 270
#
#  Retrying in 1 seconds
#
# Output 15.609252444097812
#
#
# Evaluating input: 80 of 270
#
#  Retrying in 1 seconds
#
# Output 2.841611624128532
#
#
# Evaluating input: 81 of 270
#
#  Retrying in 1 seconds
#
# Output 8.732669224958707
#
#
# Evaluating input: 82 of 270
#
#  Retrying in 1 seconds
#
# Output 4.75366639604889
#
#
# Evaluating input: 83 of 270
#
#  Retrying in 1 seconds
#
# Output 8.178450294542946
#
#
# Evaluating input: 84 of 270
#
#  Retrying in 1 seconds
#
# Output 1.8850380305496504
#
#
# Evaluating input: 85 of 270
#
#  Retrying in 1 seconds
#
# Output 11.994789222477312
#
#
# Evaluating input: 86 of 270
#
#  Retrying in 1 seconds
#
# Output 5.612314043435613
#
#
# Evaluating input: 87 of 270
#
#  Retrying in 1 seconds
#
# Output 3.1376497815438666
#
#
# Evaluating input: 88 of 270
#
#  Retrying in 1 seconds
#
# Output 5.281184989554262
#
#
# Evaluating input: 89 of 270
#
#  Retrying in 1 seconds
#
# Output 6.562758614180947
#
#
# Evaluating input: 90 of 270
#
#  Retrying in 1 seconds
#
# Output 5.066322560218718
#
#
# Evaluating input: 91 of 270
#
#  Retrying in 1 seconds
#
# Output 4.50233278434747
#
#
# Evaluating input: 92 of 270
#
#  Retrying in 1 seconds
#
# Output 10.051462273848683
#
#
# Evaluating input: 93 of 270
#
#  Retrying in 1 seconds
#
# Output 4.934037069873014
#
#
# Evaluating input: 94 of 270
#
#  Retrying in 1 seconds
#
# Output 27.208685263814704
#
#
# Evaluating input: 95 of 270
#
#  Retrying in 1 seconds
#
# Output 4.63194062717324
#
#
# Evaluating input: 96 of 270
#
#  Retrying in 1 seconds
#
# Output 9.25210998871477
#
#
# Evaluating input: 97 of 270
#  Retrying in 1 seconds
#
# Output 7.272966175545103
#
#
# Evaluating input: 98 of 270
#
#  Retrying in 1 seconds
#
# Output 4.334927252302753
#
#
# Evaluating input: 99 of 270
#
#  Retrying in 1 seconds
#
# Output 6.430221674998059
#
#
# Evaluating input: 100 of 270
#
#  Retrying in 1 seconds
#
# Output 10.378611912085091
#
#
# Evaluating input: 101 of 270
#
#  Retrying in 1 seconds
#
# Output 5.150417091133974
#
#
# Evaluating input: 102 of 270
#
#  Retrying in 1 seconds
#
# Output 10.339029236478941
#
#
# Evaluating input: 103 of 270
#
#  Retrying in 1 seconds
#
# Output 10.291877639413197
#
#
# Evaluating input: 104 of 270
#
#  Retrying in 1 seconds
#
# Output 7.7446421161589205
#
#
# Evaluating input: 105 of 270
#
#  Retrying in 1 seconds
#
# Output 5.067074237193671
#
#
# Evaluating input: 106 of 270
#
#  Retrying in 1 seconds
#
# Output 8.817525320353884
#
#
# Evaluating input: 107 of 270
#
#  Retrying in 1 seconds
#
# Output 18.811929348045247
#
#
# Evaluating input: 108 of 270
#
#  Retrying in 1 seconds
#
# Output 9.325407298072054
#
#
# Evaluating input: 109 of 270
#
#  Retrying in 1 seconds
#
# Output 3.444994763521578
#
#
# Evaluating input: 110 of 270
#
#  Retrying in 1 seconds
#
# Output 5.201010054155987
#
#
# Evaluating input: 111 of 270
#
#  Retrying in 1 seconds
#
# Output 8.588503850719915
#
#
# Evaluating input: 112 of 270
#
#  Retrying in 1 seconds
#
# Output 7.486562963174665
#
#
# Evaluating input: 113 of 270
#
#  Retrying in 1 seconds
#
# Output 7.612418303172189
#
#
# Evaluating input: 114 of 270
#
#  Retrying in 1 seconds
#
# Output 8.087041969019804
#
#
# Evaluating input: 115 of 270
#
#  Retrying in 1 seconds
#
# Output 6.438714311094118
#
#
# Evaluating input: 116 of 270
#
#  Retrying in 1 seconds
#
# Output 14.561842106667003
#
#
# Evaluating input: 117 of 270
#
#  Retrying in 1 seconds
#
# Output 17.870009002774346
#
#
# Evaluating input: 118 of 270
#
#  Retrying in 1 seconds
#
# Output 12.325293358987455
#
#
# Evaluating input: 119 of 270
#
#  Retrying in 1 seconds
#
# Output 8.882529586059421
#
#
# Evaluating input: 120 of 270
#
#  Retrying in 1 seconds
#
# Output 6.633597954717785
#
#
# Evaluating input: 121 of 270
#
#  Retrying in 1 seconds
#
# Output 2.304718464444914
#
#
# Evaluating input: 122 of 270
#
#  Retrying in 1 seconds
#
# Output 6.60462349670388
#
#
# Evaluating input: 123 of 270
#
#  Retrying in 1 seconds
#
# Output 19.999658721959854
#
#
# Evaluating input: 124 of 270
#
#  Retrying in 1 seconds
#
# Output 4.251108830965945
#
#
# Evaluating input: 125 of 270
#
#  Retrying in 1 seconds
#
# Output 4.29586983845399
#
#
# Evaluating input: 126 of 270
#
#  Retrying in 1 seconds
#
# Output 7.407067062690642
#
#
# Evaluating input: 127 of 270
#
#  Retrying in 1 seconds
#
# Output 8.773641667544176
#
#
# Evaluating input: 128 of 270
#
#  Retrying in 1 seconds
#
# Output 8.978926752038848
#
#
# Evaluating input: 129 of 270
#
#  Retrying in 1 seconds
#
# Output 4.340722898712784
#
#
# Evaluating input: 130 of 270
#
#  Retrying in 1 seconds
#
# Output 7.191590944577226
#
#
# Evaluating input: 131 of 270
#
#  Retrying in 1 seconds
#
# Output 5.6731290648250905
#
#
# Evaluating input: 132 of 270
#
#  Retrying in 1 seconds
#
# Output 6.962061204280975
#
#
# Evaluating input: 133 of 270
#
#  Retrying in 1 seconds
#
# Output 4.61246328325067
#
#
# Evaluating input: 134 of 270
#
#  Retrying in 1 seconds
#
# Output 4.591737755188785
#
#
# Evaluating input: 135 of 270
#
#  Retrying in 1 seconds
#
# Output 3.6964874352964494
#
#
# Evaluating input: 136 of 270
#
#  Retrying in 1 seconds
#
# Output 7.927851019283747
#
#
# Evaluating input: 137 of 270
#
#  Retrying in 1 seconds
#
# Output 1.8358010685451454
#
#
# Evaluating input: 138 of 270
#
#  Retrying in 1 seconds
#
# Output 6.754774856625672
#
#
# Evaluating input: 139 of 270
#
#  Retrying in 1 seconds
#
# Output 3.805156578655718
#
#
# Evaluating input: 140 of 270
#
#  Retrying in 1 seconds
#
# Output 3.0196040232000705
#
#
# Evaluating input: 141 of 270
#
#  Retrying in 1 seconds
#
# Output 2.702906259397945
#
#
# Evaluating input: 142 of 270
#
#  Retrying in 1 seconds
#
# Output 2.6092218354915646
#
#
# Evaluating input: 143 of 270
#
#  Retrying in 1 seconds
#
# Output 3.2710096147643446
#
#
# Evaluating input: 144 of 270
#
#  Retrying in 1 seconds
#
# Output 10.481809165808194
#
#
# Evaluating input: 145 of 270
#
#  Retrying in 1 seconds
#
# Output 3.242209612143658
#
#
# Evaluating input: 146 of 270
#
#  Retrying in 1 seconds
#
# Output 2.737245164575728
#
#
# Evaluating input: 147 of 270
#
#  Retrying in 1 seconds
#
# Output 12.51925022393584
#
#
# Evaluating input: 148 of 270
#
#  Retrying in 1 seconds
#
# Output 3.007966348025867
#
#
# Evaluating input: 149 of 270
#
#  Retrying in 1 seconds
#
# Output 7.270724581564477
#
#
# Evaluating input: 150 of 270
#
#  Retrying in 1 seconds
#
# Output 12.483181541186145
#
#
# Evaluating input: 151 of 270
#
#  Retrying in 1 seconds
#
# Output 15.025262301725855
#
#
# Evaluating input: 152 of 270
#
#  Retrying in 1 seconds
#
# Output 2.9932227695204476
#
#
# Evaluating input: 153 of 270
#
#  Retrying in 1 seconds
#
# Output 5.96106663570031
#
#
# Evaluating input: 154 of 270
#
#  Retrying in 1 seconds
#
# Output 10.832433363596481
#
#
# Evaluating input: 155 of 270
#
#  Retrying in 1 seconds
#
# Output 4.830753773275453
#
#
# Evaluating input: 156 of 270
#
#  Retrying in 1 seconds
#
# Output 15.725355670282026
#
#
# Evaluating input: 157 of 270
#
#  Retrying in 1 seconds
#
# Output 3.0222869173518316
#
#
# Evaluating input: 158 of 270
#
#  Retrying in 1 seconds
#
# Output 15.255959420393728
#
#
# Evaluating input: 159 of 270
#
#  Retrying in 1 seconds
#
# Output 4.501677985784822
#
#
# Evaluating input: 160 of 270
#
#  Retrying in 1 seconds
#
# Output 6.325193216062703
#
#
# Evaluating input: 161 of 270
#
#  Retrying in 1 seconds
#
# Output 18.83401895048254
#
#
# Evaluating input: 162 of 270
#
#  Retrying in 1 seconds
#
# Output 13.522373708834749
#
#
# Evaluating input: 163 of 270
#
#  Retrying in 1 seconds
#
# Output 3.913008537027672
#
#
# Evaluating input: 164 of 270
#
#  Retrying in 1 seconds
#
# Output 3.2568108108213885
#
#
# Evaluating input: 165 of 270
#
#  Retrying in 1 seconds
#
# Output 5.682575974718399
#
#
# Evaluating input: 166 of 270
#
#  Retrying in 1 seconds
#
# Output 2.20364149983315
#
#
# Evaluating input: 167 of 270
#
#  Retrying in 1 seconds
#
# Output 8.426759367252481
#
#
# Evaluating input: 168 of 270
#
#  Retrying in 1 seconds
#
# Output 5.259021479569822
#
#
# Evaluating input: 169 of 270
#
#  Retrying in 1 seconds
#
# Output 9.271327557618548
#
#
# Evaluating input: 170 of 270
#
#  Retrying in 1 seconds
#
# Output 3.073802522587526
#
#
# Evaluating input: 171 of 270
#
#  Retrying in 1 seconds
#
# Output 12.230579727244116
#
#
# Evaluating input: 172 of 270
#
#  Retrying in 1 seconds
#
# Output 5.890987260577472
#
#
# Evaluating input: 173 of 270
#
#  Retrying in 1 seconds
#
# Output 10.1211463328553
#
#
# Evaluating input: 174 of 270
#
#  Retrying in 1 seconds
#
# Output 7.76509232386564
#
#
# Evaluating input: 175 of 270
#
#  Retrying in 1 seconds
#
# Output 8.358925763343679
#
#
# Evaluating input: 176 of 270
#
#  Retrying in 1 seconds
#
# Output 11.605197537745758
#
#
# Evaluating input: 177 of 270
#
#  Retrying in 1 seconds
#
# Output 7.699644444867912
#
#
# Evaluating input: 178 of 270
#
#  Retrying in 1 seconds
#
# Output 5.55889469945005
#
#
# Evaluating input: 179 of 270
#
#  Retrying in 1 seconds
#
# Output 1.7159855885465296
#
#
# Evaluating input: 180 of 270
#
#  Retrying in 1 seconds
#
# Output 8.099981869408445
#
#
# Evaluating input: 181 of 270
#
#  Retrying in 1 seconds
#
# Output 4.0859140719668074
#
#
# Evaluating input: 182 of 270
#
#  Retrying in 1 seconds
#
# Output 11.044676366050014
#
#
# Evaluating input: 183 of 270
#
#  Retrying in 1 seconds
#
# Output 5.626681914968667
#
#
# Evaluating input: 184 of 270
#
#  Retrying in 1 seconds
#
# Output 3.338774535155367
#
#
# Evaluating input: 185 of 270
#
#  Retrying in 1 seconds
#
# Output 2.5591985924202008
#
#
# Evaluating input: 186 of 270
#
#  Retrying in 1 seconds
#
# Output 3.6621120616379264
#
#
# Evaluating input: 187 of 270
#
#  Retrying in 1 seconds
#
# Output 6.274484774396017
#
#
# Evaluating input: 188 of 270
#
#  Retrying in 1 seconds
#
# Output 22.213671367965578
#
#
# Evaluating input: 189 of 270
#
#  Retrying in 1 seconds
#
# Output 3.632154095568742
#
#
# Evaluating input: 190 of 270
#
#  Retrying in 1 seconds
#
# Output 10.926134290409328
#
#
# Evaluating input: 191 of 270
#
#  Retrying in 1 seconds
#
# Output 4.6721670575328975
#
#
# Evaluating input: 192 of 270
#
#  Retrying in 1 seconds
#
# Output 12.505668153745447
#
#
# Evaluating input: 193 of 270
#
#  Retrying in 1 seconds
#
# Output 14.624702550986203
#
#
# Evaluating input: 194 of 270
#
#  Retrying in 1 seconds
#
# Output 6.435123489563726
#
#
# Evaluating input: 195 of 270
#
#  Retrying in 1 seconds
#
# Output 3.0619182002064944
#
#
# Evaluating input: 196 of 270
#
#  Retrying in 1 seconds
#
# Output 6.324574355921416
#
#
# Evaluating input: 197 of 270
#
#  Retrying in 1 seconds
#
# Output 4.734594838272557
#
#
# Evaluating input: 198 of 270
#  Retrying in 1 seconds
#
# Output 2.5827606002725156
#
#
# Evaluating input: 199 of 270
#
#  Retrying in 1 seconds
#
# Output 6.325421405717069
#
#
# Evaluating input: 200 of 270
#
#  Retrying in 1 seconds
#
# Output 13.17459526237965
#
#
# Evaluating input: 201 of 270
#
#  Retrying in 1 seconds
#
# Output 6.86865890342591
#
#
# Evaluating input: 202 of 270
#
#  Retrying in 1 seconds
#
# Output 3.625164014766223
#
#
# Evaluating input: 203 of 270
#
#  Retrying in 1 seconds
#
# Output 4.443386617750007
#
#
# Evaluating input: 204 of 270
#
#  Retrying in 1 seconds
#
# Output 2.746036244112864
#
#
# Evaluating input: 205 of 270
#
#  Retrying in 1 seconds
#
# Output 12.608793103066356
#
#
# Evaluating input: 206 of 270
#
#  Retrying in 1 seconds
#
# Output 4.530953235484135
#
#
# Evaluating input: 207 of 270
#
#  Retrying in 1 seconds
#
# Output 7.646020456246202
#
#
# Evaluating input: 208 of 270
#
#  Retrying in 1 seconds
#
# Output 3.141467333904541
#
#
# Evaluating input: 209 of 270
#
#  Retrying in 1 seconds
#
# Output 11.926877952889852
#
#
# Evaluating input: 210 of 270
#
#  Retrying in 1 seconds
#
# Output 9.396567069294337
#
#
# Evaluating input: 211 of 270
#
#  Retrying in 1 seconds
#
# Output 11.509886054141317
#
#
# Evaluating input: 212 of 270
#
#  Retrying in 1 seconds
#
# Output 4.608738286062733
#
#
# Evaluating input: 213 of 270
#
#  Retrying in 1 seconds
#
# Output 9.882211952877473
#
#
# Evaluating input: 214 of 270
#
#  Retrying in 1 seconds
#
# Output 6.353382691337809
#
#
# Evaluating input: 215 of 270
#
#  Retrying in 1 seconds
#
# Output 4.100862927392755
#
#
# Evaluating input: 216 of 270
#
#  Retrying in 1 seconds
#
# Output 28.260296201814054
#
#
# Evaluating input: 217 of 270
#
#  Retrying in 1 seconds
#
# Output 4.2623669888368125
#
#
# Evaluating input: 218 of 270
#
#  Retrying in 1 seconds
#
# Output 5.020093636717136
#
#
# Evaluating input: 219 of 270
#
#  Retrying in 1 seconds
#
# Output 7.042769289785206
#
#
# Evaluating input: 220 of 270
#
#  Retrying in 1 seconds
#
# Output 4.032565506969407
#
#
# Evaluating input: 221 of 270
#
#  Retrying in 1 seconds
#
# Output 4.525014284451348
#
#
# Evaluating input: 222 of 270
#
#  Retrying in 1 seconds
#
# Output 4.0494739228527425
#
#
# Evaluating input: 223 of 270
#
#  Retrying in 1 seconds
#
# Output 3.318429085812799
#
#
# Evaluating input: 224 of 270
#
#  Retrying in 1 seconds
#
# Output 2.2181917444000168
#
#
# Evaluating input: 225 of 270
#
#  Retrying in 1 seconds
#
# Output 6.101394398105737
#
#
# Evaluating input: 226 of 270
#
#  Retrying in 1 seconds
#
# Output 3.1117290659380266
#
#
# Evaluating input: 227 of 270
#
#  Retrying in 1 seconds
#
# Output 3.0846463075466857
#
#
# Evaluating input: 228 of 270
#
#  Retrying in 1 seconds
#
# Output 9.62730732708275
#
#
# Evaluating input: 229 of 270
#
#  Retrying in 1 seconds
#
# Output 10.677486955133377
#
#
# Evaluating input: 230 of 270
#
#  Retrying in 1 seconds
#
# Output 3.3635830848423542
#
#
# Evaluating input: 231 of 270
#
#  Retrying in 1 seconds
#
# Output 8.681080971613747
#
#
# Evaluating input: 232 of 270
#
#  Retrying in 1 seconds
#
# Output 3.365143485769055
#
#
# Evaluating input: 233 of 270
#
#  Retrying in 1 seconds
#
# Output 8.823700080973154
#
#
# Evaluating input: 234 of 270
#
#  Retrying in 1 seconds
#
# Output 14.06194771878751
#
#
# Evaluating input: 235 of 270
#
#  Retrying in 1 seconds
#
# Output 5.79614201578748
#
#
# Evaluating input: 236 of 270
#
#  Retrying in 1 seconds
#
# Output 15.490323335044764
#
#
# Evaluating input: 237 of 270
#
#  Retrying in 1 seconds
#
# Output 6.3028060092336915
#
#
# Evaluating input: 238 of 270
#
#  Retrying in 1 seconds
#
# Output 19.40494666812782
#
#
# Evaluating input: 239 of 270
#
#  Retrying in 1 seconds
#
# Output 5.746374433362915
#
#
# Evaluating input: 240 of 270
#
#  Retrying in 1 seconds
#
# Output 6.911032190651005
#
#
# Evaluating input: 241 of 270
#
#  Retrying in 1 seconds
#
# Output 8.513292528959882
#
#
# Evaluating input: 242 of 270
#
#  Retrying in 1 seconds
#
# Output 3.601174979513264
#
#
# Evaluating input: 243 of 270
#
#  Retrying in 1 seconds
#
# Output 9.060539872145595
#
#
# Evaluating input: 244 of 270
#
#  Retrying in 1 seconds
#
# Output 4.92883714330659
#
#
# Evaluating input: 245 of 270
#
#  Retrying in 1 seconds
#
# Output 5.935191801471861
#
#
# Evaluating input: 246 of 270
#
#  Retrying in 1 seconds
#
# Output 11.68892479218403
#
#
# Evaluating input: 247 of 270
#
#  Retrying in 1 seconds
#
# Output 5.462410478558346
#
#
# Evaluating input: 248 of 270
#
#  Retrying in 1 seconds
#
# Output 17.8341783070084
#
#
# Evaluating input: 249 of 270
#
#  Retrying in 1 seconds
#
# Output 7.897785934224382
#
#
# Evaluating input: 250 of 270
#
#  Retrying in 1 seconds
#
# Output 23.007405878448267
#
#
# Evaluating input: 251 of 270
#
#  Retrying in 1 seconds
#
# Output 4.452859973305019
#
#
# Evaluating input: 252 of 270
#
#  Retrying in 1 seconds
#
# Output 7.737416450580473
#
#
# Evaluating input: 253 of 270
#
#  Retrying in 1 seconds
#
# Output 17.43718514397116
#
#
# Evaluating input: 254 of 270
#
#  Retrying in 1 seconds
#
# Output 4.383062817793913
#
#
# Evaluating input: 255 of 270
#
#  Retrying in 1 seconds
#
# Output 8.636795302153493
#
#
# Evaluating input: 256 of 270
#
#  Retrying in 1 seconds
#
# Output 2.6653540329342933
#
#
# Evaluating input: 257 of 270
#
#  Retrying in 1 seconds
#
# Output 5.976848379010559
#
#
# Evaluating input: 258 of 270
#
#  Retrying in 1 seconds
#
# Output 9.121728927677617
#
#
# Evaluating input: 259 of 270
#
#  Retrying in 1 seconds
#
# Output 4.79058246046061
#
#
# Evaluating input: 260 of 270
#
#  Retrying in 1 seconds
#
# Output 5.570054285027153
#
#
# Evaluating input: 261 of 270
#
#  Retrying in 1 seconds
#
# Output 6.961762827459172
#
#
# Evaluating input: 262 of 270
#
#  Retrying in 1 seconds
#
# Output 8.7129866547416
#
#
# Evaluating input: 263 of 270
#
#  Retrying in 1 seconds
#
# Output 3.815353040011327
#
#
# Evaluating input: 264 of 270
#
#  Retrying in 1 seconds
#
# Output 11.35021741825435
#
#
# Evaluating input: 265 of 270
#
#  Retrying in 1 seconds
#
# Output 17.379342043978134
#
#
# Evaluating input: 266 of 270
#
#  Retrying in 1 seconds
#
# Output 3.772248238809897
#
#
# Evaluating input: 267 of 270
#
#  Retrying in 1 seconds
#
# Output 9.200080792352358
#
#
# Evaluating input: 268 of 270
#
#  Retrying in 1 seconds
#
# Output 4.972455725241596
#
#
# Evaluating input: 269 of 270
#
#  Retrying in 1 seconds
#
# Output 5.449609176083225
#
#
# Evaluating input: 270 of 270
#
#  Retrying in 1 seconds
#
# Output 2.239317380257322

# %% [markdown]
# To then fit a GP to these points

# %%
emulator = GPy.models.GPRegression(init_X, init_Y, noise_var=1e-10)
emukit_model_random_init = GPyModelWrapper(emulator, n_restarts=5)
emukit_model_random_init.optimize()
# Out:
# Optimization restart 1/5, f = 658.0299306274745
# Optimization restart 2/5, f = 508.81290764577227
# Optimization restart 3/5, f = 508.81290764579353
# Optimization restart 4/5, f = 508.81290764583923
# Optimization restart 5/5, f = 984.7064100908477

# %% [markdown]
# ### Experimentally designed emulator with model variance

# %% [markdown]
# We also load the emulator obtained during experimental design:

# %%
emukit_model_variance = pickle.load(open('experimental_design_new_outputs/models/model_variance_20_init_points_250_loops_co2.pkl', 'rb'))

# %% [markdown]
# ### Experimentally designed emulator with integrated variance reduction

# %% [markdown]
# We also load the emulator obtained during experimental design:

# %%
emukit_model_integrated_variance = pickle.load(open('experimental_design_new_outputs/models/integrated_variance_reduction_20_init_points_250_loops_co2.pkl', 'rb'))

# %% [markdown]
# ## Bayesian optimisation

# %% [markdown]
# We now run bayesian optimisation on the emulators

# %%
n_iter_bo = 50

# %% [markdown]
# ### Acquisition functions

# %%
acquisition_random_init = ExpectedImprovement(emukit_model_random_init)

# %%
acquisition_model_variance = ExpectedImprovement(emukit_model_variance)

# %%
acquisition_integrated_variance = ExpectedImprovement(emukit_model_integrated_variance)

# %% [markdown]
# ### Optimisation loop

# %%
bo_random_init = BayesianOptimizationLoop(parameter_space, emukit_model_random_init, acquisition=acquisition_random_init)
bo_random_init.run_loop(user_function_emissions, n_iter_bo)
# Out:
# Optimization restart 1/5, f = 508.81290764577227
# Optimization restart 2/5, f = 508.8129082007515
# Optimization restart 3/5, f = 508.8129076464255
# Optimization restart 4/5, f = 508.8129076515597
# Optimization restart 5/5, f = 508.81290766214806
# [[20. 25.  5. 70.  1.  5.]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4793876601068827
#
# Optimization restart 1/5, f = 510.98189268139697
# Optimization restart 2/5, f = 510.97817157159284
# Optimization restart 3/5, f = 510.9781715719239
# Optimization restart 4/5, f = 510.9781715717382
# Optimization restart 5/5, f = 510.9781717116666
# [[12.         25.          5.         66.83379469  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.9186259626999325
#
# Optimization restart 1/5, f = 513.3521339239195
# Optimization restart 2/5, f = 513.3487243425573
# Optimization restart 3/5, f = 513.3487243419162
# Optimization restart 4/5, f = 513.3487243413628
# Optimization restart 5/5, f = 513.3487243498137
# [[18.         25.          5.         40.99056216  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.5644679298377873
#
# Optimization restart 1/5, f = 515.5625939072013
# Optimization restart 2/5, f = 515.5577537328943
# Optimization restart 3/5, f = 515.5577537350655
# Optimization restart 4/5, f = 515.5577537597824
# Optimization restart 5/5, f = 515.5577537321533
# [[20.  8.  5. 70.  3.  5.]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.623685122334808
#
# Optimization restart 1/5, f = 517.4062990980303
# Optimization restart 2/5, f = 517.4060707809481
# Optimization restart 3/5, f = 517.4060710046488
# Optimization restart 4/5, f = 517.4060707809699
# Optimization restart 5/5, f = 517.4060707809292
# [[20.         20.15814141  5.         65.00735315  3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.743550493422713
#
# Optimization restart 1/5, f = 518.8743242248925
# Optimization restart 2/5, f = 518.8742019976366
# Optimization restart 3/5, f = 518.8742019973546
# Optimization restart 4/5, f = 518.8742019972544
# Optimization restart 5/5, f = 518.874201998158
# [[15.         25.          5.         41.73609355  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.474202238554879
#
# Optimization restart 1/5, f = 520.697894552455
# Optimization restart 2/5, f = 520.6934783998712
# Optimization restart 3/5, f = 520.6934783999144
# Optimization restart 4/5, f = 520.6934786289875
# Optimization restart 5/5, f = 520.6934784004695
# [[12.  25.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.765844094874923
#
# Optimization restart 1/5, f = 522.2035427552357
# Optimization restart 2/5, f = 522.2033158443408
# Optimization restart 3/5, f = 522.203315844078
# Optimization restart 4/5, f = 522.2033158844253
# Optimization restart 5/5, f = 1006.8536553765161
# [[20.         16.54935733  5.         70.          1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4793876601068827
#
# Optimization restart 1/5, f = 523.5508193544322
# Optimization restart 2/5, f = 523.5508122239262
# Optimization restart 3/5, f = 523.5508122594366
# Optimization restart 4/5, f = 523.5508122248064
# Optimization restart 5/5, f = 523.5508122280827
# [[16.         25.          5.         64.59994152  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.030708352938014
#
# Optimization restart 1/5, f = 524.9299809286945
# Optimization restart 2/5, f = 1013.1575570585784
# Optimization restart 3/5, f = 524.9299648884396
# Optimization restart 4/5, f = 524.9299648884831
# Optimization restart 5/5, f = 524.9299648914495
# [[20.  8.  5. 70.  1.  5.]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4793876601068827
#
# Optimization restart 1/5, f = 526.270910321676
# Optimization restart 2/5, f = 526.2708927520539
# Optimization restart 3/5, f = 526.2708927520534
# Optimization restart 4/5, f = 526.2708928208534
# Optimization restart 5/5, f = 526.2708927542242
# [[20.         17.80916743  5.         62.21520313  3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.859243132446608
#
# Optimization restart 1/5, f = 527.5827607542312
# Optimization restart 2/5, f = 527.5827271713972
# Optimization restart 3/5, f = 527.5827271720536
# Optimization restart 4/5, f = 527.5827271713404
# Optimization restart 5/5, f = 527.5827276309267
# [[15.   8.  27.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.7509200895541503
#
# Optimization restart 1/5, f = 529.2847683094365
# Optimization restart 2/5, f = 529.2846455468989
# Optimization restart 3/5, f = 529.2846455056734
# Optimization restart 4/5, f = 529.2846455083819
# Optimization restart 5/5, f = 529.2846455179255
# [[20.  8.  5. 30.  1.  5.]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 3.8004175566543945
#
# Optimization restart 1/5, f = 531.5971003973938
# Optimization restart 2/5, f = 531.5885626666727
# Optimization restart 3/5, f = 531.5885604745688
# Optimization restart 4/5, f = 531.5885604792484
# Optimization restart 5/5, f = 531.5885604839557
# [[20.  8.  5. 70.  3.  5.]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.623685122334808
#
# Optimization restart 1/5, f = 532.8083627361525
# Optimization restart 2/5, f = 532.8083417394971
# Optimization restart 3/5, f = 532.8083417556345
# Optimization restart 4/5, f = 532.8083417363302
# Optimization restart 5/5, f = 532.8083417363346
# [[12.         25.          5.         65.20759115  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.996832498179892
#
# Optimization restart 1/5, f = 534.191828831774
# Optimization restart 2/5, f = 534.1915901256175
# Optimization restart 3/5, f = 534.1915901255124
# Optimization restart 4/5, f = 534.1915901255547
# Optimization restart 5/5, f = 1021.012739593631
# [[20.         18.41411162  5.         62.64967662  3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.8395389825401383
#
# Optimization restart 1/5, f = 535.3824155734217
# Optimization restart 2/5, f = 535.3823631165228
# Optimization restart 3/5, f = 535.3823631161326
# Optimization restart 4/5, f = 535.3823631161324
# Optimization restart 5/5, f = 535.382363174666
# [[20.         15.24470387  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 536.7613778850725
# Optimization restart 2/5, f = 536.7610709050095
# Optimization restart 3/5, f = 536.7610709075277
# Optimization restart 4/5, f = 536.7610709057274
# Optimization restart 5/5, f = 536.7610709048857
# [[20. 25.  5. 70.  3.  5.]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.6164346661413083
#
# Optimization restart 1/5, f = 538.0749177447158
# Optimization restart 2/5, f = 538.074882444116
# Optimization restart 3/5, f = 538.0748824438889
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
# Optimization restart 4/5, f = 538.0748824978165
# Optimization restart 5/5, f = 538.0748824488542
# [[20.   8.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 539.4703927423878
# Optimization restart 2/5, f = 539.4702279004639
# Optimization restart 3/5, f = 682.5255291164048
# Optimization restart 4/5, f = 539.4702279218241
# Optimization restart 5/5, f = 539.4702278949692
# [[13.  25.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.6353728063663815
#
# Optimization restart 1/5, f = 540.6395720505662
# Optimization restart 2/5, f = 540.6395569437016
# Optimization restart 3/5, f = 540.6395569423507
# Optimization restart 4/5, f = 540.6395569470019
# Optimization restart 5/5, f = 540.6395569458522
# [[20.          8.         11.49241483 70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.5618519313986508
#
# Optimization restart 1/5, f = 541.9410384419773
# Optimization restart 2/5, f = 541.9410383503259
# Optimization restart 3/5, f = 693.011069038566
# Optimization restart 4/5, f = 541.9410383508624
# Optimization restart 5/5, f = 541.9410383723925
# [[20.         15.67593125  5.         70.          1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4793876601068827
#
# Optimization restart 1/5, f = 543.0848496990607
# Optimization restart 2/5, f = 543.084845836845
# Optimization restart 3/5, f = 543.0848458412606
# Optimization restart 4/5, f = 543.0848458355763
# Optimization restart 5/5, f = 543.0848458355676
# [[20.         18.21621374  5.         61.15229104  3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.8817572023615239
#
# Optimization restart 1/5, f = 544.2253355785087
# Optimization restart 2/5, f = 544.2253315579204
# Optimization restart 3/5, f = 544.2253315911403
# Optimization restart 4/5, f = 544.225331551053
# Optimization restart 5/5, f = 544.2253315727447
# [[20.         14.95784508  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 545.3710384526157
# Optimization restart 2/5, f = 545.3710133934294
# Optimization restart 3/5, f = 545.3710133976622
# Optimization restart 4/5, f = 545.3710133939146
# Optimization restart 5/5, f = 545.3710133934223
# [[20.  25.   5.  70.   3.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3111349350393235
#
# Optimization restart 1/5, f = 546.7140277967326
# Optimization restart 2/5, f = 546.7139844046848
# Optimization restart 3/5, f = 546.7139844046799
# Optimization restart 4/5, f = 546.7139844049068
# Optimization restart 5/5, f = 546.7139844047352
# [[20.         16.46714199  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 547.8133823464455
# Optimization restart 2/5, f = 547.8133672531759
# Optimization restart 3/5, f = 547.8133672490452
# Optimization restart 4/5, f = 547.8133672494312
# Optimization restart 5/5, f = 547.8133672485337
# [[20.   8.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 548.9701181262354
# Optimization restart 2/5, f = 548.970092678426
# Optimization restart 3/5, f = 548.9700927237033
# Optimization restart 4/5, f = 548.970092691214
# Optimization restart 5/5, f = 548.9700926781653
# [[20.         16.63209239  5.         70.          3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.312130307611466
#
# Optimization restart 1/5, f = 550.0932546942927
# Optimization restart 2/5, f = 550.0932474493196
# Optimization restart 3/5, f = 677.4841677366903
# Optimization restart 4/5, f = 550.0932474493342
# Optimization restart 5/5, f = 550.0932474493284
# [[20.         17.03128328  5.         70.          3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3127274329225984
#
# Optimization restart 1/5, f = 551.1744691264232
# Optimization restart 2/5, f = 551.1744601408396
# Optimization restart 3/5, f = 551.1744601366846
# Optimization restart 4/5, f = 551.1744601367826
# Optimization restart 5/5, f = 551.174460153364
# [[20.   8.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 552.271048575878
# Optimization restart 2/5, f = 552.2710310638782
# Optimization restart 3/5, f = 552.2710310635563
# Optimization restart 4/5, f = 552.2710310638596
# Optimization restart 5/5, f = 552.271031063569
# [[20.         16.85340156  5.         70.          3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3127274329225984
#
# Optimization restart 1/5, f = 553.3247167161703
# Optimization restart 2/5, f = 553.3247067344345
# Optimization restart 3/5, f = 553.3247067668419
# Optimization restart 4/5, f = 661.9808289226573
# Optimization restart 5/5, f = 553.3247067343053
# [[20.         17.07851068  5.         70.          3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3127274329225984
#
# Optimization restart 1/5, f = 554.3595314436877
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
# Optimization restart 2/5, f = 554.3595208716254
# Optimization restart 3/5, f = 554.3595208710447
# Optimization restart 4/5, f = 554.3595208710396
# Optimization restart 5/5, f = 554.3595208717658
# [[14.          8.         27.         66.12674287  3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.4303479202821583
#
# Optimization restart 1/5, f = 555.8848620342366
# Optimization restart 2/5, f = 555.883457034334
# Optimization restart 3/5, f = 555.8834570403448
# Optimization restart 4/5, f = 555.8834570347575
# Optimization restart 5/5, f = 555.8834570343756
# [[20.   8.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 556.9406257345227
# Optimization restart 2/5, f = 556.940610618756
# Optimization restart 3/5, f = 556.9406106660267
# Optimization restart 4/5, f = 556.9406106385862
# Optimization restart 5/5, f = 556.9406106186564
# [[14.  25.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.551594874932961
#
# Optimization restart 1/5, f = 558.0126174307271
# Optimization restart 2/5, f = 558.0126085088206
# Optimization restart 3/5, f = 558.0126086689272
# Optimization restart 4/5, f = 558.0126085179616
# Optimization restart 5/5, f = 558.0126085099579
# [[20.   8.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 559.0451359393645
# Optimization restart 2/5, f = 559.045122050004
# Optimization restart 3/5, f = 559.0451220553816
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
# Optimization restart 4/5, f = 559.0451220501598
# Optimization restart 5/5, f = 559.0451220500036
# [[20.         15.69660837  5.         70.          3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3097480384484506
#
# Optimization restart 1/5, f = 560.0613715080707
# Optimization restart 2/5, f = 560.061360667503
# Optimization restart 3/5, f = 635.1311454751499
# Optimization restart 4/5, f = 560.0613606843735
# Optimization restart 5/5, f = 560.0613606679854
# [[20.         13.76139069  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 561.0650449694704
# Optimization restart 2/5, f = 561.0650345435467
# Optimization restart 3/5, f = 561.0650345106724
# Optimization restart 4/5, f = 561.065034510397
# Optimization restart 5/5, f = 561.0650345404708
# [[20.   8.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 562.0745636107471
# Optimization restart 2/5, f = 562.0745504124629
# Optimization restart 3/5, f = 562.0745504127437
# Optimization restart 4/5, f = 562.0745503808454
# Optimization restart 5/5, f = 562.0745503789112
# [[20.         13.64596989  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 563.0639447628805
# Optimization restart 2/5, f = 563.0639342764892
# Optimization restart 3/5, f = 563.0639342734539
# Optimization restart 4/5, f = 563.0639342864602
# Optimization restart 5/5, f = 563.0639351398785
# [[20.   8.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 564.0575349085507
# Optimization restart 2/5, f = 564.0575220309479
# Optimization restart 3/5, f = 564.0575220331764
# Optimization restart 4/5, f = 564.057522362486
# Optimization restart 5/5, f = 564.0575220302121
# [[20.   8.   5.  70.   3.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3110490692485097
#
# Optimization restart 1/5, f = 565.1415859714228
# Optimization restart 2/5, f = 565.1415568829823
# Optimization restart 3/5, f = 565.1415568752843
# Optimization restart 4/5, f = 609.0465338678059
# Optimization restart 5/5, f = 565.1415568761345
# [[20.   8.   5.  70.   3.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3110490692485097
#
# Optimization restart 1/5, f = 566.1856956274937
# Optimization restart 2/5, f = 566.1856744047702
# Optimization restart 3/5, f = 566.1856744032049
# Optimization restart 4/5, f = 566.1856744070994
# Optimization restart 5/5, f = 566.185674405152
# [[20.   8.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 567.1588243411877
# Optimization restart 2/5, f = 567.1588114745786
# Optimization restart 3/5, f = 567.1588114774431
# Optimization restart 4/5, f = 592.8770925413849
# Optimization restart 5/5, f = 567.1588114749933
# [[17.         18.28917685  5.         43.27870743  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.571774737638167
#
# Optimization restart 1/5, f = 568.7556152126117
# Optimization restart 2/5, f = 568.7554957826295
# Optimization restart 3/5, f = 568.7554957864254
# Optimization restart 4/5, f = 568.7554959476389
# Optimization restart 5/5, f = 568.75549578435
# [[20.         12.98748488  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 569.7249027010661
# Optimization restart 2/5, f = 569.7248933270338
# Optimization restart 3/5, f = 569.7248931471923
# Optimization restart 4/5, f = 569.724893177424
# Optimization restart 5/5, f = 569.724893138899
# [[20.         12.91217013  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 570.6871926690828
# Optimization restart 2/5, f = 570.6871830595928
# Optimization restart 3/5, f = 570.6871830621333
# Optimization restart 4/5, f = 570.6871831110388
# Optimization restart 5/5, f = 570.6871830598773
# [[20.   8.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 571.6481321375812
# Optimization restart 2/5, f = 571.6481195375145
# Optimization restart 3/5, f = 571.6481195375023
# Optimization restart 4/5, f = 571.6481195426215
# Optimization restart 5/5, f = 571.648119649907
# [[13.         25.          5.         65.63164776  3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.0082269697093467
#
# Optimization restart 1/5, f = 572.8117410927141
# Optimization restart 2/5, f = 572.811695648232
# Optimization restart 3/5, f = 572.8116956444692
# Optimization restart 4/5, f = 574.5964428148642
# Optimization restart 5/5, f = 572.8116956433282
# [[20.   8.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 573.7635063342257
# Optimization restart 2/5, f = 573.7634939221233
# Optimization restart 3/5, f = 573.7634939215901
# Optimization restart 4/5, f = 573.7634939215664
# Optimization restart 5/5, f = 573.7634939215501

# %%
bo_model_variance = BayesianOptimizationLoop(parameter_space, emukit_model_variance, acquisition=acquisition_model_variance)
bo_model_variance.run_loop(user_function_emissions, n_iter_bo)
# Out:
# Optimization restart 1/5, f = 704.2580691975602
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/paramz/transformations.py:111: RuntimeWarning:overflow encountered in expm1
# Optimization restart 2/5, f = 704.2580692149708
# Optimization restart 3/5, f = 1020.1398153113507
# Optimization restart 4/5, f = 1020.139825969681
# Optimization restart 5/5, f = 704.2580692008632
# [[20.   8.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 706.0455544000944
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/paramz/transformations.py:111: RuntimeWarning:overflow encountered in expm1
# Optimization restart 2/5, f = 697.7844048993775
# Optimization restart 3/5, f = 1012.1949910112664
# Optimization restart 4/5, f = 706.0454584986635
# Optimization restart 5/5, f = 706.0454585054285
# [[15.        25.         5.        63.9449529  1.         1.5      ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.5373330905228264
#
# Optimization restart 1/5, f = 699.4369615641347
# Optimization restart 2/5, f = 707.7901409352478
# Optimization restart 3/5, f = 707.7901409343731
# Optimization restart 4/5, f = 707.7901409409359
# Optimization restart 5/5, f = 707.7901409345912
# [[14.          8.          5.         48.58966385  3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 3.002053057130501
#
# Optimization restart 1/5, f = 702.553155640471
# Optimization restart 2/5, f = 709.5335225296917
# Optimization restart 3/5, f = 709.5335225297098
# Optimization restart 4/5, f = 709.5335225299664
# Optimization restart 5/5, f = 1019.2230772935967
# [[20.         20.57201062  6.92901444 70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3788582814775376
#
# Optimization restart 1/5, f = 703.9111726365161
# Optimization restart 2/5, f = 711.2761600546189
# Optimization restart 3/5, f = 1022.7235051725804
# Optimization restart 4/5, f = 711.2761600553215
# Optimization restart 5/5, f = 703.911140588445
# [[20.          8.          5.         60.67714934  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.741380968052512
#
# Optimization restart 1/5, f = 705.4581226327197
# Optimization restart 2/5, f = 713.0334494046385
# Optimization restart 3/5, f = 713.0334494045692
# Optimization restart 4/5, f = 1026.2253866439148
# Optimization restart 5/5, f = 713.0334494039081
# [[20.         21.89935305  5.         46.71501162  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.234083177960677
#
# Optimization restart 1/5, f = 707.0843926824508
# Optimization restart 2/5, f = 714.7657595125811
# Optimization restart 3/5, f = 707.0834042086307
# Optimization restart 4/5, f = 714.7657595151227
# Optimization restart 5/5, f = 714.7657595181453
# [[15.         25.          5.         58.94442237  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.0985245713612475
#
# Optimization restart 1/5, f = 708.5735492627853
# Optimization restart 2/5, f = 716.4890882151915
# Optimization restart 3/5, f = 708.5735377599921
# Optimization restart 4/5, f = 1033.2335751701842
# Optimization restart 5/5, f = 716.4890878013788
# [[14.         25.          9.94592002 70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.5235389062296076
#
# Optimization restart 1/5, f = 710.3067505865924
# Optimization restart 2/5, f = 1036.7399482216315
# Optimization restart 3/5, f = 1036.7399484135353
# Optimization restart 4/5, f = 718.216315049959
# Optimization restart 5/5, f = 710.3067372128535
# [[15.          9.76625805 27.         66.7683515   3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.9787023138405035
#
# Optimization restart 1/5, f = 712.1097049945229
# Optimization restart 2/5, f = 719.9141025977674
# Optimization restart 3/5, f = 719.9141025396534
# Optimization restart 4/5, f = 719.9141026302358
# Optimization restart 5/5, f = 719.9141025395759
# [[20.          8.         21.87195242 70.          3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.6633084515299914
#
# Optimization restart 1/5, f = 713.6709768908298
# Optimization restart 2/5, f = 721.6433057235696
# Optimization restart 3/5, f = 721.6433057236752
# Optimization restart 4/5, f = 721.6433057233083
# Optimization restart 5/5, f = 721.6433057233166
# [[20.         20.57758855  5.         39.47628673  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.172564238944217
#
# Optimization restart 1/5, f = 715.2711154396925
# Optimization restart 2/5, f = 723.34091955386
# Optimization restart 3/5, f = 1047.2407320598409
# Optimization restart 4/5, f = 1047.2407448498004
# Optimization restart 5/5, f = 723.3409195539323
# [[20.         15.57177772  5.         53.78071448  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.9952403239688474
#
# Optimization restart 1/5, f = 716.6207133233952
# Optimization restart 2/5, f = 725.0224640823542
# Optimization restart 3/5, f = 1050.733199633868
# Optimization restart 4/5, f = 725.0224640825692
# Optimization restart 5/5, f = 725.0224641023456
# [[20.          8.          8.41142595 66.21982326  3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.773323618670392
#
# Optimization restart 1/5, f = 717.9043720276509
# Optimization restart 2/5, f = 726.7171248483627
# Optimization restart 3/5, f = 726.7171248480718
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/stationary.py:168: RuntimeWarning:overflow encountered in true_divide
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:76: RuntimeWarning:invalid value encountered in multiply
# Optimization restart 4/5, f = 727.0256000330071
# Optimization restart 5/5, f = 726.7171248511314
# [[11.         20.87837379  5.         66.12783888  3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.0577883681787865
#
# Optimization restart 1/5, f = 719.3686921144624
# Optimization restart 2/5, f = 728.3829133494852
# Optimization restart 3/5, f = 728.3829133500757
# Optimization restart 4/5, f = 728.3829133494273
# Optimization restart 5/5, f = 728.3829133494319
# [[17.         11.5273381   5.         66.53147305  3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.7449752365362157
#
# Optimization restart 1/5, f = 720.7583410872924
# Optimization restart 2/5, f = 730.0356546535329
# Optimization restart 3/5, f = 730.0356546545788
# Optimization restart 4/5, f = 730.0356546598214
# Optimization restart 5/5, f = 730.0356546537151
# [[17.          8.          8.78063454 70.          3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.6655391500500862
#
# Optimization restart 1/5, f = 721.8312885765588
# Optimization restart 2/5, f = 731.6860741388339
# Optimization restart 3/5, f = 731.6860741433995
# Optimization restart 4/5, f = 731.6860741389667
# Optimization restart 5/5, f = 731.6860741388276
# [[20.        25.         5.        64.4234079  1.         1.5      ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.293051403776933
#
# Optimization restart 1/5, f = 722.77097046772
# Optimization restart 2/5, f = 722.7705132364227
# Optimization restart 3/5, f = 1068.1544351294024
# Optimization restart 4/5, f = 733.3690716746312
# Optimization restart 5/5, f = 733.3690716746312
# [[20.         13.04493109  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 723.7052464408675
# Optimization restart 2/5, f = 735.033166517813
# Optimization restart 3/5, f = 735.0331665178537
# Optimization restart 4/5, f = 1071.6288365845403
# Optimization restart 5/5, f = 735.0331665211872
# [[14.          8.         19.66790809 70.          3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.160078262575988
#
# Optimization restart 1/5, f = 725.1065641657176
# Optimization restart 2/5, f = 725.1062371936551
# Optimization restart 3/5, f = 736.6956582296863
# Optimization restart 4/5, f = 725.1062350059797
# Optimization restart 5/5, f = 725.1062339973018
# [[16.          8.          8.23087372 52.05417469  3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 3.0501269797343165
#
# Optimization restart 1/5, f = 727.1558180396332
# Optimization restart 2/5, f = 738.3227965982915
# Optimization restart 3/5, f = 738.322796598239
# Optimization restart 4/5, f = 738.3227965982339
# Optimization restart 5/5, f = 1078.6066036687555
# [[20.         21.5612408   5.         65.06875271  3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.7366027903144023
#
# Optimization restart 1/5, f = 728.1454911066894
# Optimization restart 2/5, f = 739.9639305216525
# Optimization restart 3/5, f = 739.9639305230746
# Optimization restart 4/5, f = 739.9639305229948
# Optimization restart 5/5, f = 739.9639305217624
# [[20.         12.58981274  8.95241793 70.          1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.095184247333456
#
# Optimization restart 1/5, f = 729.4303225463063
# Optimization restart 2/5, f = 741.631342198327
# Optimization restart 3/5, f = 741.6313421984395
# Optimization restart 4/5, f = 1085.557332450433
# Optimization restart 5/5, f = 729.4288137209428
# [[20.          8.         20.93767448 61.70824065  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.8032202761986964
#
# Optimization restart 1/5, f = 730.8107402380359
# Optimization restart 2/5, f = 743.3127376910272
# Optimization restart 3/5, f = 743.3127376921253
# Optimization restart 4/5, f = 743.3127377230305
# Optimization restart 5/5, f = 743.312737690893
# [[20.         12.64259573  5.         63.08736601  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3497887372607185
#
# Optimization restart 1/5, f = 731.8356782759413
# Optimization restart 2/5, f = 744.9402926764474
# Optimization restart 3/5, f = 744.9402926765551
# Optimization restart 4/5, f = 731.835318242527
# Optimization restart 5/5, f = 731.8353196751746
# [[14.          8.          5.         52.69894026  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.1216298649585164
#
# Optimization restart 1/5, f = 733.1029258439721
# Optimization restart 2/5, f = 1095.9663776961838
# Optimization restart 3/5, f = 746.6741841541564
# Optimization restart 4/5, f = 746.67418396469
# Optimization restart 5/5, f = 733.1027290717608
# [[17.          8.         15.24411309 51.19599557  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.6533108619714
#
# Optimization restart 1/5, f = 734.627918222745
# Optimization restart 2/5, f = 748.3166822353454
# Optimization restart 3/5, f = 748.3166822400193
# Optimization restart 4/5, f = 748.3166822353589
# Optimization restart 5/5, f = 1099.4447649539002
# [[20.          8.         23.54296904 58.63194323  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.313701505544227
#
# Optimization restart 1/5, f = 735.8338676695113
# Optimization restart 2/5, f = 749.9432758134434
# Optimization restart 3/5, f = 749.9432758129537
# Optimization restart 4/5, f = 749.9432758129317
# Optimization restart 5/5, f = 749.9432758144885
# [[17.         21.02707117  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.2752886388389268
#
# Optimization restart 1/5, f = 736.7851764814684
# Optimization restart 2/5, f = 751.5403985593337
# Optimization restart 3/5, f = 751.5403985577648
# Optimization restart 4/5, f = 751.5403985575979
# Optimization restart 5/5, f = 1106.3744515505912
# [[16.   8.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4751052350336686
#
# Optimization restart 1/5, f = 737.5844096807175
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
# Optimization restart 2/5, f = 753.1561933270957
# Optimization restart 3/5, f = 753.156193327123
# Optimization restart 4/5, f = 1109.832669170393
# Optimization restart 5/5, f = 753.156193327932
# [[19.         17.41576652  5.1665547  65.10916317  1.          2.5489973 ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.5856210337219705
#
# Optimization restart 1/5, f = 737.9734879606973
# Optimization restart 2/5, f = 737.9726810868046
# Optimization restart 3/5, f = 754.7135401407279
# Optimization restart 4/5, f = 737.972681799411
# Optimization restart 5/5, f = 754.7135401444027
# [[20.          8.         17.12772901 70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.5618519313986508
#
# Optimization restart 1/5, f = 738.9466294593451
# Optimization restart 2/5, f = 756.3397421210467
# Optimization restart 3/5, f = 756.3397423135852
# Optimization restart 4/5, f = 1116.746076411053
# Optimization restart 5/5, f = 756.339742121078
# [[15.          8.         11.89985716 58.97397561  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.278224727191526
#
# Optimization restart 1/5, f = 740.0282840129273
# Optimization restart 2/5, f = 757.916595788608
# Optimization restart 3/5, f = 757.916595785998
# Optimization restart 4/5, f = 740.02828264903
# Optimization restart 5/5, f = 757.9165957859863
# [[14.         18.00890695  5.         58.90642587  3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.5222163065734895
#
# Optimization restart 1/5, f = 741.370298610688
# Optimization restart 2/5, f = 759.5146945255062
# Optimization restart 3/5, f = 741.3700558178937
# Optimization restart 4/5, f = 741.3700551075301
# Optimization restart 5/5, f = 759.5146945220469
# [[11.       21.607215  5.       70.        1.        1.5     ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.85749836253014
#
# Optimization restart 1/5, f = 742.2279247224452
# Optimization restart 2/5, f = 742.2278650386411
# Optimization restart 3/5, f = 1127.1282249017545
# Optimization restart 4/5, f = 761.0985193401377
# Optimization restart 5/5, f = 761.0985193400124
# [[20.        22.5040327  5.        70.         3.         1.5      ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3111349350393235
#
# Optimization restart 1/5, f = 742.6208799621807
# Optimization restart 2/5, f = 1130.575213790715
# Optimization restart 3/5, f = 762.7023940436629
# Optimization restart 4/5, f = 1130.5752137898653
# Optimization restart 5/5, f = 742.6208755244418
# [[20.         14.18595013  5.         62.11841938  3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.5099878723198932
#
# Optimization restart 1/5, f = 743.2020001679635
# Optimization restart 2/5, f = 1134.0223617565994
# Optimization restart 3/5, f = 764.2637728132767
# Optimization restart 4/5, f = 1134.0223745398648
# Optimization restart 5/5, f = 764.2637728130321
# [[20.         20.95506188  5.         59.43703589  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4682556380007241
#
# Optimization restart 1/5, f = 744.0816795703126
# Optimization restart 2/5, f = 744.0806499525775
# Optimization restart 3/5, f = 765.8158991214643
# Optimization restart 4/5, f = 765.8158988555481
# Optimization restart 5/5, f = 1143.9741407783542
# [[20.          8.          5.         65.90097324  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.2662467908738402
#
# Optimization restart 1/5, f = 744.3867178231978
# Optimization restart 2/5, f = 744.3864314828336
# Optimization restart 3/5, f = 744.3864307720189
# Optimization restart 4/5, f = 767.3772460247839
# Optimization restart 5/5, f = 767.3772460248776
# [[13.         21.94772465 25.40763653 51.41822878  3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 6.650653391826006
#
# Optimization restart 1/5, f = 751.1564731997349
# Optimization restart 2/5, f = 1144.4885964046805
# Optimization restart 3/5, f = 769.0873466128455
# Optimization restart 4/5, f = 769.0873466211772
# Optimization restart 5/5, f = 769.0873466128767
# [[16.         20.93288624  5.         36.04997363  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 3.9206126079961443
#
# Optimization restart 1/5, f = 753.1305937742629
# Optimization restart 2/5, f = 771.0763759827914
# Optimization restart 3/5, f = 1147.9726441927417
# Optimization restart 4/5, f = 1147.9726612466943
# Optimization restart 5/5, f = 771.0763767177432
# [[15.         18.49594881  5.         53.69525483  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.9554943131370484
#
# Optimization restart 1/5, f = 754.2649799987075
# Optimization restart 2/5, f = 772.6238321221493
# Optimization restart 3/5, f = 1151.4174325922083
# Optimization restart 4/5, f = 772.6238321222163
# Optimization restart 5/5, f = 1151.4174198051696
# [[20.          8.         27.         48.40280541  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.4147919191412828
#
# Optimization restart 1/5, f = 755.8781174173671
# Optimization restart 2/5, f = 1154.8672667022297
# Optimization restart 3/5, f = 1163.2069349221997
# Optimization restart 4/5, f = 774.39311386268
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/stationary.py:168: RuntimeWarning:overflow encountered in true_divide
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:76: RuntimeWarning:invalid value encountered in multiply
# Optimization restart 5/5, f = 848.8206482677639
# [[15.         11.03323153 27.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.535059092284798
#
# Optimization restart 1/5, f = 757.2968165423795
# Optimization restart 2/5, f = 776.0476104246975
# Optimization restart 3/5, f = 776.0476104245258
# Optimization restart 4/5, f = 776.0476104271127
# Optimization restart 5/5, f = 776.0476104255022
# [[20.         25.          8.93144389 61.01906608  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.202446496642129
#
# Optimization restart 1/5, f = 758.4580934432956
# Optimization restart 2/5, f = 1161.7611303808035
# Optimization restart 3/5, f = 777.6024052092224
# Optimization restart 4/5, f = 777.6024052172219
# Optimization restart 5/5, f = 777.6024052239918
# [[15.         13.51291287  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3779606540631277
#
# Optimization restart 1/5, f = 759.1371752046261
# Optimization restart 2/5, f = 1165.1933590857784
# Optimization restart 3/5, f = 1165.1933505572156
# Optimization restart 4/5, f = 1165.1933462941472
# Optimization restart 5/5, f = 779.1310133482712
# [[16.          8.         18.40747381 53.77240382  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.9158320946221536
#
# Optimization restart 1/5, f = 760.449746873501
# Optimization restart 2/5, f = 760.4497336379557
# Optimization restart 3/5, f = 780.6637687509814
# Optimization restart 4/5, f = 780.6637687864393
# Optimization restart 5/5, f = 780.6637687511154
# [[17.         15.12514045  7.52963765 70.          3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.5808017181142795
#
# Optimization restart 1/5, f = 760.8869135559157
# Optimization restart 2/5, f = 782.1937652549068
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
# Optimization restart 3/5, f = 782.1937652511127
# Optimization restart 4/5, f = 782.1937652708826
# Optimization restart 5/5, f = 782.193765250667
# [[11.          8.         23.53602105 36.64320813  3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 6.024265073218446
#
# Optimization restart 1/5, f = 764.2590115444166
# Optimization restart 2/5, f = 784.2853530878951
# Optimization restart 3/5, f = 784.2853530826945
# Optimization restart 4/5, f = 764.2590101658581
# Optimization restart 5/5, f = 784.2853530724637
# [[20.          8.         21.00485706 66.64699075  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.9684076752403847
#
# Optimization restart 1/5, f = 765.1944968733742
# Optimization restart 2/5, f = 785.8376993248412
# Optimization restart 3/5, f = 785.8376993259001
# Optimization restart 4/5, f = 785.8376993225227
# Optimization restart 5/5, f = 765.1943859615421
# [[16.         25.          5.         51.35593134  3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.9559825543540574
#
# Optimization restart 1/5, f = 766.5116486290344
# Optimization restart 2/5, f = 787.4323524213231
# Optimization restart 3/5, f = 787.4323524285238
# Optimization restart 4/5, f = 787.4323524213032
# Optimization restart 5/5, f = 787.4323524213547

# %%
bo_integrated_variance = BayesianOptimizationLoop(parameter_space, emukit_model_integrated_variance, acquisition=acquisition_integrated_variance)
bo_integrated_variance.run_loop(user_function_emissions, n_iter_bo)
# Out:
# Optimization restart 1/5, f = 667.0617016290553
# Optimization restart 2/5, f = 667.0617016446129
# Optimization restart 3/5, f = 667.0617016292816
# Optimization restart 4/5, f = 667.0617016290481
# Optimization restart 5/5, f = 667.0617016307854
# [[20.  25.   5.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 669.3486546094341
# Optimization restart 2/5, f = 669.3486339656895
# Optimization restart 3/5, f = 669.3486339657986
# Optimization restart 4/5, f = 669.3486339660918
# Optimization restart 5/5, f = 669.3486339655851
# [[20.         18.28660697  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 671.1591233473321
# Optimization restart 2/5, f = 671.1590924742927
# Optimization restart 3/5, f = 671.1590924758625
# Optimization restart 4/5, f = 671.159092478048
# Optimization restart 5/5, f = 671.1590924753859
# [[16.         23.78901364  5.         70.          3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.6215872976214736
#
# Optimization restart 1/5, f = 673.0271129400409
# Optimization restart 2/5, f = 673.0271129346369
# Optimization restart 3/5, f = 673.0271129288359
# Optimization restart 4/5, f = 673.0271129291187
# Optimization restart 5/5, f = 673.0271129358266
# [[20.  8.  5. 70.  1.  5.]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4793876601068827
#
# Optimization restart 1/5, f = 675.0348865725568
# Optimization restart 2/5, f = 675.0348656787669
# Optimization restart 3/5, f = 675.0348656751623
# Optimization restart 4/5, f = 675.0348656753731
# Optimization restart 5/5, f = 675.0348656789563
# [[20.         19.27239098  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 676.7183669135705
# Optimization restart 2/5, f = 676.718353163373
# Optimization restart 3/5, f = 676.7183531640986
# Optimization restart 4/5, f = 676.7183531608721
# Optimization restart 5/5, f = 676.7183531602245
# [[14.  8. 27. 70.  3.  5.]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.595244649368679
#
# Optimization restart 1/5, f = 678.8353188272627
# Optimization restart 2/5, f = 678.8351815907338
# Optimization restart 3/5, f = 678.8351815915416
# Optimization restart 4/5, f = 678.8351815912204
# Optimization restart 5/5, f = 678.8351815906782
# [[15.         21.24201582  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3779606540631277
#
# Optimization restart 1/5, f = 680.5559422242768
# Optimization restart 2/5, f = 680.5559359736868
# Optimization restart 3/5, f = 680.5559359739532
# Optimization restart 4/5, f = 680.5559359887018
# Optimization restart 5/5, f = 680.555935973375
# [[20.          8.          5.         57.18557097  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.849948392775467
#
# Optimization restart 1/5, f = 682.5782024820455
# Optimization restart 2/5, f = 682.5776952151078
# Optimization restart 3/5, f = 682.57769577802
# Optimization restart 4/5, f = 682.5776952151906
# Optimization restart 5/5, f = 682.5776952150932
# [[20.         19.48542223  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 684.201010895272
# Optimization restart 2/5, f = 684.2010008769183
# Optimization restart 3/5, f = 684.201000876918
# Optimization restart 4/5, f = 684.2010008769172
# Optimization restart 5/5, f = 684.2010008778742
# [[20.          8.         11.94370977 57.68102103  3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.587996019987925
#
# Optimization restart 1/5, f = 686.0563250799554
# Optimization restart 2/5, f = 686.056322669185
# Optimization restart 3/5, f = 686.0563226600598
# Optimization restart 4/5, f = 686.0563226600738
# Optimization restart 5/5, f = 686.0563226602044
# [[20.         19.05663635  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 687.6557352150169
# Optimization restart 2/5, f = 687.6557253293331
# Optimization restart 3/5, f = 687.6557253324773
# Optimization restart 4/5, f = 687.6557253292636
# Optimization restart 5/5, f = 687.6557253291969
# [[20.        17.3170695  5.        70.         1.         5.       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4793876601068827
#
# Optimization restart 1/5, f = 689.3600101516222
# Optimization restart 2/5, f = 689.3599928746739
# Optimization restart 3/5, f = 689.3599928799484
# Optimization restart 4/5, f = 748.7223181644476
# Optimization restart 5/5, f = 689.359992874926
# [[15.   8.  27.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.7509200895541503
#
# Optimization restart 1/5, f = 691.2421747036603
# Optimization restart 2/5, f = 691.2421743343878
# Optimization restart 3/5, f = 691.2421743334663
# Optimization restart 4/5, f = 691.2421743394996
# Optimization restart 5/5, f = 691.242174333493
# [[20.         16.12833543  5.         70.          1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4793876601068827
#
# Optimization restart 1/5, f = 692.8728053710629
# Optimization restart 2/5, f = 692.8727959188344
# Optimization restart 3/5, f = 692.8727959159912
# Optimization restart 4/5, f = 692.8727959161852
# Optimization restart 5/5, f = 751.1187077068025
# [[20.         16.06147079  5.         70.          3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.61918025425326
#
# Optimization restart 1/5, f = 694.5046103842874
# Optimization restart 2/5, f = 694.5045975091689
# Optimization restart 3/5, f = 694.5045975070943
# Optimization restart 4/5, f = 694.504597508327
# Optimization restart 5/5, f = 694.5045975070966
# [[20.         19.97117913  5.         70.          3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3147560797292257
#
# Optimization restart 1/5, f = 696.1192704797088
# Optimization restart 2/5, f = 696.1192581155447
# Optimization restart 3/5, f = 696.1192581155271
# Optimization restart 4/5, f = 696.1192581154795
# Optimization restart 5/5, f = 696.1192581154669
# [[20.         25.          5.         65.75479773  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.5608080057367923
#
# Optimization restart 1/5, f = 698.0215878435936
# Optimization restart 2/5, f = 698.0215876314181
# Optimization restart 3/5, f = 698.0215876313962
# Optimization restart 4/5, f = 698.0215876344184
# Optimization restart 5/5, f = 698.0215876314106
# [[15.   8.  27.  70.   1.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.7509200895541503
#
# Optimization restart 1/5, f = 699.7212789722619
# Optimization restart 2/5, f = 699.7212753364004
# Optimization restart 3/5, f = 699.721275717015
# Optimization restart 4/5, f = 699.7212753421416
# Optimization restart 5/5, f = 699.721275338935
# [[20.         21.77211924  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 701.2858737683455
# Optimization restart 2/5, f = 701.285868296491
# Optimization restart 3/5, f = 701.28586830491
# Optimization restart 4/5, f = 701.2858682964068
# Optimization restart 5/5, f = 701.2858683000754
# [[20.         21.03565926  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 702.828215482946
# Optimization restart 2/5, f = 702.828208910629
# Optimization restart 3/5, f = 702.8282088648889
# Optimization restart 4/5, f = 702.8282088651506
# Optimization restart 5/5, f = 702.8282088647895
# [[20.  25.   5.  70.   3.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3111349350393235
#
# Optimization restart 1/5, f = 704.5375140635272
# Optimization restart 2/5, f = 704.5375018433879
# Optimization restart 3/5, f = 704.5375018431932
# Optimization restart 4/5, f = 704.5375018431836
# Optimization restart 5/5, f = 704.537501855163
# [[20.         21.05247065  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 706.0649961444968
# Optimization restart 2/5, f = 706.0649890915467
# Optimization restart 3/5, f = 706.0649891849336
# Optimization restart 4/5, f = 730.569200552123
# Optimization restart 5/5, f = 706.0649891276082
# [[20.         17.12776002  5.         70.          1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4793876601068827
#
# Optimization restart 1/5, f = 707.6322708362559
# Optimization restart 2/5, f = 707.6322632750775
# Optimization restart 3/5, f = 707.6322632723152
# Optimization restart 4/5, f = 707.6322632725369
# Optimization restart 5/5, f = 707.6322632719681
# [[20.         21.74942712  5.         67.45836634  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.2524645946046598
#
# Optimization restart 1/5, f = 709.2083674444754
# Optimization restart 2/5, f = 709.2083671168473
# Optimization restart 3/5, f = 709.20836709197
# Optimization restart 4/5, f = 709.2083670984085
# Optimization restart 5/5, f = 709.208367091805
# [[16.         17.72989062  5.         70.          1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.8204208533966504
#
# Optimization restart 1/5, f = 710.8422448847285
# Optimization restart 2/5, f = 729.6698046586044
# Optimization restart 3/5, f = 710.8422443783184
# Optimization restart 4/5, f = 710.8422443780089
# Optimization restart 5/5, f = 710.8422443774928
# [[20.         21.01115246  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 712.3479482263573
# Optimization restart 2/5, f = 712.3479412865986
# Optimization restart 3/5, f = 712.3479412881607
# Optimization restart 4/5, f = 712.3479412874161
# Optimization restart 5/5, f = 712.3479412868938
# [[20.  8.  5. 70.  1.  5.]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4793876601068827
#
# Optimization restart 1/5, f = 714.0352243148151
# Optimization restart 2/5, f = 714.0352193047054
# Optimization restart 3/5, f = 714.0352193040633
# Optimization restart 4/5, f = 714.0352193043125
# Optimization restart 5/5, f = 713.6384884116023
# [[17.         12.60156803  5.         34.80806426  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 3.1440566157611474
#
# Optimization restart 1/5, f = 716.2676257064383
# Optimization restart 2/5, f = 715.7665764305762
# Optimization restart 3/5, f = 716.2676344013448
# Optimization restart 4/5, f = 715.7665764305891
# Optimization restart 5/5, f = 715.7665764378272
# [[20.  8.  5. 70.  3.  5.]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.623685122334808
#
# Optimization restart 1/5, f = 717.4415710299781
# Optimization restart 2/5, f = 717.4415553931964
# Optimization restart 3/5, f = 717.4415553766264
# Optimization restart 4/5, f = 717.4415553768225
# Optimization restart 5/5, f = 717.441555378114
# [[20.         25.          5.         65.56734603  3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4025115800038706
#
# Optimization restart 1/5, f = 719.1251195455088
# Optimization restart 2/5, f = 719.1251155960952
# Optimization restart 3/5, f = 719.1251155923337
# Optimization restart 4/5, f = 719.1251192832954
# Optimization restart 5/5, f = 719.1251156263332
# [[20.         20.94948762  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 720.6131665940441
# Optimization restart 2/5, f = 720.6131600639999
# Optimization restart 3/5, f = 720.6131600649908
# Optimization restart 4/5, f = 720.6131600895087
# Optimization restart 5/5, f = 720.6131600734191
# [[20.         20.89724384  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 722.0945472963417
# Optimization restart 2/5, f = 722.0945408490686
# Optimization restart 3/5, f = 722.094540855697
# Optimization restart 4/5, f = 722.0945408676873
# Optimization restart 5/5, f = 722.0945408490719
# [[20.         20.86250859  5.         70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.19946831512822
#
# Optimization restart 1/5, f = 723.5697979857306
# Optimization restart 2/5, f = 723.5697914585787
# Optimization restart 3/5, f = 693.8756023896403
# Optimization restart 4/5, f = 693.8755948078384
# Optimization restart 5/5, f = 723.5697914661359
# [[13.          8.         16.18450306 62.92461138  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.821552027222437
#
# Optimization restart 1/5, f = 697.051401617983
# Optimization restart 2/5, f = 725.176126000779
# Optimization restart 3/5, f = 725.1761260008293
# Optimization restart 4/5, f = 725.176126816902
# Optimization restart 5/5, f = 725.1761260010069
# [[20.         25.          9.89048869 49.1615541   1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 3.1587226527122594
#
# Optimization restart 1/5, f = 699.7889688407199
# Optimization restart 2/5, f = 727.0600572089163
# Optimization restart 3/5, f = 727.0600572125421
# Optimization restart 4/5, f = 727.0600572099809
# Optimization restart 5/5, f = 727.060057214587
# [[11.          8.         27.         62.67062476  3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.883517830650568
#
# Optimization restart 1/5, f = 702.3536475466631
# Optimization restart 2/5, f = 702.3529183801697
# Optimization restart 3/5, f = 702.3529276330778
# Optimization restart 4/5, f = 728.7482257588254
# Optimization restart 5/5, f = 728.7482257682376
# [[20.          8.          5.         62.67210044  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.3508900280310105
#
# Optimization restart 1/5, f = 704.7803825637482
# Optimization restart 2/5, f = 730.6849358344389
# Optimization restart 3/5, f = 730.68493583556
# Optimization restart 4/5, f = 730.6849358334534
# Optimization restart 5/5, f = 704.780090979414
# [[20.         16.10404883  5.         58.43422711  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4847144211996919
#
# Optimization restart 1/5, f = 707.2178034231815
# Optimization restart 2/5, f = 732.4075668331931
# Optimization restart 3/5, f = 732.4075668326373
# Optimization restart 4/5, f = 732.4075668702678
# Optimization restart 5/5, f = 732.4075668441158
# [[13.   8.   5.  70.   3.   1.5]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.8259038951974815
#
# Optimization restart 1/5, f = 709.6720981933329
# Optimization restart 2/5, f = 734.4024021504349
# Optimization restart 3/5, f = 734.402402135901
# Optimization restart 4/5, f = 734.4024021365099
# Optimization restart 5/5, f = 734.4024021359015
# [[20.         25.          5.         58.10949147  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.4788642585419611
#
# Optimization restart 1/5, f = 711.9186195728845
# Optimization restart 2/5, f = 736.1226842844696
# Optimization restart 3/5, f = 736.1226843129831
# Optimization restart 4/5, f = 736.1226842851049
# Optimization restart 5/5, f = 736.1226842842273
# [[12.          8.         11.64551212 70.          1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.763060180414128
#
# Optimization restart 1/5, f = 714.3862800366626
# Optimization restart 2/5, f = 737.8186261274781
# Optimization restart 3/5, f = 737.8186261231558
# Optimization restart 4/5, f = 737.8186261237732
# Optimization restart 5/5, f = 737.8186261233866
# [[17.          8.          5.         61.60134176  3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.8736294636939494
#
# Optimization restart 1/5, f = 716.4126471670038
# Optimization restart 2/5, f = 739.494113406792
# Optimization restart 3/5, f = 739.4941134065498
# Optimization restart 4/5, f = 739.4941134085262
# Optimization restart 5/5, f = 739.4941134437049
# [[20.          8.         21.35153419 44.24388537  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.852477618842882
#
# Optimization restart 1/5, f = 718.6225267991771
# Optimization restart 2/5, f = 741.1557586451548
# Optimization restart 3/5, f = 741.1557586454207
# Optimization restart 4/5, f = 718.6223353845855
# Optimization restart 5/5, f = 741.1557586448256
# [[ 8.         20.42216809  5.         70.          3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 3.1247875137985814
#
# Optimization restart 1/5, f = 721.0980023588701
# Optimization restart 2/5, f = 742.8867389672071
# Optimization restart 3/5, f = 742.8867389672263
# Optimization restart 4/5, f = 742.8867389671584
# Optimization restart 5/5, f = 742.8867389719129
# [[14.          8.          5.         55.38013224  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.97520744292352
#
# Optimization restart 1/5, f = 723.4253151205301
# Optimization restart 2/5, f = 744.8277482945778
# Optimization restart 3/5, f = 744.8277483999657
# Optimization restart 4/5, f = 723.4253213965546
# Optimization restart 5/5, f = 723.4253160482334
# [[20.          8.         27.         64.54504372  1.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 2.016577962228522
#
# Optimization restart 1/5, f = 725.8008490418163
# Optimization restart 2/5, f = 746.7416076361076
# Optimization restart 3/5, f = 746.7416085179976
# Optimization restart 4/5, f = 746.7416076361383
# Optimization restart 5/5, f = 746.7416076361743
# [[20.         25.         18.34282693 39.290572    3.          5.        ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 8.987218480197562
#
# Optimization restart 1/5, f = 732.2647661917721
# Optimization restart 2/5, f = 748.4215319161785
# Optimization restart 3/5, f = 748.4215319149441
# Optimization restart 4/5, f = 748.4215319148293
# Optimization restart 5/5, f = 748.4215319155485
# [[20.          8.         21.00041246 70.          1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.5618519313986508
#
# Optimization restart 1/5, f = 734.5801595619547
# Optimization restart 2/5, f = 750.2176600420815
# Optimization restart 3/5, f = 734.580158080752
# Optimization restart 4/5, f = 750.2176600416508
# Optimization restart 5/5, f = 750.2176600416462
# [[12.          8.         27.         46.42105577  3.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 4.729419662744031
#
# Optimization restart 1/5, f = 737.1117038105531
# Optimization restart 2/5, f = 751.8630799416053
# Optimization restart 3/5, f = 751.8630797112207
# Optimization restart 4/5, f = 751.8630797111683
# Optimization restart 5/5, f = 751.863079711685
# [[14.         17.03801103  5.         62.83891423  1.          1.5       ]]
#
# User function emissions called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
#
# Output 1.800170133977824
#
# Optimization restart 1/5, f = 739.0871814640202
# Optimization restart 2/5, f = 753.4115453825812
# Optimization restart 3/5, f = 753.4115453803221
# Optimization restart 4/5, f = 753.4115453790286
# Optimization restart 5/5, f = 739.0862455885248

# %% [markdown]
# ## Results

# %%
parameters_name = ['Size of the grid', 'Speed limit in the net (m/s)', 'Max vehicles speed (m/s)', 'Length of the roads (m)', 'Number of lanes', 'Accelleration (m/s^2)']

# %% [markdown]
# ### Results on the random initialised emulator

# %%
results_random_init = bo_random_init.get_results()

# %%
results_random_init_df = pd.DataFrame(results_random_init.minimum_location.reshape(1,-1))
results_random_init_df.columns = parameters_name
results_random_init_df
# Out:
#    Size of the grid  Speed limit in the net (m/s)  Max vehicles speed (m/s)  \
# 0              20.0                     15.244704                       5.0
#
#    Length of the roads (m)  Number of lanes  Accelleration (m/s^2)
# 0                     70.0              1.0                    1.5

# %%
results_random_init.minimum_value
# Out:
# 1.19946831512822

# %% [markdown]
# ### Results on the experimentally designed emulator with model variance

# %%
results_model_variance = bo_model_variance.get_results()

# %%
results_random_init_df = pd.DataFrame(results_model_variance.minimum_location.reshape(1,-1))
results_random_init_df.columns = parameters_name
results_random_init_df
# Out:
#    Size of the grid  Speed limit in the net (m/s)  Max vehicles speed (m/s)  \
# 0              20.0                           8.0                       5.0
#
#    Length of the roads (m)  Number of lanes  Accelleration (m/s^2)
# 0                     70.0              1.0                    1.5

# %%
results_model_variance.minimum_value
# Out:
# 1.19946831512822

# %% [markdown]
# ### Results on the experimentally designed emulator with integrated variance reduction

# %%
results_integrated_variance = bo_integrated_variance.get_results()

# %%
results_random_init_df = pd.DataFrame(results_integrated_variance.minimum_location.reshape(1,-1))
results_random_init_df.columns = parameters_name
results_random_init_df
# Out:
#    Size of the grid  Speed limit in the net (m/s)  Max vehicles speed (m/s)  \
# 0              20.0                          25.0                       5.0
#
#    Length of the roads (m)  Number of lanes  Accelleration (m/s^2)
# 0                     70.0              1.0                    1.5

# %%
results_integrated_variance.minimum_value
# Out:
# 1.19946831512822

# %% [markdown]
# ## Save stuff

# %%
with open(f'bayesian_optimization_new_outputs/bayesian_opt_results/results_random_init_emissions.pkl', "wb") as f:
     pickle.dump(results_random_init, f)

with open(f'bayesian_optimization_new_outputs/bayesian_opt_results/results_model_variance_emissions.pkl', "wb") as f:
     pickle.dump(results_model_variance, f)
        
with open(f'bayesian_optimization_new_outputs/bayesian_opt_results/results_integrated_variance_emissions.pkl', "wb") as f:
     pickle.dump(results_integrated_variance, f)

# %%
with open(f'bayesian_optimization_new_outputs/models/270_random_init_50_bay_opt_emissions.pkl', "wb") as f:
     pickle.dump(emukit_model_random_init, f)

with open(f'bayesian_optimization_new_outputs/models/270_model_variance_50_bay_emissions.pkl', "wb") as f:
     pickle.dump(emukit_model_variance, f)
        
with open(f'bayesian_optimization_new_outputs/models/270_integrated_variance_50_bay_emissions.pkl', "wb") as f:
     pickle.dump(emukit_model_integrated_variance, f)

# %%
# %cd ../
# Out:
# /Users/harrysonghurst/Documents/Coursework/L48 Machine Learning and the Physical World/TrafficEmu

# %%
# If you get a SciPy error when installing Emukit, build it from source:

# git clone https://github.com/amzn/Emukit.git
# cd Emukit
# pip install -r requirements/requirements.txt
# python setup.py develop

# %%
import numpy as np
import pickle
import emukit as ek
import GPy

from emukit.model_wrappers import GPyModelWrapper
from emukit.experimental_design.experimental_design_loop import ExperimentalDesignLoop
from emukit.core import ParameterSpace, ContinuousParameter, DiscreteParameter
from emukit.core.initial_designs import RandomDesign, latin_design
from emukit.experimental_design.acquisitions import ModelVariance, IntegratedVarianceReduction
from emukit.core.loop import UserFunctionWrapper
from emukit.bayesian_optimization.acquisitions import ExpectedImprovement
from emukit.bayesian_optimization.loops import BayesianOptimizationLoop

from sumo_grid_simulation.grid_simulation import Simulator

# %% [markdown]
# ### Pseudocode
#
# Fitting a gaussian process to a simulator using Emukit takes the following form (taken from L48 lectures):
#
# ```
# initialize GP with some randomly chosen points
# while stopping condition is not met:
#     compute candidate point(s) using GP and acquisition funciton (model_variance) -> new point
#     evaluate this new point with our simulator/user function -> observation
#     update model with new observation -> new GP
# ```

# %% [markdown]
# ### Simulator

# %%
# trips_generator_period = 10 else simulation is v. slow
simulator = Simulator(trips_generator_period=10)

# %% [markdown]
# ### User Function
#
# This is the function we want to understand. Namedly, how are CO2 emissions and timeLoss (the time lost due to driving below the ideal speed) affected by the following parameters:
#
# ```
# edgeMaxSpeed: legal speed limit in m/s - this can be exceeded (11.11 == 40km/h)
# maxSpeed: the absolute maximum velocity of any vehicle in m/s (55.55 == 200 km/h)
# edgeLength: length of the roads between intersections in meters
# numLanes: number of lanes per road
# accel: The acceleration ability of vehicles in m/s^2.
# ```
#
# *A complete list of parmeters analysed is discussed in our report.*

# %%
def user_function_time_loss(X):
    """  X = inputs - emukit doesnt pass named args, just an NxM ndarray """
    result = []
    print(X)
    
    for gridSize, edgeMaxSpeed, maxSpeed, edgeLength, numLanes, accel in X:
        s = simulator.simulate(
            gridSize      = int(gridSize),
            edgeMaxSpeed  = edgeMaxSpeed,
            maxSpeed      = maxSpeed,
            edgeLength    = int(edgeLength),
            numberOfLanes = int(numLanes),
            accel         = accel
        )
        # average time loss / average route length
        result.append(s['timeLoss']/s['routeLength'])
        
    # expand dims is essential or the acquition function breaks
    return np.expand_dims(np.array(result), 1)

# %% [markdown]
# ### Model (GP)

# %% [markdown]
# Our surrogate model is our emulator. In this case, a gaussian process. I think that emukit handles categorical/discrete inputs using one-hot encodings.

# %% [markdown]
# #### Model Inputs

# %%
gridSize = ContinuousParameter('gridSize', min_value=3, max_value=20)
edgeMaxSpeed = ContinuousParameter('edgeMaxSpeed', min_value=1, max_value=25)
maxSpeed = ContinuousParameter('maxSpeed', min_value=1, max_value=25)
edgeLength = ContinuousParameter('edgeLength', min_value=2, max_value=200)
numberOfLanes = DiscreteParameter('numberOfLanes', domain=[1,2,3])
accel = ContinuousParameter('accel', 1., 6.)

parameter_space = ParameterSpace([gridSize, edgeMaxSpeed, maxSpeed, edgeLength, numberOfLanes, accel])

# %% [markdown]
# #### Initialize Model / Emulator (GP)

# %%
design = RandomDesign(parameter_space)  # initialize with random points
num_data_points = 250
init_X = design.get_samples(num_data_points)
init_Y = user_function_time_loss(init_X)
# Out:
# [[ 10.33587602  11.01652992  13.58950958  19.27808634   1.
#     1.44777348]
#  [ 16.62791691  14.40574552   6.96809843  48.78288255   3.
#     3.25599695]
#  [  6.47560114   8.21401892  15.91831698  15.05012724   1.
#     5.87045671]
#  ...
#  [  8.06979113  19.58746025  13.58715076  56.46764741   2.
#     3.97766899]
#  [  3.05518417  21.72042646   4.32578951  17.34817092   3.
#     2.50860644]
#  [ 18.71083031  11.78438375   4.16261765 134.54223062   1.
#     5.14045339]]
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Warning: Intersecting left turns at junction 'n1' from lane 'o1ton1_1' and lane 'n4ton1_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n1' from lane 'o32ton1_1' and lane 'n2ton1_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'o4ton10_1' and lane 'n11ton10_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n16' from lane 'n9ton16_1' and lane 'n25ton16_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n16' from lane 'o29ton16_1' and lane 'n15ton16_1' (increase junction radius to avoid this).
# Warning: 50 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Warning: Intersecting left turns at junction 'n1' from lane 'o24ton1_0' and lane 'n2ton1_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n11' from lane 'n12ton11_0' and lane 'n10ton11_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n11' from lane 'n6ton11_0' and lane 'n18ton11_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n12' from lane 'n13ton12_0' and lane 'n11ton12_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n12' from lane 'n7ton12_0' and lane 'n19ton12_0' (increase junction radius to avoid this).
# Warning: 36 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Warning: Intersecting left turns at junction 'n102' from lane 'n103ton102_2' and lane 'n101ton102_2' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n102' from lane 'n83ton102_2' and lane 'n123ton102_2' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n103' from lane 'n104ton103_2' and lane 'n102ton103_2' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n103' from lane 'n84ton103_2' and lane 'n124ton103_2' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n104' from lane 'n105ton104_2' and lane 'n103ton104_2' (increase junction radius to avoid this).
# Warning: 450 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Warning: Intersecting left turns at junction 'n10' from lane 'o4ton10_1' and lane 'n11ton10_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'n5ton10_1' and lane 'n17ton10_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'n81ton100_1' and lane 'n121ton100_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'o39ton100_1' and lane 'n99ton100_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n101' from lane 'o11ton101_1' and lane 'n102ton101_1' (increase junction radius to avoid this).
# Warning: 280 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Warning: Intersecting left turns at junction 'n11' from lane 'n12ton11_1' and lane 'n10ton11_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n11' from lane 'n6ton11_1' and lane 'n18ton11_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n12' from lane 'n13ton12_1' and lane 'n11ton12_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n12' from lane 'n7ton12_1' and lane 'n19ton12_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n13' from lane 'n22ton13_1' and lane 'n12ton13_1' (increase junction radius to avoid this).
# Warning: 128 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Warning: Intersecting left turns at junction 'n10' from lane 'o4ton10_2' and lane 'n11ton10_2' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'n5ton10_2' and lane 'n17ton10_2' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'n81ton100_2' and lane 'n121ton100_2' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'o67ton100_2' and lane 'n99ton100_2' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n101' from lane 'o11ton101_2' and lane 'n102ton101_2' (increase junction radius to avoid this).
# Warning: 714 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Warning: Intersecting left turns at junction 'n1' from lane 'o48ton1_2' and lane 'n2ton1_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'n5ton10_2' and lane 'n17ton10_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'o39ton100_2' and lane 'n99ton100_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n101' from lane 'n82ton101_2' and lane 'n122ton101_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n121' from lane 'o38ton121_2' and lane 'n120ton121_1' (increase junction radius to avoid this).
# Warning: 28 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Warning: Intersecting left turns at junction 'n1' from lane 'o28ton1_1' and lane 'n2ton1_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n37' from lane 'o7ton37_1' and lane 'n38ton37_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n43' from lane 'o14ton43_1' and lane 'n44ton43_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n49' from lane 'o21ton49_1' and lane 'n36ton49_1' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Warning: Intersecting left turns at junction 'n1' from lane 'o1ton1_0' and lane 'n4ton1_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n1' from lane 'o28ton1_0' and lane 'n2ton1_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'o4ton10_0' and lane 'n11ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'n5ton10_0' and lane 'n17ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n16' from lane 'n9ton16_0' and lane 'n25ton16_0' (increase junction radius to avoid this).
# Warning: 48 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds

# %%
with open('init_points_6_param.pkl', "wb") as f:
     pickle.dump((init_X, init_Y), f)

# %%
# emulator = pickle.load(open('experimental_design_timeLoss_50_iter_batch_size_3.pkl',"rb"))
emulator = GPy.models.GPRegression(init_X, init_Y)
emukit_model = GPyModelWrapper(emulator)
emulator
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 344.3959062703371<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
init_Y
# Out:
# array([[0.01992411],
#        [0.26716679],
#        [0.02106082],
#        [0.02371084],
#        [0.04873735],
#        [0.12322937],
#        [0.0312696 ],
#        [0.13777407],
#        [0.0149418 ],
#        [0.02982264],
#        [0.09335313],
#        [0.0165484 ],
#        [0.0402875 ],
#        [0.04601946],
#        [0.02772038],
#        [0.12785355],
#        [0.10427855],
#        [0.11704698],
#        [0.08456244],
#        [0.02632688],
#        [0.01334843],
#        [0.06278568],
#        [0.09267322],
#        [0.01925865],
#        [0.01294227]])

# %% [markdown]
# ### Optimization

# %% [markdown]
# #### Acquisition Function

# %%
model_variance = ModelVariance(model=emukit_model)

# %% [markdown]
# #### Experimental Design

# %%
ed_loop = ExperimentalDesignLoop(
    model = emukit_model,
    space = parameter_space,
    acquisition = model_variance,
    batch_size = 1
)

# %%
ed_loop.run_loop(user_function_time_loss, 100)
# Out:
# Optimization restart 1/1, f = 235.8962930809298
# [[20.         25.         13.98262421  2.          1.          6.        ]]
# Warning: Intersecting left turns at junction 'n1' from lane 'o80ton1_0' and lane 'n2ton1_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'o4ton10_0' and lane 'n11ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'n5ton10_0' and lane 'n17ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'n81ton100_0' and lane 'n121ton100_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'o71ton100_0' and lane 'n99ton100_0' (increase junction radius to avoid this).
# Warning: 148 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 236.5580789455865
# [[20.         25.          1.         84.61935295  1.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 237.29632097924917
# [[  3.          25.          25.         133.92424182   1.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 237.94609374224393
# [[ 20.           1.           1.         166.60062302   1.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 238.68237384230633
# [[ 3.          1.         25.         91.14256602  3.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 239.4488244800741
# [[  3.          25.           1.         158.03418902   1.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 240.19323651220444
# [[20.         1.        25.        75.5945262  1.         1.       ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 240.91209053484573
# [[20.          1.         14.52506485  2.          1.          1.        ]]
# Warning: Intersecting left turns at junction 'n1' from lane 'o80ton1_0' and lane 'n2ton1_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'o4ton10_0' and lane 'n11ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'n5ton10_0' and lane 'n17ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'n81ton100_0' and lane 'n121ton100_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'o71ton100_0' and lane 'n99ton100_0' (increase junction radius to avoid this).
# Warning: 148 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 241.62331931916947
# [[20.          1.         25.         38.70885294  1.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 242.3373519195775
# [[  3.          11.84765309  25.         129.43680197   3.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 242.96056302260274
# [[  3.           1.          25.         169.10594425   3.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 243.70606528788198
# [[  3.          25.          10.46159922 130.18802974   1.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 244.32285717191152
# [[20.         25.          1.         70.24887472  3.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 245.02666137769572
# [[ 20.          25.           1.         125.11664076   1.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 245.73755921920093
# [[ 3.          1.          1.         72.07586123  1.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 246.50670379312774
# [[20. 25.  1.  2.  1.  6.]]
# Warning: Intersecting left turns at junction 'n1' from lane 'o80ton1_0' and lane 'n2ton1_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'o4ton10_0' and lane 'n11ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'n5ton10_0' and lane 'n17ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'n81ton100_0' and lane 'n121ton100_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'o71ton100_0' and lane 'n99ton100_0' (increase junction radius to avoid this).
# Warning: 148 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 247.3294005671833
# [[ 3.          1.         25.         34.54792735  1.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 248.11713887458973
# [[ 20.           1.           1.         123.79059851   1.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 248.82419834098494
# [[ 20.           1.          25.         156.50907953   3.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 249.520952479828
# [[20.         25.         25.         76.40843883  1.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 250.1243070713366
# [[ 3.         25.          1.         69.70564995  3.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 250.8897577931284
# [[ 3.         17.42592724 25.         86.9207041   3.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 251.4803764927849
# [[ 20.           1.          13.32746127 162.81492105   3.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 252.13779834093677
# [[  3.          25.          25.         118.64531313   1.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 252.73159575368896
# [[  3.          25.           1.         177.98823725   3.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 253.4475850959846
# [[ 20.           1.           1.         141.64707851   3.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 254.13824974991027
# [[20.         12.11341289 25.         79.77567608  1.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 254.71068137081647
# [[  3.          25.           1.         144.09175967   3.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 255.40933510240686
# [[ 3.          1.         19.14983854  2.          3.          1.        ]]
# Warning: Intersecting left turns at junction 'n1' from lane 'o12ton1_2' and lane 'n2ton1_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n4' from lane 'o11ton4_2' and lane 'n3ton4_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n5' from lane 'o3ton5_2' and lane 'n6ton5_2' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n6' from lane 'o5ton6_2' and lane 'n3ton6_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n7' from lane 'o6ton7_2' and lane 'n8ton7_1' (increase junction radius to avoid this).
# Warning: 6 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 378.80170087714555
# [[ 9.91106704  1.          1.         84.4967461   1.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 379.9596500393626
# [[20.          1.         25.         25.31381508  1.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 381.3150278888023
# [[ 3.          1.         12.75419455 39.01969657  3.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 382.4963324996935
# [[20. 25. 25.  2.  1.  1.]]
# Warning: Intersecting left turns at junction 'n1' from lane 'o80ton1_0' and lane 'n2ton1_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'o4ton10_0' and lane 'n11ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'n5ton10_0' and lane 'n17ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'n81ton100_0' and lane 'n121ton100_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'o71ton100_0' and lane 'n99ton100_0' (increase junction radius to avoid this).
# Warning: 148 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 383.7163519059715
# [[ 3.          1.          1.         30.27824654  1.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 384.879428080372
# [[20.          1.         15.38198074 49.33838942  3.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 386.05182632083233
# [[  3.          25.          25.         151.79291065   1.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 387.2140970648919
# [[20.          1.          1.         66.09634104  3.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 388.41756695826825
# [[ 3.         25.          1.         54.39006596  3.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 389.6091421009205
# [[ 3.          1.         25.         58.85989061  1.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 390.8208004910279
# [[20.  1.  1.  2.  1.  1.]]
# Warning: Intersecting left turns at junction 'n1' from lane 'o80ton1_0' and lane 'n2ton1_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'o4ton10_0' and lane 'n11ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'n5ton10_0' and lane 'n17ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'n81ton100_0' and lane 'n121ton100_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'o71ton100_0' and lane 'n99ton100_0' (increase junction radius to avoid this).
# Warning: 148 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 392.0266011727181
# [[ 3.          1.          1.         99.01060439  3.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 393.1950278894819
# [[20.         25.         25.         29.72563741  1.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 394.3739489355225
# [[ 20.  25.   1. 200.   3.   1.]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 395.5871723859725
# [[20.         25.         25.         57.51743377  1.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 396.7047238568334
# [[  3.          25.          14.8277141  141.88055379   3.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 397.80566635162234
# [[20.         11.58530025  1.         91.26838869  1.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 398.87575492064735
# [[  3.          10.48473146  25.         200.           3.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 399.99112982778263
# [[  3.          25.           1.         127.59083076   3.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 401.07497060610893
# [[ 3.         25.         15.62760707  2.          3.          1.        ]]
# Warning: Intersecting left turns at junction 'n1' from lane 'o12ton1_2' and lane 'n2ton1_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n4' from lane 'o11ton4_2' and lane 'n3ton4_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n5' from lane 'o3ton5_2' and lane 'n6ton5_2' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n6' from lane 'o5ton6_2' and lane 'n3ton6_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n7' from lane 'o6ton7_2' and lane 'n8ton7_1' (increase junction radius to avoid this).
# Warning: 6 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 402.20462650160573
# [[ 20.           9.76319048  12.2962557  200.           1.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 403.2446956310411
# [[14.17400102  1.         16.05625586 76.53030042  1.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 404.27808601782556
# [[20.          1.          1.         32.29507458  3.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 405.4408309998927
# [[ 3.          1.         12.84727703 67.09884935  1.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 406.5207232850371
# [[ 3.         11.42394702 25.         45.79355308  1.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 407.5848384040456
# [[ 20.          12.40493979  25.         127.01591206   1.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 408.62688758685175
# [[ 3.         13.23076392  1.         60.0688456   1.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 409.70923884556305
# [[  3.           1.          25.         125.21495571   1.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 410.8528887936785
# [[  3.          12.58031968   1.         154.20985266   1.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 411.9377630967384
# [[ 20.           1.          25.         169.04602389   3.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 413.0172934894117
# [[ 20.          25.          25.         136.44092988   3.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 414.07324073145617
# [[20.          1.         12.76590397 27.05888795  3.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 415.1848853413572
# [[ 20.         25.         25.        166.0488507   1.          1.       ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 416.2652396897753
# [[  3.           1.           1.         126.91894428   1.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 417.36246214353105
# [[  3.           1.          25.         181.91393157   3.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 418.4535910541922
# [[20.         25.         25.         13.58892385  3.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 419.5020378299206
# [[  3.           1.           1.         161.56222424   1.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 420.5298811119786
# [[ 20.          25.           1.         147.10978418   3.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 421.6273388503678
# [[  3.           1.          25.         138.28202914   1.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 422.67933284740513
# [[20.         11.12351832 25.         95.8798516   3.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 423.6624282374549
# [[ 20.           1.          25.         105.71925854   1.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 424.7921506539601
# [[ 20.          25.          12.30779588 123.75253101   1.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 425.7667294770796
# [[20.          1.         15.61731751 64.05954287  3.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 426.7640071939261
# [[20.         25.         14.87185365 85.36317073  1.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 427.78741879127796
# [[20.          7.66946605 25.         48.67329896  1.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 428.79254378339175
# [[ 20.          1.          1.        153.7904689   3.          6.       ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 429.8496138509289
# [[  3.          14.77182944  19.0344475  137.64534279   3.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 430.75465417254316
# [[20.         13.99740633 11.78316547  2.          3.          1.        ]]
# Warning: Intersecting left turns at junction 'n1' from lane 'o80ton1_2' and lane 'n2ton1_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'n5ton10_2' and lane 'n17ton10_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'o71ton100_2' and lane 'n99ton100_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n101' from lane 'n82ton101_2' and lane 'n122ton101_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n121' from lane 'o70ton121_2' and lane 'n120ton121_1' (increase junction radius to avoid this).
# Warning: 44 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 431.74781503966926
# [[  3.          13.54423044  25.         101.36053572   3.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 432.721240138559
# [[  3.          25.           1.         189.57551466   3.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 433.71697816018775
# [[20.         25.          1.         31.07656165  3.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 434.77294137141655
# [[20.          1.          1.         49.16814565  3.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 435.85578796234097
# [[20.         14.52697321  1.         77.42874776  3.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 436.8192365388153
# [[  3.           1.           1.         173.26638153   3.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 437.81522258739494
# [[20.         12.79015551  1.         62.50321814  1.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 438.83015338982943
# [[ 6.60482123  1.         25.         82.19968528  1.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 439.762973271341
# [[20.         11.51790608  1.         27.84226494  3.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 441.56089578612114
# [[ 20.          10.30903217  25.         141.52595875   3.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 442.5140594260472
# [[ 3.        11.5281166 25.         2.         3.         1.       ]]
# Warning: Intersecting left turns at junction 'n1' from lane 'o12ton1_2' and lane 'n2ton1_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n4' from lane 'o11ton4_2' and lane 'n3ton4_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n5' from lane 'o3ton5_2' and lane 'n6ton5_2' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n6' from lane 'o5ton6_2' and lane 'n3ton6_1' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n7' from lane 'o6ton7_2' and lane 'n8ton7_1' (increase junction radius to avoid this).
# Warning: 6 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 450.52520085925994
# [[20.          1.         14.90813872 13.91712204  1.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 451.5761656004735
# [[20.  1. 25.  2.  1.  6.]]
# Warning: Intersecting left turns at junction 'n1' from lane 'o80ton1_0' and lane 'n2ton1_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'o4ton10_0' and lane 'n11ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n10' from lane 'n5ton10_0' and lane 'n17ton10_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'n81ton100_0' and lane 'n121ton100_0' (increase junction radius to avoid this).
# Warning: Intersecting left turns at junction 'n100' from lane 'o71ton100_0' and lane 'n99ton100_0' (increase junction radius to avoid this).
# Warning: 148 total messages of type: Intersecting left turns at junction '%' from lane '%' and lane '%' (increase junction radius to avoid this).
#
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 452.57663659406427
# [[20.          1.         10.11720386 90.76774272  1.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 453.56530639878486
# [[ 20.          12.69558358   1.         121.65815457   3.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 454.5555803009376
# [[  3.          11.98841575   1.         185.01865705   3.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 455.54574589067977
# [[ 3.          1.         25.         19.26332525  1.          6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 457.33302225415787
# [[  3.          25.          25.         104.57905439   3.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 458.30980278305765
# [[20.         12.654065   25.         30.98507989  3.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 459.2984989893376
# [[  3.          14.54103335   1.         137.66033667   1.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 460.26219351614475
# [[20.         11.32095213 16.18485003 82.50123835  3.          1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 461.14888422208423
# [[  3.          25.          12.62116874 157.38944938   3.
#     6.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 462.07891753413764
# [[  3.           1.          18.37843565 100.45955277   1.
#     1.        ]]
#  Retrying in 1 seconds
# Optimization restart 1/1, f = 463.0648608351627

# %% [markdown]
# ### Evaluate

# %% [markdown]
# #### Test on 25 point test set

# %%
design = RandomDesign(parameter_space)  # initialize with random points
num_data_points = 25
test_X = design.get_samples(num_data_points)
test_Y = user_function_time_loss(test_X)
# Out:
# [[ 17.74164414   4.47819712  22.92517542 156.43432953   1.
#     5.18996509]
#  [  8.87903432  19.85880676  20.98060366 168.5313835    1.
#     2.29685529]
#  [  6.07937847  11.60478553  18.63913742 151.53272833   2.
#     2.00224977]
#  [ 14.7036176   24.29256155   5.67293463  93.11649403   2.
#     4.07597088]
#  [  3.06258204  20.00571735  14.09110268 143.32162282   2.
#     3.4045103 ]
#  [ 11.58053279  15.44211809   2.24862032 172.87603896   3.
#     5.41479714]
#  [ 17.27074678   1.15111185  19.16630237  90.85624074   3.
#     4.83750778]
#  [ 14.00199028  17.37110855  24.42397088 176.97111434   1.
#     4.48150837]
#  [  5.41545797  17.0223595    8.58741279  13.98218367   1.
#     4.0218222 ]
#  [  7.61614089   9.81779992   8.25310184  98.16649721   3.
#     5.21924655]
#  [  4.25353183  19.1639502    5.96550596 119.87989637   3.
#     4.20040659]
#  [  7.12923339  16.13449201  20.26763368  94.06885367   1.
#     1.89357651]
#  [ 19.9423617    8.39969859  17.11163329  12.06719419   3.
#     4.99557225]
#  [ 17.18360778  17.86549388  13.05651834 149.75732273   2.
#     3.19076967]
#  [ 15.30794698  15.53442329   7.13263909  76.66033291   1.
#     1.63452406]
#  [ 13.31745873  10.07334436  23.00009769  47.84002881   3.
#     2.05686847]
#  [  3.15252706  13.07232609  22.58699803 172.81258664   1.
#     3.57368504]
#  [ 14.53544128  10.49026454   2.5403915  141.42603228   2.
#     1.61279921]
#  [ 15.77173138  12.38466227   1.00297897 160.70096524   3.
#     2.89274515]
#  [  6.21868194  13.36853277   8.82579771  65.79291677   2.
#     5.9786484 ]
#  [  4.19529627   1.86070611   6.34551513 131.24161943   1.
#     5.03943474]
#  [ 13.14781133   7.23767477  16.91966684 129.0898419    1.
#     5.23309058]
#  [ 10.75507839   3.19036546  23.34215405 192.96035947   1.
#     2.42567772]
#  [  9.23648117  11.77021545   7.5463479   77.94054845   1.
#     2.75081391]
#  [  7.1837423    3.17488154  13.13558525  86.52433001   3.
#     4.41841583]]
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds

# %%
with open('test_points_6_param.pkl', "wb") as f:
     pickle.dump((test_X, test_Y), f)

# %%
pred_Y, pred_Y_variance = emukit_model.predict(test_X)
mse = np.sqrt(np.mean((pred_Y-test_Y)**2))
print('Root mean squared error: ', mse)
# Out:
# Root mean squared error:  1.4445145369062213

# %%
pred_Y, test_Y
# Out:
# (array([[2.45691158e-01],
#         [2.38863539e-02],
#         [4.69330831e-03],
#         [1.00988806e-01],
#         [1.35885465e-02],
#         [1.05232247e-01],
#         [2.28397253e-01],
#         [9.31499341e-03],
#         [7.26287369e+00],
#         [3.83722195e-02],
#         [1.34149205e-01],
#         [2.27769023e-02],
#         [3.36298296e-01],
#         [1.33301769e-02],
#         [1.01401805e-01],
#         [4.72236366e-02],
#         [7.42585919e-02],
#         [1.17316377e-01],
#         [1.51749925e-01],
#         [6.84317207e-02],
#         [1.48797727e-01],
#         [2.29759632e-03],
#         [2.24372114e-01],
#         [1.03947071e-02],
#         [1.12581139e-01]]),
#  array([[0.07507789],
#         [0.01842446],
#         [0.01340747],
#         [0.04006658],
#         [0.01636273],
#         [0.1492    ],
#         [0.29265569],
#         [0.01211676],
#         [0.05204098],
#         [0.02777613],
#         [0.03821875],
#         [0.02842034],
#         [0.11653083],
#         [0.01095996],
#         [0.01356708],
#         [0.02503396],
#         [0.01444033],
#         [0.07486009],
#         [0.33457083],
#         [0.03126339],
#         [0.19318111],
#         [0.03377914],
#         [0.07821928],
#         [0.01839882],
#         [0.10872219]]))

# %%
# test_X, test_Y = pickle.load(open('init_and_test_points/test_points_6_param.pkl', 'rb'))
# test_Y = test_Y[:,:,0]
pred_Y, pred_Y_variance = emukit_model.predict(init_X)

# %%
mse = np.sqrt(np.mean((pred_Y-init_Y)**2))
print('Root mean squared error: ', mse)
# Out:
# Root mean squared error:  0.043233969041942356

# %%
pred_Y, init_Y
# Out:
# (array([[0.0099622 ],
#         [0.13358535],
#         [0.01053057],
#         [0.01185559],
#         [0.02436903],
#         [0.06161562],
#         [0.01563503],
#         [0.06888804],
#         [0.00747101],
#         [0.01491154],
#         [0.04667725],
#         [0.00827432],
#         [0.02014405],
#         [0.02301007],
#         [0.01386039],
#         [0.06392771],
#         [0.05214004],
#         [0.05852435],
#         [0.04228184],
#         [0.01316363],
#         [0.00667431],
#         [0.0313933 ],
#         [0.04633733],
#         [0.00962946],
#         [0.00647123]]),
#  array([[0.01992411],
#         [0.26716679],
#         [0.02106082],
#         [0.02371084],
#         [0.04873735],
#         [0.12322937],
#         [0.0312696 ],
#         [0.13777407],
#         [0.0149418 ],
#         [0.02982264],
#         [0.09335313],
#         [0.0165484 ],
#         [0.0402875 ],
#         [0.04601946],
#         [0.02772038],
#         [0.12785355],
#         [0.10427855],
#         [0.11704698],
#         [0.08456244],
#         [0.02632688],
#         [0.01334843],
#         [0.06278568],
#         [0.09267322],
#         [0.01925865],
#         [0.01294227]]))

# %% [markdown]
# ### Save Model

# %%
with open('timeLoss_model_variance_100_iter_batch_size_1.pkl', "wb") as f:
     pickle.dump(emulator, f)

# %% [markdown]
# ### Analysis
#
# As we can see, optimizing for model_variance causes emukit to alternate between extreme choices of \[gridSize, edgeMaxSpeed, maxSpeed, numberOfLanes, accel\] whilst only varying edgeLength sensibly. This means that we don't explore the parameter space comprehensively - which is undesirable.

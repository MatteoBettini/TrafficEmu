# %%
# %cd ../
# Out:
# /Users/harrysonghurst/Documents/Coursework/L48 Machine Learning and the Physical World/TrafficEmu

# %%
# If you get a SciPy error when installing Emukit, build it from source:

# git clone https://github.com/amzn/Emukit.git
# cd Emukit
# pip install -r requirements/requirements.txt
# python setup.py develop

# %%
import numpy as np
import pickle
import emukit as ek
import GPy

from emukit.model_wrappers import GPyModelWrapper
from emukit.experimental_design.experimental_design_loop import ExperimentalDesignLoop
from emukit.core import ParameterSpace, ContinuousParameter, DiscreteParameter
from emukit.core.initial_designs import RandomDesign, latin_design
from emukit.experimental_design.acquisitions import ModelVariance, IntegratedVarianceReduction
from emukit.core.loop import UserFunctionWrapper
from emukit.bayesian_optimization.acquisitions import ExpectedImprovement
from emukit.bayesian_optimization.loops import BayesianOptimizationLoop
from emukit.core.optimization import GradientAcquisitionOptimizer

from sumo_grid_simulation.grid_simulation import Simulator
import experimental_design.config as config

# %% [markdown]
# ### Pseudocode
#
# Fitting a gaussian process to a simulator using Emukit takes the following form (taken from L48 lectures):
#
# ```
# initialize GP with some randomly chosen points
# while stopping condition is not met:
#     compute candidate point(s) using GP and acquisition funciton (model_variance) -> new point
#     evaluate this new point with our simulator/user function -> observation
#     update model with new observation -> new GP
# ```

# %% [markdown]
# ### Simulator

# %%
simulator = Simulator(end_time=300)

# %% [markdown]
# ### User Function
#
# This is the function we want to understand. Namedly, how are CO2 emissions and timeLoss (the time lost due to driving below the ideal speed) affected by the following parameters:
#
# ```
# gridSize: the size of the grid network where the simulation is carried out
# edgeMaxSpeed: legal speed limit in m/s - this can be exceeded (11.11 == 40km/h)
# maxSpeed: the absolute maximum velocity of any vehicle in m/s (55.55 == 200 km/h)
# edgeLength: length of the roads between intersections in meters
# numLanes: number of lanes per road
# accel: The acceleration ability of vehicles in m/s^2.
# ```
#
# *A complete list of parmeters analysed is discussed in our report.*

# %%
def user_function_time_loss(X):
    """  X = inputs - emukit doesnt pass named args, just an NxM ndarray, N is the number of points to evaluate, M is the number of parameters per each point """
    result = []
    i = 0
    
    print(X)
    print(f'\nUser function time loss called with {X.shape[0]} inputs to simulate')

    
    for gridSize, edgeMaxSpeed, numLanes, accel in X:
        print(f'\nEvaluating input: {i+1} of {X.shape[0]}\n')
        
        alpha = 0.005
        max_number_of_vehicles = ((gridSize - 1) * gridSize * 2 + 4 * gridSize) * 10
        period = 300/(max_number_of_vehicles * alpha)
        
        s = simulator.simulate(
            gridSize      = int(gridSize),
            edgeMaxSpeed  = edgeMaxSpeed,
#             maxSpeed      = maxSpeed,
#             edgeLength    = edgeLength,
            numberOfLanes = int(numLanes),
            accel         = accel,
            trips_generator_period = period
        )
        # average time loss / average route duration
        result.append(s['timeLoss']/s['duration'])
        i += 1
        
    # expand dims is essential or the acquition function breaks
    return np.expand_dims(np.array(result), 1)

# %% [markdown]
# ### Model Inputs / parameter space

# %%
parameter_space = config.get_parameter_space()

# %% [markdown]
# ### Get init, test, and train points
#
# Train points are used to optimize a GP without experimental design - to verify experimental design works.

# %%
design = RandomDesign(parameter_space)
init_X = design.get_samples(20)
init_Y = user_function_time_loss(init_X)

design = RandomDesign(parameter_space)
test_X = design.get_samples(50)
test_Y = user_function_time_loss(test_X)

design = RandomDesign(parameter_space)
train_X = design.get_samples(250)
train_Y = user_function_time_loss(train_X)
# Out:
# [[ 7.          9.59503611  2.          1.37621928]
#  [ 6.         10.51706091  1.          1.49605149]
#  [ 3.         13.91220573  1.          2.13969597]
#  [ 3.         17.93894878  1.          2.81357603]
#  [ 8.         12.73839795  3.          1.65390904]
#  [ 6.          9.67471123  2.          1.79264984]
#  [10.         11.46956136  1.          2.67417509]
#  [ 3.         13.82467557  1.          1.75409524]
#  [ 7.         16.41307344  2.          1.91362615]
#  [ 5.         15.85933282  2.          1.67924305]
#  [ 8.         15.29692411  2.          2.13448762]
#  [ 4.         13.17954287  1.          1.33729367]
#  [ 5.         10.89015214  2.          1.62849411]
#  [ 6.         14.3214885   2.          2.95040701]
#  [ 4.         19.78047493  2.          2.77721368]
#  [10.         13.19454801  3.          2.41093324]
#  [ 9.          8.40390059  2.          2.3356186 ]
#  [ 3.         11.2281715   2.          1.34100593]
#  [ 5.          9.44599072  2.          1.94223962]
#  [ 3.          8.71662158  3.          2.93658025]]
#
# User function time loss called with 20 inputs to simulate
#
# Evaluating input: 1 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 6 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 7 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 8 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 9 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 10 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 11 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 12 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 13 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 14 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 15 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 16 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 17 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 18 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 19 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 20 of 20
#
#  Retrying in 1 seconds
# [[ 3.          8.01684014  2.          2.48395289]
#  [ 7.         16.24584514  3.          2.13058994]
#  [ 6.         11.39891011  1.          2.20169692]
#  [ 7.          9.35311315  1.          1.41248972]
#  [ 4.         12.48352259  3.          1.10139493]
#  [ 9.         18.15696307  1.          1.49490151]
#  [ 9.          9.39804837  1.          1.6875499 ]
#  [ 6.         10.20844373  2.          2.39250497]
#  [ 8.         10.4557358   1.          2.01403713]
#  [ 9.         12.50906831  1.          1.19164578]
#  [ 5.          8.75074273  1.          2.23946422]
#  [ 5.         14.64664587  3.          2.57159803]
#  [ 5.          9.60648245  2.          1.79961224]
#  [ 9.         13.71420764  2.          2.19949199]
#  [10.         12.07620975  1.          1.38297136]
#  [ 4.         17.86757343  1.          2.25794757]
#  [ 8.          8.52170381  2.          1.19738014]
#  [10.         15.93042946  1.          2.28079131]
of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 124 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 125 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 126 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 127 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 128 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 129 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 130 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 131 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 132 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 133 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 134 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 135 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 136 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 137 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 138 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 139 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 140 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 141 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 142 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 143 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 144 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 145 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 146 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 147 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 148 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 149 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 150 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 151 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 152 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 153 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 154 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 155 of 200
#  Retrying in 1 seconds
#
# Evaluating input: 156 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 157 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 158 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 159 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 160 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 161 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 162 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 163 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 164 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 165 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 166 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 167 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 168 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 169 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 170 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 171 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 172 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 173 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 174 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 175 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 176 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 177 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 178 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 179 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 180 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 181 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 182 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 183 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 184 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 185 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 186 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 187 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 188 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 189 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 190 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 191 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 192 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 193 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 194 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 195 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 196 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 197 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 198 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 199 of 200
#
#  Retrying in 1 seconds
#
# Evaluating input: 200 of 200
#
#  Retrying in 1 seconds

# %% [markdown]
# ### Experimental Design - Model Variance

# %% [markdown]
# #### Model / Emulator (GP)
#
# Our surrogate model is our emulator. In this case, a gaussian process.

# %%
emulator_ed = GPy.models.GPRegression(init_X, init_Y)
emukit_model_ed = GPyModelWrapper(emulator_ed, n_restarts=5)
emukit_model_ed.optimize()
emulator_ed
# Out:
# Optimization restart 1/5, f = -30.123663898287347
# Optimization restart 2/5, f = -30.123663898309413
# Optimization restart 3/5, f = -30.12366388272921
# Optimization restart 4/5, f = -30.12366389830084
# Optimization restart 5/5, f = -30.1236638983859
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -30.1236638983859<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>                value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right>   0.5421099987279349</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>    29.59049031699629</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>0.0009258824139696584</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %% [markdown]
# #### Acquisition Function

# %%
model_variance = ModelVariance(model=emukit_model_ed)

# %% [markdown]
# #### Optimizer

# %%
optimizer = GradientAcquisitionOptimizer(parameter_space)

# %% [markdown]
# #### Experimental Design Loop

# %%
ed_loop = ExperimentalDesignLoop(
    model = emukit_model_ed,
    space = parameter_space,
    acquisition = model_variance,
    acquisition_optimizer = optimizer,
    update_interval = 1,
    batch_size = 5
)

# %%
ed_loop.run_loop(user_function_time_loss, 50)
# Out:
# Optimization restart 1/5, f = -30.1236638983859
# Optimization restart 2/5, f = -30.123663898138833
# Optimization restart 3/5, f = -30.12366389817443
# Optimization restart 4/5, f = -30.123663898307967
# Optimization restart 5/5, f = -30.123663898206907
# [[10. 20.  1.  1.]
#  [ 3. 20.  3.  1.]
#  [10. 20.  3.  3.]
#  [10.  8.  3.  1.]
#  [10.  8.  1.  3.]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#  /Users/harrysonghurst/opt/anaconda3/envs/traffic/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -39.50544502296353
# Optimization restart 2/5, f = -39.50544504125409
# Optimization restart 3/5, f = -39.50544504068958
# Optimization restart 4/5, f = -39.50544504114181
# Optimization restart 5/5, f = -39.50544504112854
# [[ 3.  8.  3.  3.]
#  [10. 20.  1.  3.]
#  [ 3. 20.  3.  3.]
#  [ 3.  8.  1.  3.]
#  [ 3. 20.  1.  1.]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -50.26256778710493
# Optimization restart 2/5, f = -50.26256778708287
# Optimization restart 3/5, f = -50.262567787107926
# Optimization restart 4/5, f = -50.26256778175406
# Optimization restart 5/5, f = -50.262567787107265
# [[10. 20.  3.  1.]
#  [10.  8.  1.  1.]
#  [ 3.  8.  3.  1.]
#  [ 3.  8.  1.  1.]
#  [10. 20.  1.  3.]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -61.34601187157461
# Optimization restart 2/5, f = -42.08162137757249
# Optimization restart 3/5, f = -61.34601177256039
# Optimization restart 4/5, f = -61.34601186911382
# Optimization restart 5/5, f = -61.346011871613655
# [[10.  8.  3.  1.]
#  [10.  8.  3.  3.]
#  [ 3. 20.  3.  1.]
#  [10. 20.  3.  1.]
#  [ 3.  8.  1.  3.]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -73.44145036126856
# Optimization restart 2/5, f = -73.44145036118447
# Optimization restart 3/5, f = -75.10004264978019
# Optimization restart 4/5, f = -75.10004463251225
# Optimization restart 5/5, f = -73.441450361188
# [[10.         16.09700026  1.          1.        ]
#  [ 3.         15.12111105  3.          3.        ]
#  [ 7.         20.          3.          1.        ]
#  [10.         17.02956608  3.          3.        ]
#  [10.         12.49519516  1.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -80.35177550404175
# Optimization restart 2/5, f = -85.05321930103989
# Optimization restart 3/5, f = -85.05321930102272
# Optimization restart 4/5, f = -80.35177511030986
# Optimization restart 5/5, f = -80.35177568259499
# [[ 3.         20.          1.          3.        ]
#  [ 7.         20.          1.          1.        ]
#  [ 3.         12.76958381  3.          1.        ]
#  [10.          8.          3.          3.        ]
#  [10.          8.          1.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -96.4547257834638
# Optimization restart 2/5, f = -101.21555271370033
# Optimization restart 3/5, f = -96.45472579851267
# Optimization restart 4/5, f = -96.45472579080472
# Optimization restart 5/5, f = -101.21555402493601
# [[10.         15.7869483   3.          1.        ]
#  [10.         10.54507188  3.          1.        ]
#  [ 3.         17.18085687  3.          1.        ]
#  [ 7.         20.          1.          3.        ]
#  [ 6.          8.          1.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -108.33293562207722
# Optimization restart 2/5, f = -108.33293516629976
# Optimization restart 3/5, f = -108.3329327226236
# Optimization restart 4/5, f = -108.33293246075787
# Optimization restart 5/5, f = -109.07404588722243
# [[ 3.         20.          3.          3.        ]
#  [ 3.         20.          1.          1.        ]
#  [ 3.          8.          1.          1.        ]
#  [10.         14.21059008  1.          3.        ]
#  [10.         20.          3.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -123.12958377922745
# Optimization restart 2/5, f = -141.77665582233243
# Optimization restart 3/5, f = -141.77665192874073
# Optimization restart 4/5, f = -123.1295837785874
# Optimization restart 5/5, f = -141.7766426616329
# [[ 6.         17.28272089  3.          3.        ]
#  [ 6.          8.          3.          1.        ]
#  [ 7.         16.77460088  1.          3.        ]
#  [ 3.         12.16391514  3.          3.        ]
#  [ 8.         12.10255815  1.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -147.86048429481127
# Optimization restart 2/5, f = -147.86048426319377
# Optimization restart 3/5, f = -147.86048401211434
# Optimization restart 4/5, f = -136.84149280050866
# Optimization restart 5/5, f = -147.86048412898467
# [[ 3.         10.87639618  1.          3.        ]
#  [ 7.          8.          3.          3.        ]
#  [ 5.         17.89657953  1.          1.        ]
#  [ 7.         14.2585105   1.          1.        ]
#  [ 8.         10.62198605  3.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -156.86947003262654
# Optimization restart 2/5, f = -156.8694697340062
# Optimization restart 3/5, f = -156.86946980187852
# Optimization restart 4/5, f = -148.35773614212377
# Optimization restart 5/5, f = -156.86945880238824
# [[ 6.         15.11966888  3.          1.        ]
#  [ 6.          8.          1.          3.        ]
#  [10.         17.70921263  1.          3.        ]
#  [ 9.         18.15152949  3.          1.        ]
#  [ 7.         20.          3.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -165.35040307192045
# Optimization restart 2/5, f = -165.35040323127612
# Optimization restart 3/5, f = -165.35022818530192
# Optimization restart 4/5, f = -160.49582434094268
# Optimization restart 5/5, f = -165.35040292382226
# [[ 3.         16.49974781  1.          1.        ]
#  [ 5.         11.28478675  3.          3.        ]
#  [10.          9.91334171  1.          1.        ]
#  [ 5.         18.58636403  3.          1.        ]
#  [ 8.         18.02824078  1.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -172.31095500632668
# Optimization restart 2/5, f = -172.310953679405
# Optimization restart 3/5, f = -172.31095403347152
# Optimization restart 4/5, f = -172.31095154879267
# Optimization restart 5/5, f = -174.8658444122023
# [[10.        20.         1.         1.       ]
#  [ 3.         8.         3.         1.       ]
#  [ 3.        20.         1.         3.       ]
#  [10.        13.8464026  3.         3.       ]
#  [ 3.         8.         3.         3.       ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -189.72714520265384
# Optimization restart 2/5, f = -189.72714520317925
# Optimization restart 3/5, f = -206.58117276290108
# Optimization restart 4/5, f = -206.5811729465686
# Optimization restart 5/5, f = -206.58117291478936
# [[ 8.         18.7676286   2.          3.        ]
#  [ 5.         11.54148623  1.          3.        ]
#  [ 5.         10.07725867  3.          1.        ]
#  [10.         10.19417266  3.          3.        ]
#  [ 3.         17.939355    3.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -217.06188673238734
# Optimization restart 2/5, f = -204.27450557154597
# Optimization restart 3/5, f = -217.06188658441076
# Optimization restart 4/5, f = -217.06187190582614
# Optimization restart 5/5, f = -204.27450556978687
# [[ 8.          9.37756886  1.          3.        ]
#  [10.         18.4691822   2.          1.65846365]
#  [ 4.         16.04880085  1.          3.        ]
#  [ 8.         15.15214598  3.          3.        ]
#  [ 9.         20.          1.          1.99341696]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -222.04118470761955
# Optimization restart 2/5, f = -211.39692336959598
# Optimization restart 3/5, f = -211.39692336964114
# Optimization restart 4/5, f = -211.39692336959888
# Optimization restart 5/5, f = -222.0411817443464
# [[ 5.         13.79093394  3.          2.27090075]
#  [ 8.          8.          3.          1.        ]
#  [ 5.         20.          1.          1.82629696]
#  [ 8.          8.          1.          1.86236635]
#  [ 3.          9.86875429  1.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -231.59788136745314
# Optimization restart 2/5, f = -223.98569957787245
# Optimization restart 3/5, f = -223.98569957793833
# Optimization restart 4/5, f = -231.59787250123247
# Optimization restart 5/5, f = -223.9856995257912
# [[ 3.         19.08149346  2.          1.74714004]
#  [ 5.         18.63996571  1.          3.        ]
#  [ 8.         11.65218012  1.          1.        ]
#  [ 6.         12.46162497  3.          1.        ]
#  [ 3.         14.62848128  2.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -239.3333140167395
# Optimization restart 2/5, f = -239.3333141947609
# Optimization restart 3/5, f = -236.447386444679
# Optimization restart 4/5, f = -239.3333133912214
# Optimization restart 5/5, f = -236.44738821243038
# [[ 5.          8.          3.          3.        ]
#  [10.         13.22383228  3.          1.        ]
#  [ 5.         20.          3.          2.02319935]
#  [ 9.          9.24065     3.          1.91974167]
#  [ 6.         14.07644599  1.          2.33216467]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -246.85840146817395
# Optimization restart 2/5, f = -247.74372160574987
# Optimization restart 3/5, f = -247.74372160296812
# Optimization restart 4/5, f = -247.74372160717726
# Optimization restart 5/5, f = -247.743721605254
# [[10.          8.          1.          3.        ]
#  [ 3.          8.35654523  3.          1.13501992]
#  [ 3.         20.          1.          1.        ]
#  [10.          8.          3.          1.        ]
#  [10.         17.49718734  1.          1.04985618]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -262.1825361668813
# Optimization restart 2/5, f = -274.40358547528683
# Optimization restart 3/5, f = -262.18253616816514
# Optimization restart 4/5, f = -274.4035858473103
# Optimization restart 5/5, f = -262.18253616808636
# [[10.         15.91939655  2.          3.        ]
#  [ 7.         18.77625604  3.          2.01162274]
#  [10.         12.33840879  2.          3.        ]
#  [ 3.         15.64657904  3.          1.8594284 ]
#  [ 5.         20.          2.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -284.138715641159
# Optimization restart 2/5, f = -277.01082176655103
# Optimization restart 3/5, f = -277.0108217870583
# Optimization restart 4/5, f = -284.1387156282717
# Optimization restart 5/5, f = -277.0108217851036
# [[ 4.          8.          1.          1.97214934]
#  [ 8.         15.40375165  3.          1.        ]
#  [ 9.         20.          2.          1.        ]
#  [ 3.          8.          2.          2.03778519]
#  [ 3.         16.48192592  2.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -295.37571305976513
# Optimization restart 2/5, f = -290.8711529496417
# Optimization restart 3/5, f = -290.87115294259365
# Optimization restart 4/5, f = -295.3757117748848
# Optimization restart 5/5, f = -295.37571292341187
# [[ 4.          8.          2.          1.        ]
#  [ 9.         20.          3.          2.12422718]
#  [ 3.         18.55092386  1.          1.        ]
#  [10.          8.91145481  1.          2.16257962]
#  [ 7.         12.82197696  3.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -303.7259338057023
# Optimization restart 2/5, f = -303.7259138612302
# Optimization restart 3/5, f = -296.0874392366146
# Optimization restart 4/5, f = -303.7259099570591
# Optimization restart 5/5, f = -296.087439197756
# [[ 8.         15.03576802  1.          3.        ]
#  [ 9.         16.68922673  1.          2.1591588 ]
#  [ 7.         20.          2.          2.12474831]
#  [ 3.         10.73276903  3.          1.95706552]
#  [ 3.         12.00243101  1.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -316.434289864104
# Optimization restart 2/5, f = -307.4092536705777
# Optimization restart 3/5, f = -307.40925367061277
# Optimization restart 4/5, f = -316.4342891064888
# Optimization restart 5/5, f = -307.409253653116
# [[10.         11.06922619  2.          1.61482861]
#  [ 9.         13.48032415  1.          1.80470241]
#  [ 9.          8.78930888  1.          1.        ]
#  [ 6.         15.96515389  1.          1.        ]
#  [10.          9.45802637  2.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -321.82128536823825
# Optimization restart 2/5, f = -321.82125976247073
# Optimization restart 3/5, f = -319.87242555409574
# Optimization restart 4/5, f = -319.872425522256
# Optimization restart 5/5, f = -321.82128481917346
# [[ 4.          9.32543176  1.          3.        ]
#  [ 4.         15.89553783  3.          3.        ]
#  [ 8.         10.64910256  3.          1.        ]
#  [ 4.         14.92131476  3.          1.        ]
#  [ 4.         13.14212568  2.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -325.000259786136
# Optimization restart 2/5, f = -318.12959637383506
# Optimization restart 3/5, f = -85.05342319414542
# Optimization restart 4/5, f = -325.000232729738
# Optimization restart 5/5, f = -318.12959634860374
# [[ 7.         17.32888196  3.          1.        ]
#  [ 5.         19.10670195  3.          3.        ]
#  [ 6.         12.33918317  1.          1.        ]
#  [ 9.         12.43087597  3.          3.        ]
#  [10.         14.31942987  2.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -330.48547478848315
# Optimization restart 2/5, f = -332.0471175723027
# Optimization restart 3/5, f = -332.0471175698088
# Optimization restart 4/5, f = -332.0471175737078
# Optimization restart 5/5, f = -332.04711756898973
# [[10.         20.          3.          3.        ]
#  [ 3.         19.97793992  3.          1.39920967]
#  [ 3.          8.          3.          1.        ]
#  [10.          8.          1.          1.        ]
#  [10.         20.          1.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -346.24938262900446
# Optimization restart 2/5, f = -346.2493826178646
# Optimization restart 3/5, f = -346.24938262845154
# Optimization restart 4/5, f = -365.8738890706047
# Optimization restart 5/5, f = -365.8738895040466
# [[ 9.         16.6225952   2.          1.        ]
#  [ 6.          9.35966161  3.          3.        ]
#  [ 8.         17.4953571   3.          3.        ]
#  [ 4.          8.          3.          1.8106557 ]
#  [ 6.         10.49299084  2.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -374.96380279565903
# Optimization restart 2/5, f = -374.9638027454646
# Optimization restart 3/5, f = -359.93493577913557
# Optimization restart 4/5, f = -359.9349357797375
# Optimization restart 5/5, f = -374.96380002499825
# [[ 7.         18.6465838   1.          2.10565752]
#  [ 3.          9.29779401  1.          2.18967193]
#  [10.          8.91318324  2.          1.        ]
#  [ 4.         17.39206632  1.          2.00044723]
#  [ 4.         11.59997497  3.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -389.63889379685224
# Optimization restart 2/5, f = -370.07575424485157
# Optimization restart 3/5, f = -370.0757542356187
# Optimization restart 4/5, f = -389.63889239209647
# Optimization restart 5/5, f = -370.07575425090204
# [[ 8.         12.83552937  2.          1.        ]
#  [10.         18.78354477  3.          3.        ]
#  [ 5.          9.49857672  1.          1.        ]
#  [10.         17.55820507  3.          1.74290422]
#  [ 5.         17.33735318  3.          1.90485846]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -400.7345282918234
# Optimization restart 2/5, f = -400.73452813567
# Optimization restart 3/5, f = -400.73452362408204
# Optimization restart 4/5, f = -400.73452789155283
# Optimization restart 5/5, f = -383.5603885230351
# [[ 5.         17.53217301  2.          3.        ]
#  [ 7.         18.66631558  2.          1.        ]
#  [10.         15.28000737  3.          2.0503434 ]
#  [ 4.         15.02391603  1.          1.        ]
#  [ 5.         13.6531797   2.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -413.6092838954487
# Optimization restart 2/5, f = -395.42552642530393
# Optimization restart 3/5, f = -395.4255264235581
# Optimization restart 4/5, f = -395.4255264271761
# Optimization restart 5/5, f = -395.4255263289665
# [[ 3.         13.22853072  3.          2.1032518 ]
#  [ 3.         12.81371035  1.          3.        ]
#  [ 8.          8.          1.          3.        ]
#  [ 9.         18.91349301  1.          3.        ]
#  [10.          8.          3.          1.99822245]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -426.805548066304
# Optimization restart 2/5, f = -426.8054822236734
# Optimization restart 3/5, f = -404.3092480028472
# Optimization restart 4/5, f = -404.30924806898315
# Optimization restart 5/5, f = -426.80554775169395
# [[ 3.          9.53498456  2.          3.        ]
#  [10.         20.          2.          2.09882463]
#  [ 7.         12.08520935  2.          2.16549814]
#  [ 9.         20.          2.          3.        ]
#  [ 3.         18.80915399  3.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -441.86059626766746
# Optimization restart 2/5, f = -418.30286768683254
# Optimization restart 3/5, f = -441.860595648622
# Optimization restart 4/5, f = -418.3028676180262
# Optimization restart 5/5, f = -441.86059620370656
# [[ 3.         10.36950381  3.          1.        ]
#  [ 9.         15.050587    1.          1.        ]
#  [ 9.         10.73699896  2.          3.        ]
#  [ 7.          8.          2.          3.        ]
#  [ 4.         17.54836819  2.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -456.01101348635757
# Optimization restart 2/5, f = -432.6461327086806
# Optimization restart 3/5, f = -456.0110125029472
# Optimization restart 4/5, f = -432.6461327085474
# Optimization restart 5/5, f = -432.6461326898801
# [[10.         15.0565911   1.          2.04155463]
#  [ 8.          8.          2.          1.        ]
#  [ 3.         11.55132522  1.          2.1253051 ]
#  [ 4.         19.55864784  1.          1.        ]
#  [ 9.         13.76565924  2.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -472.063169194825
# Optimization restart 2/5, f = -446.8293763837855
# Optimization restart 3/5, f = -472.06316966804195
# Optimization restart 4/5, f = -446.8293763837921
# Optimization restart 5/5, f = -446.8293762028918
# [[ 5.         14.0113012   1.          3.        ]
#  [10.         18.83378443  1.          2.15770845]
#  [ 9.          8.66210167  3.          3.        ]
#  [ 7.          8.38123948  3.          1.84945514]
#  [ 3.         20.          1.          2.03309582]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -485.0947460941353
# Optimization restart 2/5, f = -460.54397337064177
# Optimization restart 3/5, f = -485.094746108765
# Optimization restart 4/5, f = -460.54397330008374
# Optimization restart 5/5, f = -460.5439733750872
# [[ 6.         20.          2.          3.        ]
#  [10.          9.87124285  1.          3.        ]
#  [ 7.          9.13690401  1.          1.        ]
#  [ 4.         13.64614609  3.          3.        ]
#  [ 9.         16.88114147  2.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -478.7752757801069
# Optimization restart 2/5, f = -459.0455261973273
# Optimization restart 3/5, f = -459.0455260962866
# Optimization restart 4/5, f = -478.775272367387
# Optimization restart 5/5, f = -459.045526188064
# [[ 9.         11.062358    2.          1.        ]
#  [10.         18.67705592  3.          1.        ]
#  [ 3.         15.52370369  1.          3.        ]
#  [ 4.         10.12225587  3.          3.        ]
#  [ 9.         10.59596885  1.          1.99419237]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -479.54347980233797
# Optimization restart 2/5, f = -464.86100830967524
# Optimization restart 3/5, f = -479.5434789875786
# Optimization restart 4/5, f = -464.86100831746575
# Optimization restart 5/5, f = -464.86100831728726
# [[ 4.         20.          1.          3.        ]
#  [ 6.         15.23615542  3.          3.        ]
#  [ 4.          8.          2.          3.        ]
#  [ 8.         16.30178829  3.          1.89182816]
#  [ 6.          9.58413876  1.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -490.47116084007416
# Optimization restart 2/5, f = -475.0137440651845
# Optimization restart 3/5, f = -490.4711572573458
# Optimization restart 4/5, f = -475.01374403981026
# Optimization restart 5/5, f = -490.47108309851046
# [[ 6.         15.70548595  1.          3.        ]
#  [ 6.         10.86986497  3.          2.00156656]
#  [ 4.         11.06467678  1.          1.        ]
#  [ 7.         14.30598591  3.          1.92696459]
#  [ 9.         19.1765425   1.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -503.4468156348837
# Optimization restart 2/5, f = -484.40566577368674
# Optimization restart 3/5, f = -484.40566577377916
# Optimization restart 4/5, f = -503.4468088222829
# Optimization restart 5/5, f = -484.4056657622576
# [[ 9.         14.23604218  3.          1.34916928]
#  [ 7.          9.10877636  3.          1.        ]
#  [ 5.         18.88519999  2.          1.82360551]
#  [ 3.         14.25350685  2.          3.        ]
#  [ 3.         17.69253322  3.          1.97318549]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -516.3332374483633
# Optimization restart 2/5, f = -516.333237448121
# Optimization restart 3/5, f = -516.3332343920398
# Optimization restart 4/5, f = -496.52846843377654
# Optimization restart 5/5, f = -496.52846845915815
# [[ 7.         13.19763148  1.          3.        ]
#  [ 6.         16.980068    1.          1.96731866]
#  [ 6.          8.          2.          1.84754819]
#  [ 4.         20.          3.          1.        ]
#  [10.         18.83400554  2.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -526.9603973077055
# Optimization restart 2/5, f = -508.74637187560916
# Optimization restart 3/5, f = -508.7463718754773
# Optimization restart 4/5, f = -508.7463718222681
# Optimization restart 5/5, f = -508.7463718598524
# [[ 7.         11.13582323  1.          3.        ]
#  [10.         11.32885684  3.          2.10090197]
#  [ 3.         16.30021209  1.          2.05000694]
#  [ 3.          8.97147202  2.          1.        ]
#  [ 9.         19.22862961  3.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -535.556297984368
# Optimization restart 2/5, f = -521.163832996526
# Optimization restart 3/5, f = -521.1638329962389
# Optimization restart 4/5, f = -521.163832976404
# Optimization restart 5/5, f = -521.163832996574
# [[ 8.         16.07180569  1.          1.        ]
#  [10.         15.87943919  1.          3.        ]
#  [ 6.         11.00150082  2.          1.        ]
#  [ 5.         16.59116011  3.          1.        ]
#  [10.         14.08033386  1.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -550.0901911764473
# Optimization restart 2/5, f = -535.3252506656237
# Optimization restart 3/5, f = -535.3252506543889
# Optimization restart 4/5, f = -535.3252506625786
# Optimization restart 5/5, f = -535.3252506651603
# [[ 6.         19.23767752  1.          1.        ]
#  [10.          9.07782909  3.          1.69872104]
#  [ 3.         10.44730706  3.          3.        ]
#  [ 4.          8.65393033  3.          1.        ]
#  [ 3.         14.66388069  3.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -559.1084706468315
# Optimization restart 2/5, f = -559.108465644634
# Optimization restart 3/5, f = -548.252946778287
# Optimization restart 4/5, f = -548.2529466027794
# Optimization restart 5/5, f = -548.2529467705494
# [[ 4.         19.00885401  3.          2.45949975]
#  [10.          8.          2.          1.77761737]
#  [ 6.          8.66183051  1.          2.13162231]
#  [ 3.         18.89742079  2.          3.        ]
#  [ 7.         14.98359288  2.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -570.0737047175016
# Optimization restart 2/5, f = -559.8480663221861
# Optimization restart 3/5, f = -559.8480663178833
# Optimization restart 4/5, f = -559.8480662946417
# Optimization restart 5/5, f = -559.8480662961874
# [[ 3.         11.66081573  2.          3.        ]
#  [10.         16.59525503  2.          1.80486527]
#  [10.         12.75545621  1.          1.9475269 ]
#  [ 4.         10.19662478  1.          2.2255653 ]
#  [ 9.          8.          3.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -584.4472669244362
# Optimization restart 2/5, f = -584.4472649751042
# Optimization restart 3/5, f = -574.0876738770435
# Optimization restart 4/5, f = -518.1654613834277
# Optimization restart 5/5, f = -574.0876738992498
# [[ 9.         12.12809886  3.          1.        ]
#  [ 8.         19.59286711  3.          1.        ]
#  [ 7.         12.55242504  1.          1.7555059 ]
#  [ 6.         17.28123355  2.          1.        ]
#  [ 3.         17.41860091  2.          1.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -596.006515245422
# Optimization restart 2/5, f = -586.5692205039248
# Optimization restart 3/5, f = -586.5692205040676
# Optimization restart 4/5, f = -586.5692203961362
# Optimization restart 5/5, f = -586.5692205040829
# [[ 4.         11.83487683  3.          2.30209552]
#  [ 9.          8.96376413  3.          1.        ]
#  [10.         19.36133258  3.          1.86052127]
#  [ 7.         13.53431882  3.          1.        ]
#  [ 9.         15.69804181  3.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -597.0041219919929
# Optimization restart 2/5, f = -543.1831574385884
# Optimization restart 3/5, f = -597.4039777232683
# Optimization restart 4/5, f = -597.0041211952974
# Optimization restart 5/5, f = -597.4039777191456
# [[10.         20.          1.          1.        ]
#  [ 3.          8.          1.          3.        ]
#  [ 3.          8.2880366   1.          1.26501524]
#  [10.          8.          1.          3.        ]
#  [ 3.         20.          3.          3.        ]]
#
# User function time loss called with 5 inputs to simulate
#
# Evaluating input: 1 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 5
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 5
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -611.7577864336569
# Optimization restart 2/5, f = -633.5626124339014
# Optimization restart 3/5, f = -611.7577999764213
# Optimization restart 4/5, f = -633.5626094157825
# Optimization restart 5/5, f = -611.7577964201779

# %% [markdown]
# ### Experimental Design - Integrated Variance Reduction

# %% [markdown]
# #### Model / Emulator (GP)

# %%
emulator_ird = GPy.models.GPRegression(init_X, init_Y, noise_var=1e-10)
emukit_model_ird = GPyModelWrapper(emulator_ird, n_restarts=5)
emukit_model_ird.optimize()
# Out:
# Optimization restart 1/5, f = -19.61491373133359
# Optimization restart 2/5, f = -30.123663898283255
# Optimization restart 3/5, f = -30.123663898380876
# Optimization restart 4/5, f = -30.123663898385853
# Optimization restart 5/5, f = -30.123663898386102

# %% [markdown]
# #### Acquisition Function

# %%
integrated_variance_reduction = IntegratedVarianceReduction(model=emukit_model_ird, space=parameter_space)

# %% [markdown]
# #### Optimizer

# %%
optimizer = GradientAcquisitionOptimizer(parameter_space)

# %% [markdown]
# #### Experimental Design Loop

# %%
ed_loop = ExperimentalDesignLoop(
    model = emukit_model_ird,
    space = parameter_space,
    acquisition = integrated_variance_reduction,
    acquisition_optimizer = optimizer,
    update_interval = 1,
    batch_size = 10
)

# %%
ed_loop.run_loop(user_function_time_loss, 10)
# Out:
# Optimization restart 1/5, f = -30.123663898386102
# Optimization restart 2/5, f = -30.12366389815559
# Optimization restart 3/5, f = -30.123663898370488
# Optimization restart 4/5, f = -29.915752486615947
# Optimization restart 5/5, f = -30.12366389838657
#  /Users/harrysonghurst/opt/anaconda3/envs/traffic/lib/python3.8/site-packages/GPy/kern/src/stationary.py:168: RuntimeWarning:overflow encountered in true_divide
#  /Users/harrysonghurst/opt/anaconda3/envs/traffic/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
#  /Users/harrysonghurst/opt/anaconda3/envs/traffic/lib/python3.8/site-packages/GPy/kern/src/rbf.py:76: RuntimeWarning:invalid value encountered in multiply
# [[10.         19.48493387  1.          1.48992291]
#  [ 3.         18.56383444  3.          1.07153559]
#  [10.         19.98036324  3.          2.53740027]
#  [10.         10.31642425  3.          1.05533876]
#  [ 9.         19.76758188  1.          1.13296382]
#  [ 9.          8.06588965  1.          2.66951995]
#  [ 4.         19.05832594  3.          1.11976761]
#  [ 9.         16.11582068  3.          2.95037847]
#  [ 3.          8.12812851  3.          2.64249375]
#  [10.          8.96308323  3.          1.0660271 ]]
#
# User function time loss called with 10 inputs to simulate
#
# Evaluating input: 1 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 6 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 7 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 8 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 9 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 10 of 10
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -51.66135759006083
# Optimization restart 2/5, f = -51.661357590257424
# Optimization restart 3/5, f = -51.661357605854555
# Optimization restart 4/5, f = -51.66135760057159
# Optimization restart 5/5, f = -51.66135760606238
# [[ 4.         19.51421415  3.          2.97164792]
#  [10.         16.55147998  1.          2.8528249 ]
#  [10.          8.46616495  1.          2.98511899]
#  [ 3.          8.03113098  1.          1.4197304 ]
#  [ 3.         19.96155669  1.          1.54662278]
#  [10.         17.20479129  1.          1.06108393]
#  [ 3.         13.19012815  3.          2.96184574]
#  [10.         17.0490579   3.          1.07741024]
#  [ 9.         19.67849381  1.          2.82025581]
#  [ 3.          8.63076282  3.          1.0169236 ]]
#
# User function time loss called with 10 inputs to simulate
#
# Evaluating input: 1 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 6 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 7 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 8 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 9 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 10 of 10
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -71.65805849857223
# Optimization restart 2/5, f = -71.65805849997912
# Optimization restart 3/5, f = -71.65805850019942
# Optimization restart 4/5, f = -71.65805850019811
# Optimization restart 5/5, f = -71.65805850009252
# [[10.          8.13500737  1.          1.08232227]
#  [ 7.         15.65053338  3.          1.00900072]
#  [ 7.          8.24759576  3.          2.95895872]
#  [ 6.         14.1652276   1.          2.94781443]
#  [ 9.         19.94554245  3.          2.76442102]
#  [ 3.          8.52437179  1.          2.98920686]
#  [ 3.         19.7645586   3.          1.27480819]
#  [ 7.         19.44606657  1.          1.04247834]
#  [10.         12.06541664  3.          2.91853014]
#  [ 8.         13.27312828  1.          1.0217989 ]]
#
# User function time loss called with 10 inputs to simulate
#
# Evaluating input: 1 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 6 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 7 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 8 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 9 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 10 of 10
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -92.17457337969235
# Optimization restart 2/5, f = -92.17457337980045
# Optimization restart 3/5, f = -92.17457337982748
# Optimization restart 4/5, f = -92.17457337982609
# Optimization restart 5/5, f = -92.17457337897363
# [[ 3.         14.64330586  3.          2.83751185]
#  [ 5.         19.73025467  1.          2.94040395]
#  [ 6.         13.30567073  3.          1.01126247]
#  [10.         14.37714688  1.          2.70164058]
#  [ 8.         19.86800894  3.          1.08201759]
#  [ 6.          8.03262662  3.          1.00890382]
#  [10.          8.34821746  3.          2.91253184]
#  [ 6.         15.30168343  3.          2.93695649]
#  [ 3.         16.26187966  1.          1.0490958 ]
#  [ 7.         12.66983727  1.          2.99783372]]
#
# User function time loss called with 10 inputs to simulate
#
# Evaluating input: 1 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 6 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 7 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 8 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 9 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 10 of 10
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -115.18861170010894
# Optimization restart 2/5, f = -115.18861171102327
# Optimization restart 3/5, f = -115.18861171113431
# Optimization restart 4/5, f = -115.18861171113775
# Optimization restart 5/5, f = -115.18861171056938
# [[10.         12.86383707  1.          1.45301907]
#  [ 3.         14.10815108  3.          1.11412297]
#  [ 6.         17.82858775  1.          2.99095764]
#  [ 6.          8.07671646  1.          1.05425959]
#  [ 3.         10.32736361  1.          2.92024877]
#  [10.         14.27097477  3.          1.0071741 ]
#  [ 6.         17.13908041  1.          1.10522315]
#  [ 7.         11.10755873  3.          2.96343956]
#  [ 6.         17.64029966  3.          2.99039799]
#  [ 3.         14.96414703  3.          2.87408061]]
#
# User function time loss called with 10 inputs to simulate
#
# Evaluating input: 1 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 6 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 7 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 8 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 9 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 10 of 10
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -138.8896935077167
# Optimization restart 2/5, f = -138.88969369333395
# Optimization restart 3/5, f = -138.88969369179628
# Optimization restart 4/5, f = -138.88969369334188
# Optimization restart 5/5, f = -138.88969369348075
# [[10.         19.91936932  3.          2.89709743]
#  [ 3.         19.28452205  1.          2.93695103]
#  [10.         12.36299206  1.          1.05521453]
#  [ 5.          8.18914753  1.          2.85472739]
#  [ 7.         19.96939904  3.          1.13827995]
#  [ 3.         11.09786161  3.          1.02697459]
#  [ 3.         17.3969794   1.          1.00345406]
#  [ 7.         10.5055251   3.          2.99217092]
#  [10.          8.31648991  3.          1.00146852]
#  [10.         18.48872295  1.          2.90828582]]
#
# User function time loss called with 10 inputs to simulate
#
# Evaluating input: 1 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 6 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 7 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 8 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 9 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 10 of 10
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -163.2876218950406
# Optimization restart 2/5, f = -163.28762189006324
# Optimization restart 3/5, f = -163.2876218949355
# Optimization restart 4/5, f = -163.28762184550567
# Optimization restart 5/5, f = -163.2876218408494
# [[10.         16.85821726  3.          1.05516133]
#  [ 6.         16.90784789  1.          1.20435983]
#  [ 7.         11.02177385  1.          1.23101084]
#  [ 3.         12.81380673  1.          2.86911137]
#  [ 7.         17.64341883  3.          2.94589393]
#  [ 3.          8.69447442  1.          1.04381753]
#  [ 3.         19.97758479  3.          2.7212506 ]
#  [10.         14.01110902  3.          2.94041848]
#  [ 7.         10.79011833  1.          2.99032555]
#  [ 6.         10.85063265  3.          1.18837016]]
#
# User function time loss called with 10 inputs to simulate
#
# Evaluating input: 1 of 10
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 6 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 7 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 8 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 9 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 10 of 10
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -188.40113826278773
# Optimization restart 2/5, f = -188.40113828092356
# Optimization restart 3/5, f = -188.40113828110822
# Optimization restart 4/5, f = -188.40113828092524
# Optimization restart 5/5, f = -188.40113827035654
# [[ 6.         19.72677365  1.          1.22757468]
#  [10.          8.02027891  3.          2.81419752]
#  [10.         12.53418302  1.          1.06271827]
#  [10.         19.95910581  1.          1.26367345]
#  [ 3.         12.49958454  3.          1.0944904 ]
#  [ 3.          8.04408615  3.          1.03309623]
#  [ 7.         16.57730774  3.          1.03079574]
#  [10.          8.04062909  1.          1.17719059]
#  [10.         13.0580601   1.          2.99874686]
#  [ 3.         14.1557863   3.          2.95376949]]
#
# User function time loss called with 10 inputs to simulate
#
# Evaluating input: 1 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 6 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 7 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 8 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 9 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 10 of 10
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -214.65298904830064
# Optimization restart 2/5, f = -214.65298904884452
# Optimization restart 3/5, f = -214.65298904935347
# Optimization restart 4/5, f = -214.65298904928437
# Optimization restart 5/5, f = -214.65298904887368
# [[ 6.         17.18481282  1.          2.74130305]
#  [ 6.         10.29663789  3.          2.78316093]
#  [ 6.         17.28912414  3.          1.93912825]
#  [ 7.         19.91659443  1.          2.80274739]
#  [ 3.         12.67874267  1.          1.07679721]
#  [10.         16.23409772  3.          2.82102307]
#  [ 3.         15.51730049  1.          2.98612917]
#  [ 6.          8.34569404  1.          2.61021088]
#  [ 7.         11.26692391  3.          1.12462958]
#  [ 3.         19.70782652  1.          1.26011581]]
#
# User function time loss called with 10 inputs to simulate
#
# Evaluating input: 1 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 6 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 7 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 8 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 9 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 10 of 10
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -238.86582925748542
# Optimization restart 2/5, f = -238.86582925682563
# Optimization restart 3/5, f = -238.8658292507826
# Optimization restart 4/5, f = -238.8658292407938
# Optimization restart 5/5, f = -238.8658292573497
# [[ 7.         16.09307082  1.          1.00244673]
#  [ 3.         16.08998086  3.          1.1958768 ]
#  [10.         18.24968248  3.          1.02086395]
#  [ 6.          8.05270981  3.          1.22639174]
#  [10.         17.72007164  1.          2.90800949]
#  [ 3.          9.6821848   3.          2.90713046]
#  [ 7.         11.13878156  1.          2.99528598]
#  [ 6.         16.8978731   3.          1.90686843]
#  [ 7.         11.49447768  1.          1.02290964]
#  [10.         11.37380855  3.          2.98359061]]
#
# User function time loss called with 10 inputs to simulate
#
# Evaluating input: 1 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 6 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 7 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 8 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 9 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 10 of 10
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -261.93606856912135
# Optimization restart 2/5, f = -261.9360685690848
# Optimization restart 3/5, f = -261.93606856911435
# Optimization restart 4/5, f = -261.9360685686966
# Optimization restart 5/5, f = -261.9360685691242

# %% [markdown]
# ### Random GP
#
# Supervised learning

# %%
emulator_rnd = GPy.models.GPRegression(train_X, train_Y)
emukit_model_rnd = GPyModelWrapper(emulator_rnd, n_restarts=5)
emukit_model_rnd.optimize()
emulator_rnd
# Out:
# Optimization restart 1/5, f = -425.091967728542
# Optimization restart 2/5, f = -404.1223847688247
# Optimization restart 3/5, f = -425.0919679879982
# Optimization restart 4/5, f = -425.0919679820563
# Optimization restart 5/5, f = -425.0919679879704
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -425.0919679879982<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>                value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right>  0.25997091630883973</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>   14.710576636825746</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>0.0006171249210919437</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %% [markdown]
# ### Evaluate
#
# Evaluate RMSE of each model on our test set of 50 randomly selected points.

# %%
pred_Y, pred_Y_variance = emukit_model_ed.predict(test_X)
mse_ed = np.sqrt(np.mean((pred_Y-test_Y)**2))
print('Experimental Design w/ Model Variance RMSE: ', mse_ed)
# Out:
# Experimental Design w/ Model Variance RMSE:  0.016557482174249984

# %%
pred_Y, pred_Y_variance = emukit_model_ird.predict(test_X)
mse_ird = np.sqrt(np.mean((pred_Y-test_Y)**2))
print('Experimental Design w/ Integrated Variance Reduction RMSE: ', mse_ird)
# Out:
# Experimental Design w/ Integrated Variance Reduction RMSE:  0.03357609604099156

# %%
pred_Y, pred_Y_variance = emukit_model_rnd.predict(test_X)
mse_rnd = np.sqrt(np.mean((pred_Y-test_Y)**2))
print('Random GP RMSE: ', mse_rnd)
# Out:
# Random GP RMSE:  0.031080123842760262

# %%
p = 1 - (mse_ed/mse_rnd)
f'Experimental Design w/ Model Variance is {p*100:.3f}% better than training on random points.'
# Out:
# 'Experimental Design w/ Model Variance is 46.726% better than training on random points.'

# %%
p = 1 - (mse_ird/mse_rnd)
f'Experimental Design w/ Integrated Variance Reduction is {p*100:.3f}% better than training on random points.'
# Out:
# 'Experimental Design w/ Integrated Variance Reduction is -8.031% better than training on random points.'

# %% [markdown]
# ### Save Models

# %%
with open(f'experimental_design/models/model_variance_20_init_points_250_loops_timeloss.pkl', "wb") as f:
     pickle.dump(emukit_model_ed, f)

with open(f'experimental_design/models/integrated_variance_reduction_20_init_points_10_loops_timeloss.pkl', "wb") as f:
     pickle.dump(emukit_model_ird, f)
        
with open(f'experimental_design/models/250_random_points_supervised_GP_timeloss.pkl', "wb") as f:
     pickle.dump(emukit_model_rnd, f)

# %%
# %cd ../

# %%
# If you get a SciPy error when installing Emukit, build it from source:

# git clone https://github.com/amzn/Emukit.git
# cd Emukit
# pip install -r requirements/requirements.txt
# python setup.py develop

# %%
import numpy as np
import pickle
import emukit as ek
import GPy

from emukit.model_wrappers import GPyModelWrapper
from emukit.experimental_design.experimental_design_loop import ExperimentalDesignLoop
from emukit.core import ParameterSpace, ContinuousParameter, DiscreteParameter
from emukit.core.initial_designs import RandomDesign, latin_design
from emukit.experimental_design.acquisitions import ModelVariance, IntegratedVarianceReduction
from emukit.core.loop import UserFunctionWrapper
from emukit.bayesian_optimization.acquisitions import ExpectedImprovement
from emukit.bayesian_optimization.loops import BayesianOptimizationLoop
from emukit.core.optimization import GradientAcquisitionOptimizer

from sumo_grid_simulation.grid_simulation import Simulator

# %% [markdown]
# ### Pseudocode
#
# Fitting a gaussian process to a simulator using Emukit takes the following form (taken from L48 lectures):
#
# ```
# initialize GP with some randomly chosen points
# while stopping condition is not met:
#     compute candidate point(s) using GP and acquisition funciton (model_variance) -> new point
#     evaluate this new point with our simulator/user function -> observation
#     update model with new observation -> new GP
# ```

# %% [markdown]
# ### Simulator

# %%
simulator = Simulator(end_time=300)

# %% [markdown]
# ### User Function
#
# This is the function we want to understand. Namedly, how are CO2 emissions and timeLoss (the time lost due to driving below the ideal speed) affected by the following parameters:
#
# ```
# gridSize: the size of the grid network where the simulation is carried out
# edgeMaxSpeed: legal speed limit in m/s - this can be exceeded (11.11 == 40km/h)
# maxSpeed: the absolute maximum velocity of any vehicle in m/s (55.55 == 200 km/h)
# edgeLength: length of the roads between intersections in meters
# numLanes: number of lanes per road
# accel: The acceleration ability of vehicles in m/s^2.
# ```
#
# *A complete list of parmeters analysed is discussed in our report.*

# %%
def user_function_time_loss(X):
    """  X = inputs - emukit doesnt pass named args, just an NxM ndarray, N is the number of points to evaluate, M is the number of parameters per each point """
    result = []
    i = 0
    
    print(X)
    print(f'\nUser function time loss called with {X.shape[0]} inputs to simulate')

    
    for gridSize, edgeMaxSpeed, maxSpeed, edgeLength, numLanes, accel in X:
        print(f'\nEvaluating input: {i+1} of {X.shape[0]}\n')
        
        alpha = 0.005
        max_number_of_vehicles = ((gridSize - 1) * gridSize * 2 + 4 * gridSize) * edgeLength / 5
        period = 300/(max_number_of_vehicles * alpha)
        
        s = simulator.simulate(
            gridSize      = int(gridSize),
            edgeMaxSpeed  = edgeMaxSpeed,
            maxSpeed      = maxSpeed,
            edgeLength    = edgeLength,
            numberOfLanes = int(numLanes),
            accel         = accel,
            trips_generator_period = period
        )
        # average time loss / average route length
        result.append(s['timeLoss']/s['duration'])
        i += 1
        
    # expand dims is essential or the acquition function breaks
    return np.expand_dims(np.array(result), 1)

# %% [markdown]
# ### Model (GP)

# %% [markdown]
# Our surrogate model is our emulator. In this case, a gaussian process. I think that emukit handles categorical/discrete inputs using one-hot encodings.

# %% [markdown]
# #### Model Inputs

# %%
# gridSize = ContinuousParameter('gridSize', min_value=3, max_value=20)
# edgeMaxSpeed = ContinuousParameter('edgeMaxSpeed', min_value=1, max_value=25)
# maxSpeed = ContinuousParameter('maxSpeed', min_value=1, max_value=25)
# edgeLength = ContinuousParameter('edgeLength', min_value=30, max_value=200)
# numberOfLanes = DiscreteParameter('numberOfLanes', domain=[1,2,3])
# accel = ContinuousParameter('accel', 1., 6.)

# parameter_space = ParameterSpace([gridSize, edgeMaxSpeed, maxSpeed, edgeLength, numberOfLanes, accel])
import experimental_design.config as config
parameter_space = config.get_parameter_space()

# %% [markdown]
# #### Initialize Model / Emulator (GP)

# %%
#init_X, init_Y = pickle.load(open('experimental_design/init_points/25_init_points.pkl', 'rb'))

design = RandomDesign(parameter_space)  # initialize with random points
num_init_points = 20
init_X = design.get_samples(num_init_points)
init_Y = user_function_time_loss(init_X)
with open(f'experimental_design/init_points/{num_init_points}_init_points.pkl', "wb") as f:
      pickle.dump((init_X, init_Y), f)
# Out:
# [[18.         21.29471398 10.84159073 51.710595    1.          3.073451  ]
#  [10.         17.71015026 19.38865074 61.40277485  1.          3.61846045]
#  [ 3.         22.15671886 15.03720399 48.64065614  3.          1.90655573]
#  [17.         15.56086041 12.93259488 42.12967458  1.          1.58924423]
#  [13.         13.89272444 13.46640112 43.79690961  1.          1.9259444 ]
#  [17.         23.91929617 11.22955358 37.20167828  1.          1.94310127]
#  [ 4.         18.46026734  6.31239346 51.20928034  1.          2.49811022]
#  [19.         12.01943081 15.5602276  36.19001061  2.          1.99164107]
#  [14.         13.11477879 23.96213755 61.00858012  2.          4.06484513]
#  [12.         13.39800176 11.35340573 41.94600644  3.          4.24116715]
#  [ 7.         21.54224208  6.93008724 54.69510458  3.          3.32276322]
#  [10.         10.9497604  14.41182116 34.72894936  2.          2.57731689]
#  [15.         13.85158776  7.74701478 35.60437716  3.          3.54300043]
#  [ 4.         18.07582123 13.37258165 69.65233485  1.          4.00326349]
#  [ 9.          9.2706133  17.92473834 67.31240115  3.          1.87910589]
#  [18.         10.2479211  21.83644338 55.55327787  1.          4.21738926]
#  [17.         20.05137646 14.93696819 46.5709121   3.          4.55393702]
#  [11.         10.17057065 18.39942475 33.43549098  2.          3.4072704 ]
#  [11.         19.06483183  5.19563866 49.03362041  3.          1.92305022]
#  [13.          8.47807685  7.05458519 50.13158532  1.          3.91236805]]
#
# User function time loss called with 20 inputs to simulate
#
# Evaluating input: 1 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 6 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 7 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 8 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 9 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 10 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 11 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 12 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 13 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 14 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 15 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 16 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 17 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 18 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 19 of 20
#
#  Retrying in 1 seconds
#
# Evaluating input: 20 of 20
#
#  Retrying in 1 seconds

# %%
emulator = GPy.models.GPRegression(init_X, init_Y, noise_var=1e-10)
emukit_model = GPyModelWrapper(emulator, n_restarts=5)
emukit_model.optimize()
emulator
# Out:
# Optimization restart 1/5, f = -26.105669864682376
# Optimization restart 2/5, f = -0.689048801047667
# Optimization restart 3/5, f = -26.58451893080403
# Optimization restart 4/5, f = -0.689048801047937
# Optimization restart 5/5, f = -26.584518930804265
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -26.584518930804265<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>                 value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right>    0.0324030401455607</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>    16.674498119017887</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>0.00013215882025482766</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %% [markdown]
# ### Optimization

# %% [markdown]
# #### Acquisition Function

# %%
model_variance = ModelVariance(model=emukit_model)

# %% [markdown]
# #### Optimizer

# %%
optimizer = GradientAcquisitionOptimizer(parameter_space)

# %% [markdown]
# #### Experimental Design

# %%
ed_loop = ExperimentalDesignLoop(
    model = emukit_model,
    space = parameter_space,
    acquisition = model_variance,
    acquisition_optimizer = optimizer,
)

# %%
ed_loop.run_loop(user_function_time_loss, 200)
# Out:
# Optimization restart 1/5, f = -26.584518930804265
# Optimization restart 2/5, f = -0.6890488010479441
# Optimization restart 3/5, f = -20.587381025992233
# Optimization restart 4/5, f = -26.584518930796143
# Optimization restart 5/5, f = -26.584518930798247
# [[20.  8.  5. 70.  1.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/stationary.py:168: RuntimeWarning:overflow encountered in true_divide
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:76: RuntimeWarning:invalid value encountered in multiply
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -26.03080986028283
# Optimization restart 2/5, f = -0.655731849735016
# Optimization restart 3/5, f = -0.65573166339437
# Optimization restart 4/5, f = -0.6557316633979173
# Optimization restart 5/5, f = -26.030809860224757
# [[ 3. 25. 27. 30.  3.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -23.918184593131965
# Optimization restart 2/5, f = 1.595758927145491
# Optimization restart 3/5, f = 1.5957589433699049
# Optimization restart 4/5, f = 1.5957589421716332
# Optimization restart 5/5, f = -23.918184593153264
# [[20.  25.  27.  70.   3.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -22.858570813636497
# Optimization restart 2/5, f = 3.127924691805422
# Optimization restart 3/5, f = 3.1279247381515525
# Optimization restart 4/5, f = 3.1279247381515294
# Optimization restart 5/5, f = -22.85857081611604
# [[ 3.  25.   5.  30.   1.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -23.813232637747234
# Optimization restart 2/5, f = 2.8456592178401365
# Optimization restart 3/5, f = 2.8456606292201077
# Optimization restart 4/5, f = 2.8456596211493554
# Optimization restart 5/5, f = 2.845660768116643
# [[ 3.          8.         27.         48.75300796  1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -24.90147979057782
# Optimization restart 2/5, f = 2.619216742838301
# Optimization restart 3/5, f = 2.619217236208213
# Optimization restart 4/5, f = 2.6192060467142646
# Optimization restart 5/5, f = 2.6192139920429796
# [[ 3. 25. 27. 70.  3.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -26.077330393657185
# Optimization restart 2/5, f = 3.61513594572501
# Optimization restart 3/5, f = 3.6151365228887347
# Optimization restart 4/5, f = 3.6151365033656706
# Optimization restart 5/5, f = -26.077330393660148
# [[20.  25.  27.  30.   1.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -25.8225799097099
# Optimization restart 2/5, f = 5.593647097453854
# Optimization restart 3/5, f = -16.13994798310974
# Optimization restart 4/5, f = -25.82257990971351
# Optimization restart 5/5, f = 5.593647097454234
# [[20. 25.  5. 70.  3.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/stationary.py:168: RuntimeWarning:overflow encountered in true_divide
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:76: RuntimeWarning:invalid value encountered in multiply
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -27.04295599995865
# Optimization restart 2/5, f = 5.655770070617647
# Optimization restart 3/5, f = -27.042955999961045
# Optimization restart 4/5, f = 5.655770038435039
# Optimization restart 5/5, f = -27.042955999955957
# [[ 3.   8.   5.  70.   3.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -28.37583671963636
# Optimization restart 2/5, f = 5.398360984191868
# Optimization restart 3/5, f = -28.375836719697396
# Optimization restart 4/5, f = 5.398360984191875
# Optimization restart 5/5, f = 5.398360984191942
# [[20.        25.        27.        49.0040198  3.         1.5      ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -29.765093631515278
# Optimization restart 2/5, f = 6.902718385022171
# Optimization restart 3/5, f = 6.902712150349062
# Optimization restart 4/5, f = 6.902718384941444
# Optimization restart 5/5, f = 6.902718359219733
# [[20.  8. 27. 30.  1.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -31.059162134934063
# Optimization restart 2/5, f = 6.86914563590908
# Optimization restart 3/5, f = 6.869145635928071
# Optimization restart 4/5, f = -31.05916213518114
# Optimization restart 5/5, f = 6.869145635927234
# [[ 3.   8.  27.  30.   3.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -32.528131409947605
# Optimization restart 2/5, f = -32.52813140853131
# Optimization restart 3/5, f = 6.771487204696122
# Optimization restart 4/5, f = -32.528131409945345
# Optimization restart 5/5, f = -29.759877311097416
# [[ 3.  8. 27. 70.  1.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -32.07256140491439
# Optimization restart 2/5, f = -32.072561415204106
# Optimization restart 3/5, f = 6.664254688421412
# Optimization restart 4/5, f = 6.664259100309945
# Optimization restart 5/5, f = -32.072561415332785
# [[ 3.   8.   5.  30.   1.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -33.56775845697632
# Optimization restart 2/5, f = 6.43883171027084
# Optimization restart 3/5, f = -33.567758457007045
# Optimization restart 4/5, f = 6.438832581634411
# Optimization restart 5/5, f = 6.438832581634411
# [[20.   8.  27.  70.   1.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -35.030041735322285
# Optimization restart 2/5, f = -35.03004173540066
# Optimization restart 3/5, f = 6.177596592640693
# Optimization restart 4/5, f = -35.030041734367785
# Optimization restart 5/5, f = -35.03004173538095
# [[ 3.  25.   5.  70.   3.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -36.405775823276414
# Optimization restart 2/5, f = 5.898510967746507
# Optimization restart 3/5, f = 5.898510458436082
# Optimization restart 4/5, f = 5.898510967746503
# Optimization restart 5/5, f = 5.89850938457419
# [[20. 25.  5. 30.  3.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -33.950977419252794
# Optimization restart 2/5, f = 6.115915471880424
# Optimization restart 3/5, f = 6.115915471880367
# Optimization restart 4/5, f = 6.115915471880395
# Optimization restart 5/5, f = -33.95097741969952
# [[ 3.         25.         27.         50.03915711  1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -35.476211426489954
# Optimization restart 2/5, f = 8.05986859074783
# Optimization restart 3/5, f = 8.059868590747698
# Optimization restart 4/5, f = -35.47621142650291
# Optimization restart 5/5, f = -35.47621142647101
# [[20.   8.   5.  30.   1.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -36.11641299426684
# Optimization restart 2/5, f = -36.116412994330375
# Optimization restart 3/5, f = -36.116412994354775
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
# Optimization restart 4/5, f = -36.116412992008534
# Optimization restart 5/5, f = -36.116412993248446
# [[20.          8.          5.         55.65418484  3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -37.81874989170119
# Optimization restart 2/5, f = 7.570582359462708
# Optimization restart 3/5, f = -37.81874989204016
# Optimization restart 4/5, f = 7.570582805457832
# Optimization restart 5/5, f = 7.570582807211121
# [[ 3.         8.         5.        52.5337372  3.         5.       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -38.514122250135614
# Optimization restart 2/5, f = -38.51412225019725
# Optimization restart 3/5, f = -38.51412225019659
# Optimization restart 4/5, f = -38.51412225017775
# Optimization restart 5/5, f = 7.594037192750633
# [[20.          8.         27.         46.05643299  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -39.7698124821231
# Optimization restart 2/5, f = -39.76981248219394
# Optimization restart 3/5, f = 7.5067149396030075
# Optimization restart 4/5, f = 7.506714939603043
# Optimization restart 5/5, f = 7.506714922369973
# [[20.  25.   5.  70.   1.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -39.69281957631227
# Optimization restart 2/5, f = 7.22148574250901
# Optimization restart 3/5, f = 7.221485742509007
# Optimization restart 4/5, f = 7.221485742508733
# Optimization restart 5/5, f = -39.69281957636401
# [[ 3.          8.         27.         45.35380689  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -41.50336095752037
# Optimization restart 2/5, f = -41.50336095875713
# Optimization restart 3/5, f = 7.14879931910157
# Optimization restart 4/5, f = 7.148796207077826
# Optimization restart 5/5, f = -41.50336095876531
# [[20.         25.         20.90532648 70.          3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -42.472629768829464
# Optimization restart 2/5, f = 7.611570732948209
# Optimization restart 3/5, f = 7.611570732948234
# Optimization restart 4/5, f = -42.47262976979056
# Optimization restart 5/5, f = -42.47262976979621
# [[20. 25. 27. 30.  3.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -43.73298420143132
# Optimization restart 2/5, f = 9.056475487508873
# Optimization restart 3/5, f = 9.056476706743101
# Optimization restart 4/5, f = -43.73298420153847
# Optimization restart 5/5, f = 9.056476937873605
# [[20.         25.          5.         48.69580848  3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -45.52736916654937
# Optimization restart 2/5, f = -45.52736916524712
# Optimization restart 3/5, f = 8.7962331262401
# Optimization restart 4/5, f = -45.527369165468386
# Optimization restart 5/5, f = -45.527369166173486
# [[ 3. 25.  5. 30.  3.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -46.65603537081164
# Optimization restart 2/5, f = -46.65603537743681
# Optimization restart 3/5, f = -46.656035377482084
# Optimization restart 4/5, f = 8.881192808676118
# Optimization restart 5/5, f = 8.881192808676118
# [[ 3.         25.         19.10760774 30.          1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -47.70763155649668
# Optimization restart 2/5, f = 10.302571506411269
# Optimization restart 3/5, f = 10.30256383753375
# Optimization restart 4/5, f = 10.302571506410903
# Optimization restart 5/5, f = -47.707631556474425
# [[ 3.         25.          5.         52.28188253  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -48.608995604418965
# Optimization restart 2/5, f = 10.375143819288429
# Optimization restart 3/5, f = 10.375144227800167
# Optimization restart 4/5, f = 10.375144227800178
# Optimization restart 5/5, f = 10.375144227800149
# [[13.   8.  27.  70.   3.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -50.42468483111372
# Optimization restart 2/5, f = -50.42468483292397
# Optimization restart 3/5, f = -50.424684832928904
# Optimization restart 4/5, f = 10.135293889153001
# Optimization restart 5/5, f = 10.135293865839536
# [[ 3.  25.  27.  70.   1.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -50.35507441702916
# Optimization restart 2/5, f = 11.778901732525004
# Optimization restart 3/5, f = 11.778901732525195
# Optimization restart 4/5, f = 11.77890173252495
# Optimization restart 5/5, f = 11.778901665762412
# [[20.  8.  5. 30.  1.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -51.46348818481329
# Optimization restart 2/5, f = -51.46348819016745
# Optimization restart 3/5, f = 11.846105976894101
# Optimization restart 4/5, f = 11.846105976905022
# Optimization restart 5/5, f = 11.8461055088679
# [[20.         25.         27.         53.01444979  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -52.648357828195664
# Optimization restart 2/5, f = 12.768078952223632
# Optimization restart 3/5, f = 12.76807895222364
# Optimization restart 4/5, f = -52.648357827382725
# Optimization restart 5/5, f = 12.768078931047473
# [[20.          8.         16.90891255 70.          3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -54.42157392518145
# Optimization restart 2/5, f = 12.682054276159477
# Optimization restart 3/5, f = -54.42157392780016
# Optimization restart 4/5, f = 12.68205427945782
# Optimization restart 5/5, f = 12.682054279446263
# [[ 3.  8.  5. 30.  3.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -55.60534911809306
# Optimization restart 2/5, f = -55.6053491184598
# Optimization restart 3/5, f = 12.777220651632284
# Optimization restart 4/5, f = 12.777220651632348
# Optimization restart 5/5, f = -40.308154371438185
# [[ 3.  25.  27.  30.   3.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -57.2192629261699
# Optimization restart 2/5, f = 14.513248939411401
# Optimization restart 3/5, f = -57.219262926206
# Optimization restart 4/5, f = -57.219262926341486
# Optimization restart 5/5, f = -57.21926292613225
# [[ 3.         15.06005353 27.         61.93940784  3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -58.25735002809523
# Optimization restart 2/5, f = 15.08722053952356
# Optimization restart 3/5, f = 15.087220539564107
# Optimization restart 4/5, f = 15.08722025504192
# Optimization restart 5/5, f = 15.087220539445688
# [[20.         19.68701421 27.         70.          1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -59.66945799702245
# Optimization restart 2/5, f = -59.669457986716914
# Optimization restart 3/5, f = 15.78628063617257
# Optimization restart 4/5, f = -59.66945799702838
# Optimization restart 5/5, f = -59.669457997013936
# [[ 3.  8.  5. 70.  1.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -60.95115480268951
# Optimization restart 2/5, f = -60.951154802898145
# Optimization restart 3/5, f = 15.85070764786758
# Optimization restart 4/5, f = -60.95115480294423
# Optimization restart 5/5, f = -60.95115480296933
# [[20.          8.         27.         45.56898842  1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -62.72394021537595
# Optimization restart 2/5, f = 15.688857250644432
# Optimization restart 3/5, f = 15.688856724354405
# Optimization restart 4/5, f = -62.723940219022666
# Optimization restart 5/5, f = 15.688855095002303
# [[20.   8.  27.  30.   3.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -64.002271623455
# Optimization restart 2/5, f = -64.00227162368077
# Optimization restart 3/5, f = -64.00227162321045
# Optimization restart 4/5, f = 15.825269387672943
# Optimization restart 5/5, f = 15.825269387666204
# [[ 3.         25.         27.         45.21668153  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -65.08139917989652
# Optimization restart 2/5, f = 17.07318893469757
# Optimization restart 3/5, f = 17.07316642926456
# Optimization restart 4/5, f = 17.073189402124886
# Optimization restart 5/5, f = 17.073189402120835
# [[ 3.  8. 27. 30.  1.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -66.8924380694694
# Optimization restart 2/5, f = 17.03446770686601
# Optimization restart 3/5, f = 17.034461821024934
# Optimization restart 4/5, f = -66.89245021230693
# Optimization restart 5/5, f = 17.034467706869485
# [[ 9.  25.   5.  70.   1.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -68.75071786681936
# Optimization restart 2/5, f = 16.83445269202918
# Optimization restart 3/5, f = 16.834432098943047
# Optimization restart 4/5, f = 16.834452692027867
# Optimization restart 5/5, f = 16.834452692028293
# [[ 3.          8.         15.80223803 54.1580492   1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -70.55481770229017
# Optimization restart 2/5, f = -70.55481770242292
# Optimization restart 3/5, f = -70.55481770223744
# Optimization restart 4/5, f = -70.55481770225694
# Optimization restart 5/5, f = 16.775302351718118
# [[ 3. 25.  5. 70.  3.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -71.67559177743568
# Optimization restart 2/5, f = -71.6755916673161
# Optimization restart 3/5, f = 16.831891960184493
# Optimization restart 4/5, f = -71.67559177701231
# Optimization restart 5/5, f = 16.83189203370852
# [[20.         16.17283325 17.5702403  30.          3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -73.68816863455399
# Optimization restart 2/5, f = 17.364354086336064
# Optimization restart 3/5, f = 17.36435408520537
# Optimization restart 4/5, f = 17.36435408614401
# Optimization restart 5/5, f = 17.364353876694032
# [[20.  8.  5. 70.  3.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -75.59452197037865
# Optimization restart 2/5, f = -75.59452196774456
# Optimization restart 3/5, f = -75.59452197359293
# Optimization restart 4/5, f = -75.59452197278766
# Optimization restart 5/5, f = -75.59452197364655
# [[20.  25.   5.  30.   1.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -76.65009513817117
# Optimization restart 2/5, f = -76.65009514060316
# Optimization restart 3/5, f = -76.65009514059025
# Optimization restart 4/5, f = 17.24074037384043
# Optimization restart 5/5, f = 17.24074037386965
# [[20.         11.97305401 27.         70.          3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -78.66364243934422
# Optimization restart 2/5, f = 17.218486623862105
# Optimization restart 3/5, f = -78.663642442297
# Optimization restart 4/5, f = 17.218486623862105
# Optimization restart 5/5, f = -78.66364244228697
# [[12. 25. 27. 70.  1.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -79.78741726606853
# Optimization restart 2/5, f = -75.83407565851323
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/stationary.py:168: RuntimeWarning:overflow encountered in true_divide
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:76: RuntimeWarning:invalid value encountered in multiply
# Optimization restart 3/5, f = -79.78741726743067
# Optimization restart 4/5, f = -79.78741726742085
# Optimization restart 5/5, f = -79.78741726713795
# [[20.          8.         11.93243393 70.          1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -81.61846153705636
# Optimization restart 2/5, f = -81.61846153976272
# Optimization restart 3/5, f = -81.61846153976455
# Optimization restart 4/5, f = -81.61846153966755
# Optimization restart 5/5, f = -81.6184615397649
# [[ 3.         25.         16.13024861 70.          1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -82.93185016530137
# Optimization restart 2/5, f = -82.9318501652677
# Optimization restart 3/5, f = -82.93185016528724
# Optimization restart 4/5, f = 18.245957335158444
# Optimization restart 5/5, f = 18.245957335668706
# [[20.         20.1956091   5.         42.33798072  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -84.34373898389774
# Optimization restart 2/5, f = 18.31521628765445
# Optimization restart 3/5, f = -84.34373898833655
# Optimization restart 4/5, f = -84.3437389883482
# Optimization restart 5/5, f = -84.34373898800973
# [[ 3.          8.          5.         56.07461772  1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -86.43701871134952
# Optimization restart 2/5, f = -86.43701871124412
# Optimization restart 3/5, f = -86.43701871142717
# Optimization restart 4/5, f = -86.43701871144197
# Optimization restart 5/5, f = -86.43701870935051
# [[ 3.         25.          5.         35.82703877  3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -88.31860653320827
# Optimization restart 2/5, f = -88.31860653319839
# Optimization restart 3/5, f = 17.914971398090955
# Optimization restart 4/5, f = -88.3186065326493
# Optimization restart 5/5, f = -88.31860653316332
# [[11.         17.12118294 27.         30.          1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -89.6088050461419
# Optimization restart 2/5, f = -89.60880504572806
# Optimization restart 3/5, f = -89.60880504581138
# Optimization restart 4/5, f = -89.60880504613881
# Optimization restart 5/5, f = -89.60880504565073
# [[20.         25.          8.02659296 70.          1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -91.03361076132015
# Optimization restart 2/5, f = -91.03361076063169
# Optimization restart 3/5, f = 18.839470346104427
# Optimization restart 4/5, f = -91.03361076110374
# Optimization restart 5/5, f = 18.839470345898754
# [[13.         25.          5.         41.85286539  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -92.24536162957676
# Optimization restart 2/5, f = -92.24536163530766
# Optimization restart 3/5, f = -92.24536163514489
# Optimization restart 4/5, f = -92.24536144772529
# Optimization restart 5/5, f = -92.24536163532119
# [[20.          8.          5.         34.65077395  3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -94.32061136592205
# Optimization restart 2/5, f = 18.700335213091492
# Optimization restart 3/5, f = -94.32061135885147
# Optimization restart 4/5, f = -94.3206113663245
# Optimization restart 5/5, f = -94.32061136578935
# [[13.         25.         15.80209924 30.          3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -95.38887241543004
# Optimization restart 2/5, f = -95.38887241545196
# Optimization restart 3/5, f = -95.38887241548363
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
# Optimization restart 4/5, f = -95.3888724150253
# Optimization restart 5/5, f = -95.3888724152
# [[ 3.         16.53637115 27.         30.          1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -95.7296779448949
# Optimization restart 2/5, f = -95.72967706672749
# Optimization restart 3/5, f = -95.72967793880008
# Optimization restart 4/5, f = 20.452487002959714
# Optimization restart 5/5, f = 20.452486980442714
# [[20.         16.07522837  5.         70.          3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -97.14162017099164
# Optimization restart 2/5, f = -97.14162017148007
# Optimization restart 3/5, f = 20.234649610248646
# Optimization restart 4/5, f = 20.234648481329096
# Optimization restart 5/5, f = 20.234649610248304
# [[ 3.   8.  27.  70.   3.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -98.86061339546626
# Optimization restart 2/5, f = 20.065933276896345
# Optimization restart 3/5, f = -98.86061339557594
# Optimization restart 4/5, f = -98.86061339564301
# Optimization restart 5/5, f = -98.86061339524345
# [[ 3.          8.         13.88404386 30.          1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -100.25814593538908
# Optimization restart 2/5, f = -100.25814593528258
# Optimization restart 3/5, f = -100.25814583105821
# Optimization restart 4/5, f = -100.25814584311931
# Optimization restart 5/5, f = -100.25814593488988
# [[20.         25.         15.43434062 30.          3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -101.09881326785631
# Optimization restart 2/5, f = -101.09881326773458
# Optimization restart 3/5, f = 20.78726686571271
# Optimization restart 4/5, f = -101.09881326700173
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/stationary.py:168: RuntimeWarning:overflow encountered in true_divide
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:76: RuntimeWarning:invalid value encountered in multiply
# Optimization restart 5/5, f = -67.6776833563602
# [[ 3.         15.97174191  5.         30.          1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -102.46097341043173
# Optimization restart 2/5, f = -102.4609734105065
# Optimization restart 3/5, f = -102.46097341062566
# Optimization restart 4/5, f = -102.46097341057703
# Optimization restart 5/5, f = -102.4609734058943
# [[20.         25.         17.46342535 64.24671735  3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -103.45950065949734
# Optimization restart 2/5, f = 21.335879778562102
# Optimization restart 3/5, f = -103.45971607158936
# Optimization restart 4/5, f = -103.45971607158617
# Optimization restart 5/5, f = -103.45971607157611
# [[ 3.         12.65142968 17.05935546 70.          3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -105.17159896269072
# Optimization restart 2/5, f = -105.17159896257185
# Optimization restart 3/5, f = -105.17159896198336
# Optimization restart 4/5, f = -105.17159896193766
# Optimization restart 5/5, f = 21.328550972016508
# [[ 3.         25.          5.         63.48201869  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -107.00186343391579
# Optimization restart 2/5, f = -107.00200674973097
# Optimization restart 3/5, f = 21.40021066571687
# Optimization restart 4/5, f = 21.40021035572012
# Optimization restart 5/5, f = -107.00200675435158
# [[20.         25.         27.         47.49403684  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -109.11124490432698
# Optimization restart 2/5, f = -109.11150149434951
# Optimization restart 3/5, f = -109.11150158086008
# Optimization restart 4/5, f = -109.11150158090541
# Optimization restart 5/5, f = -109.11150157161305
# [[20.          8.          5.         48.65648198  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -110.92283410376697
# Optimization restart 2/5, f = 22.510318622687585
# Optimization restart 3/5, f = -110.92283534326066
# Optimization restart 4/5, f = 22.51031862596161
# Optimization restart 5/5, f = -110.92283531823134
# [[ 6.        25.        27.        52.3473966  3.         1.5      ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -113.06519284716194
# Optimization restart 2/5, f = -113.06519284388486
# Optimization restart 3/5, f = 24.004444629957078
# Optimization restart 4/5, f = -113.06519284718392
# Optimization restart 5/5, f = 24.004444629097712
# [[20.          8.         20.05256422 59.64807496  3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -115.21142045542427
# Optimization restart 2/5, f = -115.21143418524763
# Optimization restart 3/5, f = -115.21143417969287
# Optimization restart 4/5, f = -115.2114341863003
# Optimization restart 5/5, f = -115.21143418639888
# [[ 3.          8.         16.72012396 30.          3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -117.33334930323123
# Optimization restart 2/5, f = -117.33361772699571
# Optimization restart 3/5, f = -117.3336177254845
# Optimization restart 4/5, f = -117.33361772372771
# Optimization restart 5/5, f = -117.33361772692248
# [[20.  25.   5.  30.   1.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -119.04551839454062
# Optimization restart 2/5, f = 15.812522518916737
# Optimization restart 3/5, f = -103.56138061750738
# Optimization restart 4/5, f = -103.5613804933754
# Optimization restart 5/5, f = 15.812522124349442
# [[ 3.          8.         18.33912026 70.          1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -121.09227367839274
# Optimization restart 2/5, f = -105.586198351084
# Optimization restart 3/5, f = -105.58620020011156
# Optimization restart 4/5, f = -105.58619829681996
# Optimization restart 5/5, f = -105.58620020051472
# [[11.  8. 27. 30.  3.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -122.63092428993914
# Optimization restart 2/5, f = -103.98062614335731
# Optimization restart 3/5, f = 15.720635513673805
# Optimization restart 4/5, f = -103.98062614298101
# Optimization restart 5/5, f = 15.720633515775702
# [[12.  8.  5. 70.  1.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -124.3851268986594
# Optimization restart 2/5, f = -106.01239039137172
# Optimization restart 3/5, f = -106.01239160740789
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/stationary.py:168: RuntimeWarning:overflow encountered in true_divide
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:76: RuntimeWarning:invalid value encountered in multiply
# Optimization restart 4/5, f = -81.17671285185565
# Optimization restart 5/5, f = -106.01238204704586
# [[ 3.         17.48719059 27.         52.30619069  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -126.11070121848118
# Optimization restart 2/5, f = 16.218286728760226
# Optimization restart 3/5, f = 16.21828743239592
# Optimization restart 4/5, f = 16.218286754171913
# Optimization restart 5/5, f = -107.12650288400182
# [[20.   8.  27.  30.   1.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -126.42814758467328
# Optimization restart 2/5, f = -107.42201248462553
# Optimization restart 3/5, f = -126.42814778615512
# Optimization restart 4/5, f = -107.42201262661212
# Optimization restart 5/5, f = 16.083509111964062
# [[10.         15.03918566  5.         30.          3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -127.59600276977838
# Optimization restart 2/5, f = -105.5784410630541
# Optimization restart 3/5, f = 16.340064888019867
# Optimization restart 4/5, f = 16.340060862706977
# Optimization restart 5/5, f = -117.03532862695165
# [[20.         18.03182559 27.         30.          1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/stationary.py:168: RuntimeWarning:overflow encountered in true_divide
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:76: RuntimeWarning:invalid value encountered in multiply
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -129.70643505082353
# Optimization restart 2/5, f = -107.3556785839671
# Optimization restart 3/5, f = 17.084816640938143
# Optimization restart 4/5, f = 17.084863296120794
# Optimization restart 5/5, f = -107.35567869742019
# [[ 3.          8.          5.         43.69948204  3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -131.8213299270283
# Optimization restart 2/5, f = -108.10095291309696
# Optimization restart 3/5, f = -108.10086792926788
# Optimization restart 4/5, f = -108.1009529130539
# Optimization restart 5/5, f = -108.10095291266994
# [[16.         25.          5.         62.62316658  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -132.91305252182156
# Optimization restart 2/5, f = -109.71569864599329
# Optimization restart 3/5, f = -109.71571288881276
# Optimization restart 4/5, f = -132.91305252330295
# Optimization restart 5/5, f = 16.958895082626753
# [[14.   8.   5.  30.   3.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -132.02366286839043
# Optimization restart 2/5, f = -110.49847616335724
# Optimization restart 3/5, f = 17.002163722713426
# Optimization restart 4/5, f = -110.49847556282869
# Optimization restart 5/5, f = 17.0021723249059
# [[ 7.         19.36944937 27.         70.          3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -134.0999186510039
# Optimization restart 2/5, f = 17.542152307273255
# Optimization restart 3/5, f = -112.66421889965712
# Optimization restart 4/5, f = -112.66421889973284
# Optimization restart 5/5, f = -112.66421745129674
# [[11.          8.         27.         58.09854957  3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -136.17775760454134
# Optimization restart 2/5, f = -113.054926553034
# Optimization restart 3/5, f = -136.17779814454042
# Optimization restart 4/5, f = -113.05509392721113
# Optimization restart 5/5, f = -113.05508985263677
# [[ 8.   8.   5.  70.   3.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -138.31331255741173
# Optimization restart 2/5, f = 17.13610206376991
# Optimization restart 3/5, f = -115.89242870286648
# Optimization restart 4/5, f = -115.89242870358052
# Optimization restart 5/5, f = 17.13610124750288
# [[20.          8.         22.83297842 36.15467203  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -140.49333810817876
# Optimization restart 2/5, f = 17.123808592129237
# Optimization restart 3/5, f = -117.62093141604592
# Optimization restart 4/5, f = 17.123799672018855
# Optimization restart 5/5, f = 17.1237448982941
# [[ 3. 25. 27. 70.  1.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -142.24053843775746
# Optimization restart 2/5, f = -120.1280307010056
# Optimization restart 3/5, f = 18.026557980693312
# Optimization restart 4/5, f = 18.026564638967955
# Optimization restart 5/5, f = -120.12803088141109
# [[ 3.  25.  27.  30.   1.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -144.30521289784423
# Optimization restart 2/5, f = -144.30521289784397
# Optimization restart 3/5, f = -122.49195621402323
# Optimization restart 4/5, f = -144.30521289789297
# Optimization restart 5/5, f = -122.49220093751188
# [[12.  25.  27.  30.   1.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -146.46720632017477
# Optimization restart 2/5, f = -146.46720632218683
# Optimization restart 3/5, f = -146.46720632221405
# Optimization restart 4/5, f = -146.46720632211355
# Optimization restart 5/5, f = -124.964265628304
# [[20.  8. 27. 70.  1.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -147.4981999816356
# Optimization restart 2/5, f = -126.02633892017823
# Optimization restart 3/5, f = -126.02645657196136
# Optimization restart 4/5, f = 21.730610814945457
# Optimization restart 5/5, f = -147.49819998217316
# [[ 3.         16.02837754  5.         70.          1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -149.64113793005143
# Optimization restart 2/5, f = -127.49857357651504
# Optimization restart 3/5, f = -127.49858345355075
# Optimization restart 4/5, f = -127.49858368239674
# Optimization restart 5/5, f = 21.792490512515094
# [[ 3.         19.15840711 27.         70.          3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -150.02832168225592
# Optimization restart 2/5, f = -129.94667603191215
# Optimization restart 3/5, f = 22.845559017208025
# Optimization restart 4/5, f = -150.02832168224256
# Optimization restart 5/5, f = 22.84554851503625
# [[ 3.         25.         13.26892112 34.32003702  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -150.5799167520717
# Optimization restart 2/5, f = -130.03676243740335
# Optimization restart 3/5, f = -130.0367620777181
# Optimization restart 4/5, f = -130.0367621445959
# Optimization restart 5/5, f = -130.0367624374117
# [[ 3.          8.          5.         42.57303072  3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -152.73457297364124
# Optimization restart 2/5, f = -133.08276327145938
# Optimization restart 3/5, f = -152.73457467558222
# Optimization restart 4/5, f = -133.0827632714399
# Optimization restart 5/5, f = -133.0827608833529
# [[20.         25.         27.         62.34783401  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -154.86586648388834
# Optimization restart 2/5, f = 23.70329050430186
# Optimization restart 3/5, f = -154.86590715220743
# Optimization restart 4/5, f = -154.8659071527433
# Optimization restart 5/5, f = -135.23472939648232
# [[20.         18.48720773  5.         62.56550418  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -156.8680784841892
# Optimization restart 2/5, f = -136.36626271440554
# Optimization restart 3/5, f = -136.3662559463233
# Optimization restart 4/5, f = -136.3662666193299
# Optimization restart 5/5, f = -136.3662668254597
# [[20.          8.         10.28941836 30.          1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -158.6653586464342
# Optimization restart 2/5, f = -138.48366879615378
# Optimization restart 3/5, f = -138.483668796141
# Optimization restart 4/5, f = -138.4836687962001
# Optimization restart 5/5, f = -158.66535864530368
# [[20.         11.12679013  5.         62.01557164  1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -160.80166511969736
# Optimization restart 2/5, f = -140.73223511945696
# Optimization restart 3/5, f = -140.73223529213593
# Optimization restart 4/5, f = -160.80186970034504
# Optimization restart 5/5, f = -160.8018697025853
# [[20.         22.27355881 14.46587456 70.          3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -162.13431050368524
# Optimization restart 2/5, f = -162.13436621106058
# Optimization restart 3/5, f = -140.8246248119275
# Optimization restart 4/5, f = -140.82442294545592
# Optimization restart 5/5, f = -162.13436620398292
# [[20.         18.24810376  5.         30.          3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -163.3408158775937
# Optimization restart 2/5, f = -137.55458857611777
# Optimization restart 3/5, f = -137.55458914856948
# Optimization restart 4/5, f = -137.5545891485375
# Optimization restart 5/5, f = -163.34081587777638
# [[17.        25.        27.        43.3049413  3.         1.5      ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -165.47094112632115
# Optimization restart 2/5, f = -139.4566991258932
# Optimization restart 3/5, f = -139.45672417955242
# Optimization restart 4/5, f = -139.45655451727356
# Optimization restart 5/5, f = -165.47094112070795
# [[ 3.         25.         17.67650097 60.46643362  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -167.37879151544738
# Optimization restart 2/5, f = -167.37879151547187
# Optimization restart 3/5, f = -167.37879151472103
# Optimization restart 4/5, f = -167.3787915150677
# Optimization restart 5/5, f = -139.88885343884186
# [[ 8.  8.  5. 70.  3.  5.]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -169.39072631027378
# Optimization restart 2/5, f = -169.39086862606226
# Optimization restart 3/5, f = -142.6697200299197
# Optimization restart 4/5, f = -142.66965571970306
# Optimization restart 5/5, f = -142.66964630053866
# [[20.         19.48745184 27.         70.          1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -171.52764066290956
# Optimization restart 2/5, f = -145.1740641044106
# Optimization restart 3/5, f = -145.17404976348882
# Optimization restart 4/5, f = -145.1740566885403
# Optimization restart 5/5, f = -145.17406303120953
# [[20.          8.          5.         46.03010456  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -173.70886787505893
# Optimization restart 2/5, f = -147.7043636515388
# Optimization restart 3/5, f = -147.61170794102387
# Optimization restart 4/5, f = -147.70418692189446
# Optimization restart 5/5, f = -173.70889407329588
# [[ 3.         25.         18.12232874 36.65225177  1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# ...
# Optimization restart 4/5, f = -266.46707900921325
# Optimization restart 5/5, f = -242.14008643613926
# [[ 3.         25.         18.29560753 70.          3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -267.3524382588845
# Optimization restart 2/5, f = -244.32856903031802
# Optimization restart 3/5, f = -267.35243827474824
# Optimization restart 4/5, f = -244.32856939365126
# Optimization restart 5/5, f = -244.32856897243835
# [[20.          8.         13.49090056 46.7563953   1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -269.33313700348447
# Optimization restart 2/5, f = -269.3331370024499
# Optimization restart 3/5, f = -244.98801244088145
# Optimization restart 4/5, f = -269.3331370034433
# Optimization restart 5/5, f = -269.33313699181684
# [[13.         25.         24.76069677 30.          3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -271.58309988379574
# Optimization restart 2/5, f = -271.5830998845279
# Optimization restart 3/5, f = -247.8985278987775
# Optimization restart 4/5, f = -247.8985282139629
# Optimization restart 5/5, f = -271.58309988435406
# [[20.         16.08940906  5.         30.          1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -272.8290824572548
# Optimization restart 2/5, f = -249.43853200181422
# Optimization restart 3/5, f = -249.43853200304977
# Optimization restart 4/5, f = -249.20412830419178
# Optimization restart 5/5, f = -272.8290824591256
# [[ 3.         25.         18.67641915 58.42825056  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -274.3165233472239
# Optimization restart 2/5, f = -274.3166305127512
# Optimization restart 3/5, f = -274.3166305143353
# Optimization restart 4/5, f = -274.3166305141941
# Optimization restart 5/5, f = -251.26380991344155
# [[10.         25.         27.         40.17600404  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -276.3194040294107
# Optimization restart 2/5, f = -276.3194040295487
# Optimization restart 3/5, f = -276.31940402953495
# Optimization restart 4/5, f = -276.31940402644636
# Optimization restart 5/5, f = -276.31940402950505
# [[20.         17.18429456 19.97274505 70.          3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -278.551623949896
# Optimization restart 2/5, f = -278.5519594713599
# Optimization restart 3/5, f = -254.93660713624456
# Optimization restart 4/5, f = -278.55195947038544
# Optimization restart 5/5, f = -278.551959472537
# [[ 3.         25.          5.         49.29092557  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -280.44304730150225
# Optimization restart 2/5, f = -257.038790055692
# Optimization restart 3/5, f = -256.4448961007249
# Optimization restart 4/5, f = -257.0387330690176
# Optimization restart 5/5, f = -280.44304729414
# [[ 3.          8.         27.         36.74323426  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -282.7315532556444
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
# Optimization restart 2/5, f = -282.73155325713736
# Optimization restart 3/5, f = -282.73155325678243
# Optimization restart 4/5, f = -282.7315532574214
# Optimization restart 5/5, f = -259.103352544229
# [[ 8.          8.          5.         40.63740714  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -284.85276098927204
# Optimization restart 2/5, f = -284.85289602482277
# Optimization restart 3/5, f = -260.8516947519191
# Optimization restart 4/5, f = -260.85170304539224
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
# Optimization restart 5/5, f = -284.85289602255966
# [[ 3.        25.        14.3770199 30.         1.         1.5      ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -284.7706936553038
# Optimization restart 2/5, f = -284.7706937080191
# Optimization restart 3/5, f = -261.42851463199423
# Optimization restart 4/5, f = -284.77069370777826
# Optimization restart 5/5, f = -284.77069370805617
# [[ 3.         19.78868016  5.         35.53306267  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -287.0984838562038
# Optimization restart 2/5, f = -287.09848385634086
# Optimization restart 3/5, f = -263.44135960101175
# Optimization restart 4/5, f = -263.44136300357854
# Optimization restart 5/5, f = -263.4413504693723
# [[20.         16.74424004 27.         46.25612633  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -289.37419584380916
# Optimization restart 2/5, f = -289.37427078510314
# Optimization restart 3/5, f = -265.7195545252263
# Optimization restart 4/5, f = -265.71955505108883
# Optimization restart 5/5, f = -265.7195540711913
# [[12.          8.          5.         59.25183344  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -291.6686892577209
# Optimization restart 2/5, f = -267.77508980871465
# Optimization restart 3/5, f = -267.77508362649456
# Optimization restart 4/5, f = -267.7750781830693
# Optimization restart 5/5, f = -291.66883757581104
# [[11.         25.         22.69229143 47.51686026  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -293.69226656048454
# Optimization restart 2/5, f = -268.8041122360672
# Optimization restart 3/5, f = -268.8040627404341
# Optimization restart 4/5, f = -293.69226656064484
# Optimization restart 5/5, f = -293.69226656061824
# [[ 3.   8.   5.  30.   3.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -295.62859878180495
# Optimization restart 2/5, f = -267.24886264808765
# Optimization restart 3/5, f = -295.6285987806285
# Optimization restart 4/5, f = -267.2490228796828
# Optimization restart 5/5, f = -295.62859878210367
# [[13.          8.         21.47712005 30.          1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -297.3859745129208
# Optimization restart 2/5, f = -269.90179904327584
# Optimization restart 3/5, f = -297.38597449112154
# Optimization restart 4/5, f = -269.90179637095144
# Optimization restart 5/5, f = -297.3859745147398
# [[20.         25.         14.23785227 70.          1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -298.71673093801223
# Optimization restart 2/5, f = -298.7167309458998
# Optimization restart 3/5, f = -298.71673094588044
# Optimization restart 4/5, f = -298.716730937236
# Optimization restart 5/5, f = -272.57780261630626
# [[20.         25.         19.50434733 43.02154227  1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -299.70461299574174
# Optimization restart 2/5, f = -273.6546862137985
# Optimization restart 3/5, f = -273.6546858429323
# Optimization restart 4/5, f = -299.704613008701
# Optimization restart 5/5, f = -273.654686026597
# [[15.          8.         27.         66.11490599  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -301.262208241397
# Optimization restart 2/5, f = -301.2622082461604
# Optimization restart 3/5, f = -276.2282088789139
# Optimization restart 4/5, f = -276.2282073080756
# Optimization restart 5/5, f = -276.2282081142154
# [[ 3.         12.04354654 19.7518666  42.70514759  1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -303.65983791301477
# Optimization restart 2/5, f = -276.49667937504637
# Optimization restart 3/5, f = -276.4967502515061
# Optimization restart 4/5, f = -276.4967438536735
# Optimization restart 5/5, f = -276.49674783958847
# [[13.  25.   5.  70.   3.   1.5]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -305.86827967319545
# Optimization restart 2/5, f = -305.86827967312354
# Optimization restart 3/5, f = -305.8682796731813
# Optimization restart 4/5, f = -279.168851472768
# Optimization restart 5/5, f = -305.8682796630178
# [[20.         25.          5.         33.19340342  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -307.932241626475
# Optimization restart 2/5, f = -280.5793256153058
# Optimization restart 3/5, f = -280.5791184798342
# Optimization restart 4/5, f = -280.57932610759025
# Optimization restart 5/5, f = -307.9322416262368
# [[ 3.         25.         16.10456574 43.32933954  3.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -310.31991225840693
# Optimization restart 2/5, f = -280.96151098471523
# Optimization restart 3/5, f = -310.31991225821713
# Optimization restart 4/5, f = -280.96151085418364
# Optimization restart 5/5, f = -310.3199122580316
# [[20.         25.         12.09362797 40.43527112  3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -312.2531360066813
# Optimization restart 2/5, f = -312.253136006688
# Optimization restart 3/5, f = -280.89738954513655
# Optimization restart 4/5, f = -280.8974377702292
# Optimization restart 5/5, f = -312.25313599054977
# [[20.          8.          5.         60.37266068  1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -314.66498014419244
# Optimization restart 2/5, f = -314.6649801380826
# Optimization restart 3/5, f = -314.6649801460046
# Optimization restart 4/5, f = -314.6649801456895
# Optimization restart 5/5, f = -283.4779214794167
# [[11.         15.55830873 27.         30.          3.          3.24689864]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -316.4221407640521
# Optimization restart 2/5, f = -316.4221407641278
# Optimization restart 3/5, f = -285.55267120219924
# Optimization restart 4/5, f = -285.5526712022405
# Optimization restart 5/5, f = -285.55267120179417
# [[20.        25.         5.        51.3600253  1.         1.5      ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -318.8000661327788
# Optimization restart 2/5, f = -318.80006572650746
# Optimization restart 3/5, f = -318.80006613709804
# Optimization restart 4/5, f = -287.86971029318033
# Optimization restart 5/5, f = -318.800066136783
# [[ 5.         25.         27.         65.36213529  3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -321.1770522432041
# Optimization restart 2/5, f = -321.177052304851
# Optimization restart 3/5, f = -321.1770523045944
# Optimization restart 4/5, f = -290.2667153775221
# Optimization restart 5/5, f = -321.17705230481585
# [[20.         8.         5.        44.6273157  3.         1.5      ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -323.5029354797071
# Optimization restart 2/5, f = -292.8422345026419
# Optimization restart 3/5, f = -292.8422348927123
# Optimization restart 4/5, f = -292.842237322158
# Optimization restart 5/5, f = -323.5029354805873
# [[20.         23.15883539 23.3841165  56.75064627  3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -325.30152081149527
# Optimization restart 2/5, f = -295.22706400485583
# Optimization restart 3/5, f = -295.22706839537864
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/stationary.py:168: RuntimeWarning:overflow encountered in true_divide
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:76: RuntimeWarning:invalid value encountered in multiply
# Optimization restart 4/5, f = -300.1395073998606
# Optimization restart 5/5, f = -295.2270686932519
# [[ 3.          8.         13.03877166 70.          3.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -327.42453461521995
# Optimization restart 2/5, f = -327.4245563239192
# Optimization restart 3/5, f = -296.6037202626911
# Optimization restart 4/5, f = -327.4245563241466
# Optimization restart 5/5, f = -296.6036270991576
# [[13.          8.          5.         42.67782351  1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -329.8469726089748
# Optimization restart 2/5, f = -329.8469726153718
# Optimization restart 3/5, f = -329.84697261608
# Optimization restart 4/5, f = -329.846972616181
# Optimization restart 5/5, f = -329.8469726158377
# [[ 8.         14.76134526 27.         54.13200973  1.          5.        ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -331.9598642447024
# Optimization restart 2/5, f = -300.07112530714966
# Optimization restart 3/5, f = -331.959864232991
# Optimization restart 4/5, f = -300.0711277188114
# Optimization restart 5/5, f = -300.07110206824325
# [[11.         14.39512571 23.15609691 70.          1.          1.5       ]]
#
# User function time loss called with 1 inputs to simulate
#
# Evaluating input: 1 of 1
#
#  Retrying in 1 seconds
# Optimization restart 1/5, f = -334.3922349318907
# Optimization restart 2/5, f = -302.1541742936108
# Optimization restart 3/5, f = -334.3922349318782
#  /Users/Matteo/opt/anaconda3/envs/ml_and_physical/lib/python3.8/site-packages/GPy/kern/src/rbf.py:52: RuntimeWarning:overflow encountered in square
# Optimization restart 4/5, f = -334.3922349291758
# Optimization restart 5/5, f = -302.1541674914263

# %%
#emukit_model = pickle.load(open('experimental_design/models/5_init_50_loop_model_timeLoss.pkl', 'rb'))

# %% [markdown]
# ### Evaluate

# %% [markdown]
# #### Test on 25 point test set

# %%
#test_X, test_Y = pickle.load(open('experimental_design/test_points/25_test_points.pkl', 'rb'))


design = RandomDesign(parameter_space)  # initialize with random points
num_test_points = 10
test_X = design.get_samples(num_test_points)
test_Y = user_function_time_loss(test_X)
with open(f'experimental_design/test_points/{num_test_points}_test_points.pkl', "wb") as f:
      pickle.dump((test_X, test_Y), f)
# Out:
# [[15.          9.72705593 10.27058551 31.34390452  3.          4.94063932]
#  [19.         13.92852147 20.34637651 58.27993496  2.          1.74447518]
#  [10.         22.71135238 12.17992285 36.52041085  3.          4.59715697]
#  [10.         24.5788716  23.52069127 57.21099899  3.          3.39226334]
#  [ 3.         18.59984289 25.81546725 33.31834658  3.          4.29792502]
#  [ 4.         10.88209666 10.85029336 34.09407136  1.          2.27898786]
#  [ 9.         21.27893502 14.44927891 52.2173265   2.          3.38242538]
#  [10.         19.47084739 22.42361137 35.80552456  2.          3.0043293 ]
#  [ 4.         21.79956825 16.31590776 32.95009075  3.          2.29320308]
#  [14.         14.04159792 12.45062444 68.97041527  3.          3.61442616]]
#
# User function time loss called with 10 inputs to simulate
#
# Evaluating input: 1 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 2 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 3 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 4 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 5 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 6 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 7 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 8 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 9 of 10
#
#  Retrying in 1 seconds
#
# Evaluating input: 10 of 10
#
#  Retrying in 1 seconds

# %%
pred_Y, pred_Y_variance = emukit_model.predict(test_X)
mse = np.sqrt(np.mean((pred_Y-test_Y)**2))
print('Root mean squared error: ', mse)
# Out:
# Root mean squared error:  0.03933937505364552

# %%
pred_Y*100, test_Y*100
# Out:
# (array([[27.84673898],
#         [24.8553864 ],
#         [32.59098263],
#         [47.27557777],
#         [49.69832816],
#         [21.18947079],
#         [29.96053027],
#         [49.39875271],
#         [47.35729953],
#         [19.62674198]]),
#  array([[28.45528455],
#         [26.87348398],
#         [30.2591251 ],
#         [50.10535188],
#         [43.86666667],
#         [30.03773585],
#         [27.40442656],
#         [49.71330275],
#         [51.58139535],
#         [19.93456132]]))

# %% [markdown]
# ### Save Model

# %%
num_init_points = 20
num_loop_iters = 200


with open(f'experimental_design/models/{num_init_points}_init_{num_loop_iters}_loop_model_timeLoss.pkl', "wb") as f:
     pickle.dump(emukit_model, f)

# %% [markdown]
# ### Analysis
#
# As we can see, optimizing for model_variance causes emukit to alternate between extreme choices of \[gridSize, edgeMaxSpeed, maxSpeed, numberOfLanes, accel\] whilst only varying edgeLength sensibly. This means that we don't explore the parameter space comprehensively - which is undesirable.
